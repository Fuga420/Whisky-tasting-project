# %% [markdown]
# これはSaketryサイトから必要なデータセットを作成するためにスクレイピングするためのものです。

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# 2. 情報を取得したいページのURL
url = 'https://www.saketry.com/113445.html'

print(f"これから、このページの情報を取得します: {url}")

# 3. WebページにアクセスしてHTML情報を取得する
try:
    response = requests.get(url)
    # サーバーからの応答がエラーだった場合に、ここでプログラムを停止させる
    response.raise_for_status() 
    print("ページのHTML情報を取得しました。")
except requests.exceptions.RequestException as e:
    print(f"エラー: ページにアクセスできませんでした。 {e}")
    exit() # プログラムを終了

# 4. BeautifulSoupを使って、HTMLを解析できる形に変換する
# 'html.parser'は、HTMLを解析するためのエンジン名
soup = BeautifulSoup(response.content, 'html.parser')
print("HTMLの解析準備ができました。")

# 5. ステップ2で調べた「住所」を元に、各情報を探し出す
print("各情報の抽出を開始します...")

# ▼ 商品名の取得
# 実際の住所である 'ty-product-block-title' を指定する
product_name_tag = soup.find('h1', class_='ty-product-block-title')

# .find('bdi') を追加する
# <h1>の中にある<bdi>タグをさらに見つけて、その中のテキストを取得する
product_name = product_name_tag.find('bdi').text.strip() if product_name_tag else '商品名不明'

print(f"  - 商品名: {product_name}")

# ▼ テイスティングノートの取得
description_area = soup.find('div', id='content_description')
tasting_note_parts = [] # 抽出したノートの各行を入れるための空リスト

if description_area:
    # description_areaの中から、全てのpタグを見つける
    paragraphs = description_area.find_all('p')
    
    for p in paragraphs:
        text = p.text.strip()
        # テキストが「香り：」「味わい：」「フィニッシュ：」のいずれかで始まるかチェック
        if text.startswith(('香り：', '味わい：', 'フィニッシュ：')):
            # 条件に一致した行だけをリストに追加する
            tasting_note_parts.append(text)
            
# 抽出した各行を、改行で連結して一つのテキストにまとめる
tasting_note = '\n'.join(tasting_note_parts)

print("  - テイスティングノートをピンポイントで取得しました。")


# ▼ スペック情報の取得
spec_data = {} # スペック情報を入れるための空の辞書を用意

# id='content_features'を持つdiv要素を見つける
spec_area = soup.find('div', id='content_features')

if spec_area:
    # spec_areaの中から、クラス名が'ty-product-feature'のdivを全て見つける
    spec_items = spec_area.find_all('div', class_='ty-product-feature')
    
    # 見つけた各項目をループ処理
    for item in spec_items:
        # ラベル（キー）と値（バリュー）をそれぞれ探す
        key_tag = item.find('span', class_='ty-product-feature__label')
        value_tag = item.find('div', class_='ty-product-feature__value')
        
        # キーと値の両方が見つかった場合のみ処理する
        if key_tag and value_tag:
            # .textで文字だけを取り出し、.strip()で余分な空白を除去
            # キーからコロン「:」も除去しておく
            key = key_tag.text.strip().replace(':', '') 
            value = value_tag.text.strip()
            
            # 辞書に保存する
            spec_data[key] = value
            print(f"  - {key}: {value}")
else:
    print("スペック情報が見つかりませんでした。")


# 6. 最終的にCSVに保存するために、全データを一つの辞書にまとめる
final_data = {
    '商品名': product_name,
    'テイスティングノート': tasting_note,
    # spec_data辞書を展開して結合
    **spec_data 
}
from pathlib import Path 
df = pd.DataFrame([final_data])

output_dir = Path('output')
output_dir.mkdir(parents=True, exist_ok=True)
file_path = output_dir / 'whisky_data_single.csv'
df.to_csv(file_path, index=False, encoding='utf-8-sig')


print("\n処理が完了しました！")
print(f"'{output_dir}'フォルダの中に '{file_path.name}' という名前でファイルが作成されています。")
# Out:
# これから、このページの情報を取得します: https://www.saketry.com/113445.html
# ページのHTML情報を取得しました。
# HTMLの解析準備ができました。
# 各情報の抽出を開始します...
#   - 商品名: ベンリネス 2010 14年 リフィル シェリーカスク 58.2% 700mlザ・モルトマン
#   - テイスティングノートをピンポイントで取得しました。
#   - 原産国: スコットランド
#   - 地域: スぺイサイド
#   - ブランド: ザ・モルトマン
#   - 銘柄: ベンリネス蒸溜所
#   - メーカー: メドウサイド・ブレンディング
#   - ビンテージ: 2010
#   - 年数: 14
#   - アルコール度数（%）: 58.2
#   - 容量 (ml／g): 700
#
# 処理が完了しました！
# 'output'フォルダの中に 'whisky_data_single.csv' という名前でファイルが作成されています。

# %%
# 1. 必要な道具をインポートする
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
from pathlib import Path

# --- ここからがプログラムの本体 ---

# 1. URLリストが書かれたファイル名を指定
url_file = 'data\saketry_url_data.txt'

# 2. 【ループ前】抽出した全データを格納するための空のリストを用意
all_whisky_data = []

# 3. URLリストを読み込む
try:
    with open(url_file, 'r') as f:
        # strip()で各行の余分な空白や改行を削除
        urls = [line.strip() for line in f if line.strip()]
    print(f"--- {len(urls)}件のURLを読み込みました。スクレイピングを開始します。 ---")
except FileNotFoundError:
    print(f"エラー: {url_file} が見つかりません。処理を中断します。")
    exit()

# 4. 【ループ中】各URLを順番に処理
for i, url in enumerate(urls):
    print(f"\n--- {i+1}/{len(urls)}件目を処理中: {url} ---")
    
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')

        # ▼ 各情報の抽出（ここは前回完成させたものと同じ）
        product_name_tag = soup.find('h1', class_='ty-product-block-title')
        product_name = product_name_tag.find('bdi').text.strip() if product_name_tag else '商品名不明'

        description_area = soup.find('div', id='content_description')
        tasting_note_parts = []
        if description_area:
            paragraphs = description_area.find_all('p')
            for p in paragraphs:
                text = p.text.strip()
                if text.startswith(('香り：', '味わい：', 'フィニッシュ：', 'アロマ：', 'フレーバー：')):
                 tasting_note_parts.append(text)
        tasting_note = '\n'.join(tasting_note_parts)

        spec_data = {}
        spec_area = soup.find('div', id='content_features')
        if spec_area:
            spec_items = spec_area.find_all('div', class_='ty-product-feature')
            for item in spec_items:
                key_tag = item.find('span', class_='ty-product-feature__label')
                value_tag = item.find('div', class_='ty-product-feature__value')
                if key_tag and value_tag:
                    key = key_tag.text.strip().replace(':', '')
                    value = value_tag.text.strip()
                    spec_data[key] = value
        
        # １ページ分の全データを一つの辞書にまとめる
        single_whisky_data = {
            '商品名': product_name,
            'テイスティングノート': tasting_note,
            **spec_data
        }

        # 抽出した１ページ分のデータを、大きなリストに追加する
        all_whisky_data.append(single_whisky_data)
        print(f"「{product_name}」のデータを正常に取得しました。")

    except Exception as e:
        print(f"エラーが発生したため、このURLの処理をスキップします: {e}")
    
    # サーバーに配慮して待機
    wait_time = random.uniform(2, 5)
    print(f"{wait_time:.2f}秒待機します...")
    time.sleep(wait_time)

# 5. 【ループ後】全データが溜まったリストを、一括でCSVファイルに保存
if all_whisky_data:
    df = pd.DataFrame(all_whisky_data)
    
    # 保存先フォルダとファイルパスを指定
    output_dir = Path('output')
    output_dir.mkdir(parents=True, exist_ok=True)
    file_path = output_dir / 'whisky_dataset_final.csv'
    
    # CSVファイルとして出力
    df.to_csv(file_path, index=False, encoding='utf-8-sig')
    
    print(f"\n--- 全ての処理が完了しました！ ---")
    print(f"{len(all_whisky_data)}件のデータを抽出し、'{file_path}'に保存しました。")
else:
    print("\nデータを一件も抽出できませんでした。")
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\s'
# <>:12: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\fugat\AppData\Local\Temp\ipykernel_44124\1223795352.py:12: SyntaxWarning: invalid escape sequence '\s'
#   url_file = 'data\saketry_url_data.txt'
# --- 98件のURLを読み込みました。スクレイピングを開始します。 ---
#
# --- 1/98件目を処理中: https://www.saketry.com/113472.html ---
# 「リンクウッド 2009 13年 バーボンカスク 51.3％ 700mlザ・テイスター」のデータを正常に取得しました。
# 2.11秒待機します...
#
# --- 2/98件目を処理中: https://www.saketry.com/113444.html ---
# 「アードベッグ 2007 16年 スコッチモルト販売45周年記念ボトル 54.1% 700mlザ・モルトマン」のデータを正常に取得しました。
# 4.34秒待機します...
#
# --- 3/98件目を処理中: http://saketry.com/113445.html ---
# 「ベンリネス 2010 14年 リフィル シェリーカスク 58.2% 700mlザ・モルトマン」のデータを正常に取得しました。
# 4.53秒待機します...
#
# --- 4/98件目を処理中: https://www.saketry.com/113443.html ---
# 「コッツウォルズ  ハーベスト・シリーズ No.3 アンバーメドウ シングルモルトウイスキー 51.6% 700mlコッツウォルズ」のデータを正常に取得しました。
# 3.28秒待機します...
#
# --- 5/98件目を処理中: https://www.saketry.com/113408.html ---
# 「成田一徹「THE DUFFTOWN」ラベル／レダイグ 2009 14年 ホグスヘッド 50.5% 700ml成田一徹 ラベル・ウイスキー」のデータを正常に取得しました。
# 4.59秒待機します...
#
# --- 6/98件目を処理中: https://www.saketry.com/113302.html ---
# 「イクイノックス＆ソルスティス スプリングエディション 2024 ティーニニック 12年 シングルリフィル・ホグスヘッド 48.5% 700mlイクイノックス＆ソルスティス」のデータを正常に取得しました。
# 2.63秒待機します...
#
# --- 7/98件目を処理中: https://www.saketry.com/113407.html ---
# 「『旅みやげ第三集 別府の朝』ラベル 川瀬巴水 アン・オークニー2006 17年  59.1% 700MLアートエクスプレッション」のデータを正常に取得しました。
# 4.05秒待機します...
#
# --- 8/98件目を処理中: https://www.saketry.com/113404.html ---
# 「エディション No.67 オールド・ロスデュー 1993 29年 リフィル・ホグスヘッド 57.1％ 700mlウイスキースポンジ」のデータを正常に取得しました。
# 4.64秒待機します...
#
# --- 9/98件目を処理中: https://www.saketry.com/113416.html ---
# 「エディション No.92 アベラワー 33年 49.7% 700mlウイスキースポンジ」のデータを正常に取得しました。
# 2.59秒待機します...
#
# --- 10/98件目を処理中: https://www.saketry.com/113410.html ---
# 「『笑ゥせぇるすまん』ラベル／ベンネヴィス 1997 25年 シェリーバット 48.7% 700ml漫画ラベルシリーズ」のデータを正常に取得しました。
# 3.68秒待機します...
#
# --- 11/98件目を処理中: https://www.saketry.com/113301.html ---
# 「エディション No.89 ‘ゴーン グラント’ 31年 2nd フィル・バレル 43.9% 700mlウイスキースポンジ」のデータを正常に取得しました。
# 3.26秒待機します...
#
# --- 12/98件目を処理中: https://www.saketry.com/113303.html ---
# 「エディション No.90 ブラドノック 34年 リフィルバレル 55.1% 700mlウイスキースポンジ」のデータを正常に取得しました。
# 4.11秒待機します...
#
# --- 13/98件目を処理中: https://www.saketry.com/113402.html ---
# 「アイル・オブ・ハリス ザ・ヒーラック オロロソカスク シングルモルトウイスキー 46% 700mlアイル・オブ・ハリス」のデータを正常に取得しました。
# 4.05秒待機します...
#
# --- 14/98件目を処理中: https://www.saketry.com/113374.html ---
# 「ウルフバーン ジャパン・エクスクルーシブ 7 2017 7年 カスク No.245 50% 700mlウルフバーン」のデータを正常に取得しました。
# 4.93秒待機します...
#
# --- 15/98件目を処理中: https://www.saketry.com/113194.html ---
# 「エディション No.84 オーヘントッシャン 31年 2nd フィル・バレル 53.6% 700mlウイスキースポンジ」のデータを正常に取得しました。
# 2.74秒待機します...
#
# --- 16/98件目を処理中: https://www.saketry.com/113297.html ---
# 「エディション No.85 ベンネヴィス 10年 リフィルバット / リフィル・クォーターカスク・フィニッシュ 52.0% 700mlウイスキースポンジ」のデータを正常に取得しました。
# 3.58秒待機します...
#
# --- 17/98件目を処理中: https://www.saketry.com/113193.html ---
# 「イクイノックス＆ソルスティス ウィンターエディション 2023 ミルトンダフ 11年 1st フィル・シェリーホグスヘッド 48.5% 700mlイクイノックス＆ソルスティス」のデータを正常に取得しました。
# 4.78秒待機します...
#
# --- 18/98件目を処理中: https://www.saketry.com/113192.html ---
# 「オールド・オークニー OO2 19年 53% 700mlオールド・オークニー」のデータを正常に取得しました。
# 3.33秒待機します...
#
# --- 19/98件目を処理中: https://www.saketry.com/113386.html ---
# 「ブルックラディ 1991 32年 リフィル ホグスヘッド 49.3% 700mlザ・モルトマン」のデータを正常に取得しました。
# 2.71秒待機します...
#
# --- 20/98件目を処理中: https://www.saketry.com/113360.html ---
# 「アイランズ ブレンデッドモルト 1999 22年 バーボン ホグスヘッド 46.5% 700mlザ・モルトマン」のデータを正常に取得しました。
# 4.32秒待機します...
#
# --- 21/98件目を処理中: https://www.saketry.com/113363.html ---
# 「ブレンデットスコッチ 信濃屋 37年 43.8% 700mlザ・モルトマン」のデータを正常に取得しました。
# 4.11秒待機します...
#
# --- 22/98件目を処理中: https://www.saketry.com/113362.html ---
# 「ブレンデットスコッチ 信濃屋  25年 48.2% 700mlザ・モルトマン」のデータを正常に取得しました。
# 5.00秒待機します...
#
# --- 23/98件目を処理中: https://www.saketry.com/113366.html ---
# 「ウルフバーン ウィック・ハーバー・トラスト ブラックサタデー 46% 700mlウルフバーン」のデータを正常に取得しました。
# 4.34秒待機します...
#
# --- 24/98件目を処理中: https://www.saketry.com/113365.html ---
# 「ウルフバーン マンサニージャカスクフィニッシュ 46% 700mlウルフバーン」のデータを正常に取得しました。
# 4.70秒待機します...
#
# --- 25/98件目を処理中: https://www.saketry.com/113356.html ---
# 「インバーゴードン 1974 50年 バーボンバレル 43.2% 700mlザ・グレーンマン」のデータを正常に取得しました。
# 3.93秒待機します...
#
# --- 26/98件目を処理中: https://www.saketry.com/113325.html ---
# 「シングルモルト 駒ヶ岳 2024 エディション 50% 700MLシングルモルト駒ヶ岳」のデータを正常に取得しました。
# 2.50秒待機します...
#
# --- 27/98件目を処理中: https://www.saketry.com/113322.html ---
# 「インチガワー 2010 12年 ホグスヘッド 57.6% 700mlスピリッツ ショップ セレクション」のデータを正常に取得しました。
# 2.72秒待機します...
#
# --- 28/98件目を処理中: https://www.saketry.com/113320.html ---
# 「オスロスク 2010 12年 ホグスヘッド 60.8% 700mlスピリッツ ショップ セレクション」のデータを正常に取得しました。
# 2.33秒待機します...
#
# --- 29/98件目を処理中: https://www.saketry.com/113189.html ---
# 「イクイノックス＆ソルスティス オータム エディション 2023 アバフェルディ 10年 48.5% 700mlイクイノックス＆ソルスティス」のデータを正常に取得しました。
# 4.96秒待機します...
#
# --- 30/98件目を処理中: https://www.saketry.com/113233.html ---
# 「「村松誠イラスト」ラベル "犬” TOMARTIN 2008 13年 49.4% 700ML漫画ラベル」のデータを正常に取得しました。
# 4.12秒待機します...
#
# --- 31/98件目を処理中: https://www.saketry.com/113219.html ---
# 「YUZA スプリング イン ジャパン 2024 55% 700ML限定シリーズ」のデータを正常に取得しました。
# 3.63秒待機します...
#
# --- 32/98件目を処理中: https://www.saketry.com/113127.html ---
# 「オールドオークニーモルト 13年 50.0% 700mlウイスキースポンジ」のデータを正常に取得しました。
# 3.15秒待機します...
#
# --- 33/98件目を処理中: https://www.saketry.com/113132.html ---
# 「ウルフバーン バッチNo.177 46% 700mlウルフバーン」のデータを正常に取得しました。
# 3.76秒待機します...
#
# --- 34/98件目を処理中: https://www.saketry.com/113107.html ---
# 「コッツウォルズ バーボンカスク シングルモルトウイスキー 59.1% 700mlコッツウォルズ」のデータを正常に取得しました。
# 4.44秒待機します...
#
# --- 35/98件目を処理中: https://www.saketry.com/113104.html ---
# 「ザ・ヒーラック アイル・オブ ハリス シングルモルト・スコッチウイスキー 46％ 700mlアイル・オブ・ハリス」のデータを正常に取得しました。
# 3.66秒待機します...
#
# --- 36/98件目を処理中: https://www.saketry.com/113062.html ---
# 「ウルフバーン ジャパン・エクスクルーシブ 6 2016 6年 カスク No. 196 50% 700mlウルフバーン」のデータを正常に取得しました。
# 4.81秒待機します...
#
# --- 37/98件目を処理中: https://www.saketry.com/113027.html ---
# 「イクイノックス＆ソルスティス スプリングエディション 2023 ベンネヴィス 10年 48.5% 700mlイクイノックス＆ソルスティス」のデータを正常に取得しました。
# 4.91秒待機します...
#
# --- 38/98件目を処理中: https://www.saketry.com/112996.html ---
# 「ウルフバーン 10年 46% 700mlウルフバーン」のデータを正常に取得しました。
# 2.88秒待機します...
#
# --- 39/98件目を処理中: https://www.saketry.com/112993.html ---
# 「ハーツ・アンド・クラフツ No.3 ラムカスク シングルモルト・ウイスキー 55.6% 700mlコッツウォルズ」のデータを正常に取得しました。
# 2.05秒待機します...
#
# --- 40/98件目を処理中: https://www.saketry.com/112948.html ---
# 「TWA&TR ｢ARTWORK｣ オールドロースデュ 1993 29年 ホグスヘッド 52.3% 700MLART WORK SERIES」のデータを正常に取得しました。
# 2.26秒待機します...
#
# --- 41/98件目を処理中: https://www.saketry.com/111161.html ---
# 「トマーティン ファイブ ヴァーチューズ ウッド 46% 700mlトマーティン」のデータを正常に取得しました。
# 4.80秒待機します...
#
# --- 42/98件目を処理中: https://www.saketry.com/112857.html ---
# 「コッツウォルズ ピーテッドカスクシングルモルトウイスキー 59.6% 700mlコッツウォルズ」のデータを正常に取得しました。
# 3.66秒待機します...
#
# --- 43/98件目を処理中: https://www.saketry.com/112819.html ---
# 「ケイデンヘッド テネシー 18年 46% 700MLオリジナルコレクション」のデータを正常に取得しました。
# 3.48秒待機します...
#
# --- 44/98件目を処理中: https://www.saketry.com/112639.html ---
# 「コッツウォルズ ファウンダーズチョイス シングルモルトウイスキー 59.1% 700mlコッツウォルズ」のデータを正常に取得しました。
# 2.21秒待機します...
#
# --- 45/98件目を処理中: https://www.saketry.com/112638.html ---
# 「ウルフバーン バッチ 458 46% 700mlウルフバーン」のデータを正常に取得しました。
# 4.72秒待機します...
#
# --- 46/98件目を処理中: https://www.saketry.com/112618.html ---
# 「TWA&TR レダイグ 2007 14年 ホグスヘッド 53.4% 700MLART WORK」のデータを正常に取得しました。
# 3.75秒待機します...
#
# --- 47/98件目を処理中: https://www.saketry.com/112484.html ---
# 「クレイゲラヒ 2008 13年 シェリーバット 55.2% 700mlクライマックスシリーズ」のデータを正常に取得しました。
# 4.52秒待機します...
#
# --- 48/98件目を処理中: https://www.saketry.com/112344.html ---
# 「ザ イングリッシュ ウイスキー 2007 14年 ワインカスク 58.4% 700MLザ・イングリッシュウイスキー」のデータを正常に取得しました。
# 2.17秒待機します...
#
# --- 49/98件目を処理中: https://www.saketry.com/110371.html ---
# 「燻酒 アイラ シングルモルト 50% 700ml燻酒」のデータを正常に取得しました。
# 2.32秒待機します...
#
# --- 50/98件目を処理中: https://www.saketry.com/112231.html ---
# 「イチローズ モルト＆グレーン 46% 700mlイチローズ」のデータを正常に取得しました。
# 4.14秒待機します...
#
# --- 51/98件目を処理中: https://www.saketry.com/112106.html ---
# 「コッツウォルズ シェリーカスク シングルモルトウイスキー 57.4% 700mlコッツウォルズ」のデータを正常に取得しました。
# 2.81秒待機します...
#
# --- 52/98件目を処理中: https://www.saketry.com/112132.html ---
# 「ブティック・ウイスキー・カンパニー ワールド・ウイスキー・ブレンド 41.6% 700mlブティック・ウイスキー・カンパニー」のデータを正常に取得しました。
# 3.14秒待機します...
#
# --- 53/98件目を処理中: https://www.saketry.com/112072.html ---
# 「イングリッシュ ウイスキー 2007-2019 11年 49.8% 700mlノーススター」のデータを正常に取得しました。
# 2.63秒待機します...
#
# --- 54/98件目を処理中: https://www.saketry.com/111974.html ---
# 「ウルフバーン バッチ 204 46% 700mlウルフバーン」のデータを正常に取得しました。
# 4.80秒待機します...
#
# --- 55/98件目を処理中: https://www.saketry.com/111912.html ---
# 「マルスモルテージ越百 モルトセレクション 43％ 700ml」のデータを正常に取得しました。
# 4.79秒待機します...
#
# --- 56/98件目を処理中: https://www.saketry.com/111865.html ---
# 「コッツウォルズ シングルモルトウイスキー 46% 700mlコッツウォルズ」のデータを正常に取得しました。
# 4.65秒待機します...
#
# --- 57/98件目を処理中: https://www.saketry.com/110708.html ---
# 「ウルフバーン ノースランド 46% 700mlウルフバーン」のデータを正常に取得しました。
# 4.87秒待機します...
#
# --- 58/98件目を処理中: https://www.saketry.com/110833.html ---
# 「ウルフバーン オーロラ 46% 700mlウルフバーン」のデータを正常に取得しました。
# 2.24秒待機します...
#
# --- 59/98件目を処理中: https://www.saketry.com/111060.html ---
# 「ウルフバーン モーヴェン 46% 700mlウルフバーン」のデータを正常に取得しました。
# 4.71秒待機します...
#
# --- 60/98件目を処理中: https://www.saketry.com/111253.html ---
# 「ウルフバーン ラングスキップ 58% 700mlウルフバーン」のデータを正常に取得しました。
# 2.12秒待機します...
#
# --- 61/98件目を処理中: https://www.saketry.com/105095.html ---
# 「クラシック オブ アイラ 58% 700mlスコッチモルトセールス」のデータを正常に取得しました。
# 3.74秒待機します...
#
# --- 62/98件目を処理中: https://www.saketry.com/113467.html ---
# 「MARS The Y.A. #04 50％ 700mlMARS The.Y.A.」のデータを正常に取得しました。
# 3.25秒待機します...
#
# --- 63/98件目を処理中: https://www.saketry.com/113406.html ---
# 「『めぞん一刻』音無響子＆五代裕作ラベル／キルダルトン 2009 ホグスヘッド 54.2% 700ml漫画ラベルシリーズ」のデータを正常に取得しました。
# 2.37秒待機します...
#
# --- 64/98件目を処理中: https://www.saketry.com/113405.html ---
# 「『めぞん一刻』音無響子ラベル／グレングラント 1998 25年 リフィル・シェリーバット 48.9% 700ml漫画ラベルシリーズ」のデータを正常に取得しました。
# 4.81秒待機します...
#
# --- 65/98件目を処理中: https://www.saketry.com/113358.html ---
# 「グレンロッシー 1997 26年 リフィル シェリーバット 47.6% 700mlザ・モルトマン」のデータを正常に取得しました。
# 3.73秒待機します...
#
# --- 66/98件目を処理中: https://www.saketry.com/113364.html ---
# 「リンクウッド 2006 17年 マデイラカスク フィニッシュ ジャパン・エクスクルーシブ 52.2% 700mlザ・モルトマン」のデータを正常に取得しました。
# 3.93秒待機します...
#
# --- 67/98件目を処理中: https://www.saketry.com/113357.html ---
# 「ダルユーイン 2009 14年 リフィル シェリーバット 53.1% 700mlザ・モルトマン」のデータを正常に取得しました。
# 3.83秒待機します...
#
# --- 68/98件目を処理中: https://www.saketry.com/113310.html ---
# 「コッツウォルズ リザーブ シングルモルトウイスキー 1st フィル・バーボンカスク / レッドワインカスク 50% 700mlコッツウォルズ」のデータを正常に取得しました。
# 2.16秒待機します...
#
# --- 69/98件目を処理中: https://www.saketry.com/113332.html ---
# 「イチローズ モルト アンド グレーン 20th アニバーサリーエディション 48% 700MLICHRO`S MALT」のデータを正常に取得しました。
# 4.35秒待機します...
#
# --- 70/98件目を処理中: https://www.saketry.com/113314.html ---
# 「ロブスト シガーモルト 2015 8年 オロロソシェリーカスク 52.5% 700mlザ・ウイスキー・セラー プライベート・セラーズ・コレクション」のデータを正常に取得しました。
# 3.45秒待機します...
#
# --- 71/98件目を処理中: https://www.saketry.com/113323.html ---
# 「ガーヴァン 2006 17年 ファインブルターニュカスクフィニッシュ 53.7% 700mlピンテイル」のデータを正常に取得しました。
# 2.86秒待機します...
#
# --- 72/98件目を処理中: https://www.saketry.com/113315.html ---
# 「グレンスペイ 2009 14年 ルピアック ワインカスク フィニッシュ 54.7% 700mlピンテイル」のデータを正常に取得しました。
# 3.37秒待機します...
#
# --- 73/98件目を処理中: https://www.saketry.com/113311.html ---
# 「グレンバーギー 2010 13年 オロロソ シェリー フィニッシュ 53.3% 700mlザ・ウイスキー・セラー プライベート・セラーズ・コレクション」のデータを正常に取得しました。
# 4.60秒待機します...
#
# --- 74/98件目を処理中: https://www.saketry.com/113312.html ---
# 「カリラ 2012 11年 コート・ロティ ワインカスク フィニッシュ 55.2% 700mlザ・ウイスキー・セラー プライベート・セラーズ・コレクション」のデータを正常に取得しました。
# 3.86秒待機します...
#
# --- 75/98件目を処理中: https://www.saketry.com/113316.html ---
# 「オスロスク 2008 15年 フォンディジョン ワインカスク フィニッシュ 54.3% 700mlピンテイル」のデータを正常に取得しました。
# 3.87秒待機します...
#
# --- 76/98件目を処理中: https://www.saketry.com/113313.html ---
# 「ノースブリティッシュ 1989 33年 リフィル バーボンバレル 50.1% 700mlザ・ウイスキー・セラー プライベート・セラーズ・コレクション」のデータを正常に取得しました。
# 2.77秒待機します...
#
# --- 77/98件目を処理中: https://www.saketry.com/113319.html ---
# 「グレンエルギン 2008 12年 シェリーバット 58.7% 700mlスピリッツ ショップ セレクション」のデータを正常に取得しました。
# 2.04秒待機します...
#
# --- 78/98件目を処理中: https://www.saketry.com/113318.html ---
# 「レダイグ 2005 14年 ホグスヘッド 57.8% 700mlスピリッツ ショップ セレクション」のデータを正常に取得しました。
# 2.02秒待機します...
#
# --- 79/98件目を処理中: https://www.saketry.com/113317.html ---
# 「ベンネヴィス 1997 25年 ホグスヘッド 47.6% 700mlスピリッツ ショップ セレクション」のデータを正常に取得しました。
# 2.60秒待機します...
#
# --- 80/98件目を処理中: https://www.saketry.com/113276.html ---
# 「トーモア 2015 7年 オロロソ シェリー カスク フィニッシュ 57% 700mlザ・クーパーズチョイス」のデータを正常に取得しました。
# 3.31秒待機します...
#
# --- 81/98件目を処理中: https://www.saketry.com/113275.html ---
# 「インバーゴードン2005 18年 マルサラ フィニッシュ 47.8% 700mlザ・クーパーズチョイス」のデータを正常に取得しました。
# 4.37秒待機します...
#
# --- 82/98件目を処理中: https://www.saketry.com/113274.html ---
# 「ディーンストン 2014 8年 マルサラ フィニッシュ 54% 700mlザ・クーパーズチョイス」のデータを正常に取得しました。
# 4.73秒待機します...
#
# --- 83/98件目を処理中: https://www.saketry.com/113273.html ---
# 「タムデュー 2015 8年 マデイラカスクフィニッシュ 57.4% 700mlザ・クーパーズチョイス」のデータを正常に取得しました。
# 3.52秒待機します...
#
# --- 84/98件目を処理中: https://www.saketry.com/113271.html ---
# 「グレンマレイ 2015 8年 マルサラ フィニッシュ 58.5% 700mlザ・クーパーズチョイス」のデータを正常に取得しました。
# 2.44秒待機します...
#
# --- 85/98件目を処理中: https://www.saketry.com/113272.html ---
# 「リンクウッド 2011 12年 オロロソシェリーカスクフィニッシュ 54% 700mlザ・クーパーズチョイス」のデータを正常に取得しました。
# 4.21秒待機します...
#
# --- 86/98件目を処理中: https://www.saketry.com/113270.html ---
# 「グレンロッシー2011 12年 カルヴァドスカスクフィニッシュ 54.5% 700mlザ・クーパーズチョイス」のデータを正常に取得しました。
# 4.65秒待機します...
#
# --- 87/98件目を処理中: https://www.saketry.com/113268.html ---
# 「カンバス 1991 32年 47.5% 700mlザ・クーパーズチョイス」のデータを正常に取得しました。
# 3.86秒待機します...
#
# --- 88/98件目を処理中: https://www.saketry.com/113267.html ---
# 「ベンリネス 2011 12年 マルティニークラムカスクフィニッシュ 51.5% 700mlザ・クーパーズチョイス」のデータを正常に取得しました。
# 3.86秒待機します...
#
# --- 89/98件目を処理中: https://www.saketry.com/113266.html ---
# 「ブレアソール 2011 12年 マスカットカスクフィニッシュ 52.5% 700mlザ・クーパーズチョイス」のデータを正常に取得しました。
# 4.42秒待機します...
#
# --- 90/98件目を処理中: https://www.saketry.com/113265.html ---
# 「アードモア 2013 10年 52.5% 700mlザ・クーパーズチョイス」のデータを正常に取得しました。
# 3.01秒待機します...
#
# --- 91/98件目を処理中: https://www.saketry.com/113242.html ---
# 「シークレットハイランド 2010 13年 シェリーカスク 52.1% 700mlディスティラリーズ・コレクション」のデータを正常に取得しました。
# 4.98秒待機します...
#
# --- 92/98件目を処理中: https://www.saketry.com/113243.html ---
# 「シークレットオークニー  2006 17年 ホグスヘッド 51.7% 700mlディスティラリーズ・コレクション」のデータを正常に取得しました。
# 4.24秒待機します...
#
# --- 93/98件目を処理中: https://www.saketry.com/113244.html ---
# 「バルメナック 2013 10年 シェリーホグスヘッド 53.8% 700mlディスティラリーズ・コレクション」のデータを正常に取得しました。
# 3.34秒待機します...
#
# --- 94/98件目を処理中: https://www.saketry.com/113245.html ---
# 「グレンロセス 1992 30年 ホグスヘッド 48.3% 700mlザ・テイスター」のデータを正常に取得しました。
# 4.88秒待機します...
#
# --- 95/98件目を処理中: https://www.saketry.com/113207.html ---
# 「ブレアソール 1992 31年 43.3% 700mlザ・モルトマン」のデータを正常に取得しました。
# 3.02秒待機します...
#
# --- 96/98件目を処理中: https://www.saketry.com/113249.html ---
# 「ノックデュー 2013 10年 シェリーカスク 能登チャリティーボトル 54.8% 700mlザ・モルトマン」のデータを正常に取得しました。
# 2.58秒待機します...
#
# --- 97/98件目を処理中: https://www.saketry.com/113248.html ---
# 「ベンネヴィス 1998 25年 ホグスヘッド 能登チャリティーボトル 49.4% 700mlザ・モルトマン」のデータを正常に取得しました。
# 4.09秒待機します...
#
# --- 98/98件目を処理中: https://www.saketry.com/113254.html ---
# 「『東京十二景 馬込の月』ラベル  川瀬巴水 クラインリーシュ 2011 12年 61.0% 700MLアートエクスプレッション」のデータを正常に取得しました。
# 3.62秒待機します...
#
# --- 全ての処理が完了しました！ ---
# 98件のデータを抽出し、'output\whisky_dataset_final.csv'に保存しました。

# %%
import requests
from bs4 import BeautifulSoup
import time
from urllib.parse import urljoin

# --- 設定項目 ---
# スクレイピングを開始する最初のページ（ウイスキーカテゴリの1ページ目）
start_url = 'https://www.saketry.com/all/whisky/' 
output_file = 'whisky_urls.txt'

# --- プログラム本体 ---
collected_urls = set()
current_url = start_url 

print("--- URL収集を開始します ---")

while current_url:
    print(f"--- ページを処理中: {current_url} ---")
    
    try:
        response = requests.get(current_url, timeout=10)
        if response.status_code == 404:
            print("ページが見つかりませんでした (404)。最後のページに到達したと判断します。")
            break
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # 各商品を囲んでいるコンテナを見つける
        product_containers = soup.find_all('div', class_=lambda c: c and c.startswith('ty-column'))
        
        if not product_containers:
            print("このページには商品が見つかりませんでした。")
        else:
            # 各コンテナから商品ページへのリンク(aタグ)を見つけ、URLを抽出する
            for container in product_containers:
                # ★★★ ここがあなたが見つけてくれた正しいクラス名 ★★★
                a_tag = container.find('a', class_='product-title')
                
                if a_tag and a_tag.has_attr('href'):
                    absolute_url = a_tag['href']
                    collected_urls.add(absolute_url)

            print(f"{len(product_containers)}件の商品リンクを発見。現在合計{len(collected_urls)}件。")

        # 『次のページ』ボタンを探す
        next_page_tag = soup.find('a', class_='ty-pagination__next')
        
        if next_page_tag and next_page_tag.has_attr('href'):
            current_url = next_page_tag['href']
        else:
            print("『次のページ』ボタンが見つかりませんでした。全ページの処理を完了します。")
            current_url = None
            
        time.sleep(2)

    except requests.exceptions.RequestException as e:
        print(f"エラーが発生したため、処理を中断します: {e}")
        break
    except Exception as e:
        print(f"予期せぬエラーが発生しました: {e}")
        break

# --- 収集した全URLをファイルに書き出す ---
if collected_urls:
    print(f"\n--- 合計{len(collected_urls)}件のユニークなURLを収集しました ---")
    with open(output_file, 'w', encoding='utf-8') as f:
        for url in sorted(list(collected_urls)):
            f.write(url + '\n')
    print(f"'{output_file}'に全URLを保存しました。")
else:
    print("URLを一件も収集できませんでした。")
# Out:
# --- URL収集を開始します ---
# --- ページを処理中: https://www.saketry.com/all/whisky/ ---
# 32件の商品リンクを発見。現在合計32件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-2/ ---
# 32件の商品リンクを発見。現在合計64件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-3/ ---
# 32件の商品リンクを発見。現在合計96件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-4/ ---
# 32件の商品リンクを発見。現在合計128件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-5/ ---
# 32件の商品リンクを発見。現在合計160件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-6/ ---
# 32件の商品リンクを発見。現在合計192件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-7/ ---
# 32件の商品リンクを発見。現在合計224件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-8/ ---
# 32件の商品リンクを発見。現在合計256件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-9/ ---
# 32件の商品リンクを発見。現在合計288件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-10/ ---
# 32件の商品リンクを発見。現在合計320件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-11/ ---
# 32件の商品リンクを発見。現在合計352件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-12/ ---
# 32件の商品リンクを発見。現在合計384件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-13/ ---
# 32件の商品リンクを発見。現在合計416件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-14/ ---
# 32件の商品リンクを発見。現在合計448件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-15/ ---
# 32件の商品リンクを発見。現在合計480件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-16/ ---
# 32件の商品リンクを発見。現在合計512件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-17/ ---
# 32件の商品リンクを発見。現在合計544件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-18/ ---
# 32件の商品リンクを発見。現在合計576件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-19/ ---
# 32件の商品リンクを発見。現在合計608件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-20/ ---
# 32件の商品リンクを発見。現在合計640件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-21/ ---
# 32件の商品リンクを発見。現在合計672件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-22/ ---
# 32件の商品リンクを発見。現在合計704件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-23/ ---
# 32件の商品リンクを発見。現在合計736件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-24/ ---
# 32件の商品リンクを発見。現在合計768件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-25/ ---
# 32件の商品リンクを発見。現在合計800件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-26/ ---
# 32件の商品リンクを発見。現在合計832件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-27/ ---
# 32件の商品リンクを発見。現在合計864件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-28/ ---
# 32件の商品リンクを発見。現在合計896件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-29/ ---
# 32件の商品リンクを発見。現在合計928件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-30/ ---
# 32件の商品リンクを発見。現在合計960件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-31/ ---
# 32件の商品リンクを発見。現在合計992件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-32/ ---
# 32件の商品リンクを発見。現在合計1024件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-33/ ---
# 32件の商品リンクを発見。現在合計1056件。
# --- ページを処理中: https://www.saketry.com/all/whisky/page-34/ ---
# 20件の商品リンクを発見。現在合計1076件。
# 『次のページ』ボタンが見つかりませんでした。全ページの処理を完了します。
#
# --- 合計1076件のユニークなURLを収集しました ---
# 'whisky_urls.txt'に全URLを保存しました。

# %%
# 1. 必要な道具をインポートする
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
from pathlib import Path

# --- プログラムの本体 ---

# 1. URLリストが書かれたファイル名を指定
url_file = 'whisky_urls.txt' 

# 2. URLリストを読み込む
try:
    with open(url_file, 'r', encoding='utf-8') as f:
        urls = [line.strip() for line in f if line.strip()]
    print(f"--- {len(urls)}件のURLを読み込みました。詳細情報の収集を開始します。 ---")
except FileNotFoundError:
    print(f"エラー: '{url_file}' が見つかりません。先に`url_collector.py`を実行してください。")
    exit()

# --- 保存処理の準備 ---
# 保存先フォルダとファイルパスを指定
output_dir = Path('output')
output_dir.mkdir(parents=True, exist_ok=True)
file_path = output_dir / 'whisky_dataset_final.csv'

# 3. 【ループ中】各URLを順番に処理
for i, url in enumerate(urls):
    print(f"\n--- {i+1}/{len(urls)}件目を処理中: {url} ---")
    
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')

        # ▼ 各情報の抽出ロジック
        product_name_tag = soup.find('h1', class_='ty-product-block-title')
        product_name = product_name_tag.find('bdi').text.strip() if product_name_tag else '商品名不明'

        description_area = soup.find('div', id='content_description')
        tasting_note_parts = []
        if description_area:
            paragraphs = description_area.find_all('p')
            for p in paragraphs:
                text = p.text.strip()
                if text.startswith(('香り：', '味わい：', 'フィニッシュ：', 'アロマ：', 'フレーバー：')):
                    tasting_note_parts.append(text)
        tasting_note = '\n'.join(tasting_note_parts)

        spec_data = {}
        spec_area = soup.find('div', id='content_features')
        if spec_area:
            spec_items = spec_area.find_all('div', class_='ty-product-feature')
            for item in spec_items:
                key_tag = item.find('span', class_='ty-product-feature__label')
                value_tag = item.find('div', class_='ty-product-feature__value')
                if key_tag and value_tag:
                    key = key_tag.text.strip().replace(':', '')
                    value = value_tag.text.strip()
                    spec_data[key] = value
        
        # １ページ分の全データを一つの辞書にまとめる
        single_whisky_data = {
            '商品名': product_name,
            'テイスティングノート': tasting_note,
            'URL': url,
            **spec_data
        }

        # --- ▼▼▼ ここがメモリに優しい保存ロジック ▼▼▼ ---
        # 1件分のデータをDataFrameに変換
        df_single = pd.DataFrame([single_whisky_data])

        # ループの初回(i=0)だけヘッダー付きで新規作成(mode='w')し、
        # 2回目以降はヘッダーなしで追記(mode='a')していく
        if i == 0:
            # ファイルを新規作成モード('w')で開く
            df_single.to_csv(file_path, mode='w', header=True, index=False, encoding='utf-8-sig')
            print(f"○ 「{product_name}」のデータを取得し、ファイルを新規作成しました。")
        else:
            # ファイルを追記モード('a')で開く
            df_single.to_csv(file_path, mode='a', header=False, index=False, encoding='utf-8-sig')
            print(f"○ 「{product_name}」のデータを取得し、ファイルに追記しました。")

    except Exception as e:
        print(f"× エラーが発生したため、このURLの処理をスキップします: {e}")
    
    # サーバーに配慮して待機
    wait_time = random.uniform(2, 4)
    print(f"   {wait_time:.2f}秒待機します...")
    time.sleep(wait_time)

print(f"\n--- 全ての処理が完了しました！ ---")
print(f"'{file_path}'にデータが保存されています。")
# Out:
# --- 1076件のURLを読み込みました。詳細情報の収集を開始します。 ---
#
# --- 1/1076件目を処理中: https://www.saketry.com/103120.html ---
# ○ 「クラシック オブ アイラ (10L樽)」のデータを取得し、ファイルを新規作成しました。
#    2.40秒待機します...
#
# --- 2/1076件目を処理中: https://www.saketry.com/103237.html ---
# ○ 「ハイランド・クラシック (10L樽)」のデータを取得し、ファイルに追記しました。
#    2.06秒待機します...
#
# --- 3/1076件目を処理中: https://www.saketry.com/105095.html ---
# ○ 「クラシック オブ アイラ 58% 700mlスコッチモルトセールス」のデータを取得し、ファイルに追記しました。
#    3.60秒待機します...
#
# --- 4/1076件目を処理中: https://www.saketry.com/110066.html ---
# ○ 「タリバーディン 1991 19年 46％ザ・モルトマン」のデータを取得し、ファイルに追記しました。
#    2.85秒待機します...
#
# --- 5/1076件目を処理中: https://www.saketry.com/110371.html ---
# ○ 「燻酒 アイラ シングルモルト 50% 700ml燻酒」のデータを取得し、ファイルに追記しました。
#    3.84秒待機します...
#
# --- 6/1076件目を処理中: https://www.saketry.com/110408.html ---
# ○ 「ミズナラウッドリザーブ 46%イチローズモルト」のデータを取得し、ファイルに追記しました。
#    2.06秒待機します...
#
# --- 7/1076件目を処理中: https://www.saketry.com/110409.html ---
# ○ 「イチローズモルトワインウッドリザーブ 46% 700mlイチローズモルト」のデータを取得し、ファイルに追記しました。
#    3.65秒待機します...
#
# --- 8/1076件目を処理中: https://www.saketry.com/110484.html ---
# ○ 「アラン ポートカスク・フィニッシュ 50%」のデータを取得し、ファイルに追記しました。
#    2.93秒待機します...
#
# --- 9/1076件目を処理中: https://www.saketry.com/110503.html ---
# ○ 「ティーリング シングルモルト 46% 700mlティーリング」のデータを取得し、ファイルに追記しました。
#    3.06秒待機します...
#
# --- 10/1076件目を処理中: https://www.saketry.com/110540.html ---
# ○ 「アードレア　2009　5年　50.4%リキッドサン」のデータを取得し、ファイルに追記しました。
#    2.66秒待機します...
#
# --- 11/1076件目を処理中: https://www.saketry.com/110545.html ---
# ○ 「コーヴァル バーボン 47% 750mlコーヴァル」のデータを取得し、ファイルに追記しました。
#    3.01秒待機します...
#
# --- 12/1076件目を処理中: https://www.saketry.com/110546.html ---
# ○ 「コーヴァル フォーグレーン 47% 750mlコーヴァル」のデータを取得し、ファイルに追記しました。
#    2.55秒待機します...
#
# --- 13/1076件目を処理中: https://www.saketry.com/110547.html ---
# ○ 「コーヴァル　ミレット　40%」のデータを取得し、ファイルに追記しました。
#    2.17秒待機します...
#
# --- 14/1076件目を処理中: https://www.saketry.com/110548.html ---
# ○ 「コーヴァル　ライ　40%」のデータを取得し、ファイルに追記しました。
#    2.36秒待機します...
#
# --- 15/1076件目を処理中: https://www.saketry.com/110574.html ---
# ○ 「アムルット　シングルモルト　ミニチュア　46%アムルット・ディスティラリー」のデータを取得し、ファイルに追記しました。
#    2.20秒待機します...
#
# --- 16/1076件目を処理中: https://www.saketry.com/110575.html ---
# ○ 「アムルット　フュージョン　シングルモルト　ミニチュア　50%アムルット・ディスティラリー」のデータを取得し、ファイルに追記しました。
#    3.59秒待機します...
#
# --- 17/1076件目を処理中: https://www.saketry.com/110576.html ---
# ○ 「アムルット　ピーテッド　シングルモルト　ミニチュア　46%アムルット・ディスティラリー」のデータを取得し、ファイルに追記しました。
#    3.40秒待機します...
#
# --- 18/1076件目を処理中: https://www.saketry.com/110588.html ---
# ○ 「トマーティン　クアトロ　46%　（750ml×4本）」のデータを取得し、ファイルに追記しました。
#    3.71秒待機します...
#
# --- 19/1076件目を処理中: https://www.saketry.com/110614.html ---
# ○ 「ディーンストン　2006　8年　シェリーフィニッシュ　56.5%カスク＆シスル」のデータを取得し、ファイルに追記しました。
#    3.31秒待機します...
#
# --- 20/1076件目を処理中: https://www.saketry.com/110624.html ---
# ○ 「ウシュクベ・リザーブ　43%トゥエンティオークス」のデータを取得し、ファイルに追記しました。
#    2.54秒待機します...
#
# --- 21/1076件目を処理中: https://www.saketry.com/110708.html ---
# ○ 「ウルフバーン ノースランド 46% 700mlウルフバーン」のデータを取得し、ファイルに追記しました。
#    2.52秒待機します...
#
# --- 22/1076件目を処理中: https://www.saketry.com/110740.html ---
# ○ 「キルホーマン　サナイグ　46%」のデータを取得し、ファイルに追記しました。
#    3.25秒待機します...
#
# --- 23/1076件目を処理中: https://www.saketry.com/110810.html ---
# ○ 「トマーティン 12年 43% 700mlトマーティン」のデータを取得し、ファイルに追記しました。
#    2.23秒待機します...
#
# --- 24/1076件目を処理中: https://www.saketry.com/110833.html ---
# ○ 「ウルフバーン オーロラ 46% 700mlウルフバーン」のデータを取得し、ファイルに追記しました。
#    2.10秒待機します...
#
# --- 25/1076件目を処理中: https://www.saketry.com/110890.html ---
# ○ 「アラン ソーテルヌ・カスク・フィニッシュ 50%」のデータを取得し、ファイルに追記しました。
#    3.60秒待機します...
#
# --- 26/1076件目を処理中: https://www.saketry.com/110891.html ---
# ○ 「アラン　マクリー・ムーア　46%」のデータを取得し、ファイルに追記しました。
#    3.47秒待機します...
#
# --- 27/1076件目を処理中: https://www.saketry.com/110892.html ---
# ○ 「アラン　マクリー・ムーア　カスクストレングス　58.2%」のデータを取得し、ファイルに追記しました。
#    3.54秒待機します...
#
# --- 28/1076件目を処理中: https://www.saketry.com/110896.html ---
# ○ 「トマーティン　1995　21年　オロロソ・フィニッシュ　46%」のデータを取得し、ファイルに追記しました。
#    2.63秒待機します...
#
# --- 29/1076件目を処理中: https://www.saketry.com/110897.html ---
# ○ 「トマーティン　ク・ボカン　2005　11年　リミテッド・エディション　46%」のデータを取得し、ファイルに追記しました。
#    2.91秒待機します...
#
# --- 30/1076件目を処理中: https://www.saketry.com/110974.html ---
# ○ 「トマーティン　カスクストレングス　57.5%」のデータを取得し、ファイルに追記しました。
#    2.57秒待機します...
#
# --- 31/1076件目を処理中: https://www.saketry.com/110975.html ---
# ○ 「トマーティン　18年　46%」のデータを取得し、ファイルに追記しました。
#    3.93秒待機します...
#
# --- 32/1076件目を処理中: https://www.saketry.com/110995.html ---
# ○ 「ブレンデッド モルト スコッチ ウイスキー キメラ Cask ref:CH1-2016 46% 700mlブラックアダー」のデータを取得し、ファイルに追記しました。
#    3.27秒待機します...
#
# --- 33/1076件目を処理中: https://www.saketry.com/111007.html ---
# ○ 「ピートリーク エンバース EMB3 59%ブラックアダー」のデータを取得し、ファイルに追記しました。
#    3.93秒待機します...
#
# --- 34/1076件目を処理中: https://www.saketry.com/111020.html ---
# ○ 「キルホーマン ロッホゴルム 2017リリース 46% 700ml キルホーマン」のデータを取得し、ファイルに追記しました。
#    2.31秒待機します...
#
# --- 35/1076件目を処理中: https://www.saketry.com/111060.html ---
# ○ 「ウルフバーン モーヴェン 46% 700mlウルフバーン」のデータを取得し、ファイルに追記しました。
#    3.32秒待機します...
#
# --- 36/1076件目を処理中: https://www.saketry.com/111145.html ---
# ○ 「トマーティン 2001 16年 52.5%ザ・クーパーズ・チョイス」のデータを取得し、ファイルに追記しました。
#    2.84秒待機します...
#
# --- 37/1076件目を処理中: https://www.saketry.com/111151.html ---
# ○ 「ウシュクベ  カスク プルーフ 10L樽 50%トゥエンティオークス」のデータを取得し、ファイルに追記しました。
#    2.52秒待機します...
#
# --- 38/1076件目を処理中: https://www.saketry.com/111161.html ---
# ○ 「トマーティン ファイブ ヴァーチューズ ウッド 46% 700mlトマーティン」のデータを取得し、ファイルに追記しました。
#    2.03秒待機します...
#
# --- 39/1076件目を処理中: https://www.saketry.com/111162.html ---
# ○ 「トマーティン ファイブ ヴァーチューズ ファイア 46% 700mlトマーティン」のデータを取得し、ファイルに追記しました。
#    3.63秒待機します...
#
# --- 40/1076件目を処理中: https://www.saketry.com/111170.html ---
# ○ 「ウルフバーン Batch No.270 46%」のデータを取得し、ファイルに追記しました。
#    2.04秒待機します...
#
# --- 41/1076件目を処理中: https://www.saketry.com/111186.html ---
# ○ 「ウルフバーン キルヴァー 3 50%」のデータを取得し、ファイルに追記しました。
#    2.63秒待機します...
#
# --- 42/1076件目を処理中: https://www.saketry.com/111190.html ---
# ○ 「ベンリネス 2001 15年 46% 700mlザ・クーパーズ・チョイス」のデータを取得し、ファイルに追記しました。
#    2.77秒待機します...
#
# --- 43/1076件目を処理中: https://www.saketry.com/111198.html ---
# ○ 「ブナハーブン 2005 12年 48%クランデニー」のデータを取得し、ファイルに追記しました。
#    3.47秒待機します...
#
# --- 44/1076件目を処理中: https://www.saketry.com/111199.html ---
# ○ 「フェッターケアン 2007 10年 48%クランデニー」のデータを取得し、ファイルに追記しました。
#    3.08秒待機します...
#
# --- 45/1076件目を処理中: https://www.saketry.com/111200.html ---
# ○ 「グレンバーギー 2009 7年 48%クランデニー」のデータを取得し、ファイルに追記しました。
#    2.21秒待機します...
#
# --- 46/1076件目を処理中: https://www.saketry.com/111201.html ---
# ○ 「スペイバーン 2008 8年 48%クランデニー」のデータを取得し、ファイルに追記しました。
#    2.58秒待機します...
#
# --- 47/1076件目を処理中: https://www.saketry.com/111211.html ---
# ○ 「ポール・ジョン エディテッド 46% 700mlポール・ジョン」のデータを取得し、ファイルに追記しました。
#    3.26秒待機します...
#
# --- 48/1076件目を処理中: https://www.saketry.com/111212.html ---
# ○ 「ポール・ジョン ボールド 46% 700mlポール・ジョン」のデータを取得し、ファイルに追記しました。
#    3.60秒待機します...
#
# --- 49/1076件目を処理中: https://www.saketry.com/111213.html ---
# ○ 「ポール・ジョン クラシック 55.2% 700mlポール・ジョン」のデータを取得し、ファイルに追記しました。
#    3.26秒待機します...
#
# --- 50/1076件目を処理中: https://www.saketry.com/111214.html ---
# ○ 「ポール・ジョン ピーテッド 55.5% 700mlポール・ジョン」のデータを取得し、ファイルに追記しました。
#    2.75秒待機します...
#
# --- 51/1076件目を処理中: https://www.saketry.com/111216.html ---
# ○ 「キルホーマン 2011 6年 フレッシュ・バーボン 58% スコッチモルトセレクション」のデータを取得し、ファイルに追記しました。
#    3.19秒待機します...
#
# --- 52/1076件目を処理中: https://www.saketry.com/111219.html ---
# ○ 「トマーティン ファイブ ヴァーチューズ ウォーター 46% 700mlトマーティン」のデータを取得し、ファイルに追記しました。
#    2.41秒待機します...
#
# --- 53/1076件目を処理中: https://www.saketry.com/111220.html ---
# ○ 「トマーティン ファイブ ヴァーチューズ メタル 46% 700mlトマーティン」のデータを取得し、ファイルに追記しました。
#    2.15秒待機します...
#
# --- 54/1076件目を処理中: https://www.saketry.com/111229.html ---
# ○ 「ダルユーイン 2007 10年 48%クランデニー」のデータを取得し、ファイルに追記しました。
#    2.36秒待機します...
#
# --- 55/1076件目を処理中: https://www.saketry.com/111247.html ---
# ○ 「トマーティン 14年 ポートカスク 46% 700mlトマーティン」のデータを取得し、ファイルに追記しました。
#    3.92秒待機します...
#
# --- 56/1076件目を処理中: https://www.saketry.com/111249.html ---
# ○ 「キルホーマン マキヤーベイ グラス１脚付きセット 46.0% 700ml」のデータを取得し、ファイルに追記しました。
#    3.93秒待機します...
#
# --- 57/1076件目を処理中: https://www.saketry.com/111253.html ---
# ○ 「ウルフバーン ラングスキップ 58% 700mlウルフバーン」のデータを取得し、ファイルに追記しました。
#    3.66秒待機します...
#
# --- 58/1076件目を処理中: https://www.saketry.com/111261.html ---
# ○ 「ウルフバーン ノースランド ミニチュア 46% 50mlウルフバーン」のデータを取得し、ファイルに追記しました。
#    3.70秒待機します...
#
# --- 59/1076件目を処理中: https://www.saketry.com/111262.html ---
# ○ 「ウルフバーン モーヴェン ミニチュア 46% 50mlウルフバーン」のデータを取得し、ファイルに追記しました。
#    3.52秒待機します...
#
# --- 60/1076件目を処理中: https://www.saketry.com/111275.html ---
# ○ 「ベンリネス 1997 16年 56.5% 700mlハートブラザーズ ファイネスト・コレクション」のデータを取得し、ファイルに追記しました。
#    2.10秒待機します...
#
# --- 61/1076件目を処理中: https://www.saketry.com/111283.html ---
# ○ 「ポール・ジョン カニャ 50%ポール・ジョン」のデータを取得し、ファイルに追記しました。
#    3.76秒待機します...
#
# --- 62/1076件目を処理中: https://www.saketry.com/111293.html ---
# ○ 「フェッターケアン 2007 11年 60.1%クランデニー」のデータを取得し、ファイルに追記しました。
#    3.58秒待機します...
#
# --- 63/1076件目を処理中: https://www.saketry.com/111294.html ---
# ○ 「ブナハーブン 2007 10年 57.5%クランデニー」のデータを取得し、ファイルに追記しました。
#    2.08秒待機します...
#
# --- 64/1076件目を処理中: https://www.saketry.com/111331.html ---
# ○ 「スペイサイド　ブレンデッド・モルト 46%　ザ・スピークイージー」のデータを取得し、ファイルに追記しました。
#    2.54秒待機します...
#
# --- 65/1076件目を処理中: https://www.saketry.com/111332.html ---
# ○ 「ローランド　ブレンデッド・モルト 46%ザ・スピークイージー」のデータを取得し、ファイルに追記しました。
#    2.99秒待機します...
#
# --- 66/1076件目を処理中: https://www.saketry.com/111346.html ---
# ○ 「モートラック 2007 11年 53.0%クランデニー」のデータを取得し、ファイルに追記しました。
#    3.45秒待機します...
#
# --- 67/1076件目を処理中: https://www.saketry.com/111349.html ---
# ○ 「ウルフバーン キルヴァー 4 50.0%」のデータを取得し、ファイルに追記しました。
#    2.50秒待機します...
#
# --- 68/1076件目を処理中: https://www.saketry.com/111351.html ---
# ○ 「グレンアラヒー 12年 46% 700ml」のデータを取得し、ファイルに追記しました。
#    3.92秒待機します...
#
# --- 69/1076件目を処理中: https://www.saketry.com/111361.html ---
# ○ 「ハイランド ブレンデッド・モルト 46% 700mlザ・スピークイージー」のデータを取得し、ファイルに追記しました。
#    3.49秒待機します...
#
# --- 70/1076件目を処理中: https://www.saketry.com/111362.html ---
# ○ 「アイランズ　ブレンデッド・モルト 46%ザ・スピークイージー」のデータを取得し、ファイルに追記しました。
#    3.74秒待機します...
#
# --- 71/1076件目を処理中: https://www.saketry.com/111405.html ---
# ○ 「クレイゲラキ 2010 8年 48% 700mlクランデニー」のデータを取得し、ファイルに追記しました。
#    2.43秒待機します...
#
# --- 72/1076件目を処理中: https://www.saketry.com/111410.html ---
# ○ 「オスロスク スペイサイド デザート バニュルス フィニッシュ 58.5%ザ・クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    2.51秒待機します...
#
# --- 73/1076件目を処理中: https://www.saketry.com/111425.html ---
# ○ 「アイル オブ ジュラ 1998 20年 SMS 40周年記念 52.2%スコッチモルト販売」のデータを取得し、ファイルに追記しました。
#    3.47秒待機します...
#
# --- 74/1076件目を処理中: https://www.saketry.com/111435.html ---
# ○ 「アードモア 1998 20年 51.6%ザ・シングルモルツ・オブ・スコットランド」のデータを取得し、ファイルに追記しました。
#    2.05秒待機します...
#
# --- 75/1076件目を処理中: https://www.saketry.com/111442.html ---
# ○ 「プロメテウス 28年 リミテッド・リリース 53.0%プロメテウス」のデータを取得し、ファイルに追記しました。
#    3.81秒待機します...
#
# --- 76/1076件目を処理中: https://www.saketry.com/111443.html ---
# ○ 「1770 グラスゴー シングルモルト リリース No.2 46%」のデータを取得し、ファイルに追記しました。
#    3.40秒待機します...
#
# --- 77/1076件目を処理中: https://www.saketry.com/111444.html ---
# ○ 「リトルミル 1988 30年 シェリー・バット 51.1% 700mlハートブラザーズ レジェンズ」のデータを取得し、ファイルに追記しました。
#    3.34秒待機します...
#
# --- 78/1076件目を処理中: https://www.saketry.com/111451.html ---
# ○ 「ダルモア 2007 11年 ポートパイプ 55.1% 700mlハートブラザーズ ファイネット コレクション」のデータを取得し、ファイルに追記しました。
#    3.46秒待機します...
#
# --- 79/1076件目を処理中: https://www.saketry.com/111452.html ---
# ○ 「ダルモア 2007 11年 シェリーバット 55.6% 700mlハートブラザーズ ファイネット コレクション」のデータを取得し、ファイルに追記しました。
#    3.35秒待機します...
#
# --- 80/1076件目を処理中: https://www.saketry.com/111453.html ---
# ○ 「ダルモア 2007 11年 57.5% 700mlハートブラザーズ ファイネット コレクション」のデータを取得し、ファイルに追記しました。
#    3.73秒待機します...
#
# --- 81/1076件目を処理中: https://www.saketry.com/111454.html ---
# ○ 「レダイグ 2005 11年 シェリーバット 56.5%ハートブラザーズ ファイネスト コレクション」のデータを取得し、ファイルに追記しました。
#    3.79秒待機します...
#
# --- 82/1076件目を処理中: https://www.saketry.com/111455.html ---
# ○ 「グレントファース 1996 22年 50.2% 700mlハートブラザーズ ファイネット コレクション」のデータを取得し、ファイルに追記しました。
#    3.42秒待機します...
#
# --- 83/1076件目を処理中: https://www.saketry.com/111462.html ---
# ○ 「カンバス 1990 28年 トリプルカスク 48.3%ザ・グレーンマン」のデータを取得し、ファイルに追記しました。
#    2.37秒待機します...
#
# --- 84/1076件目を処理中: https://www.saketry.com/111463.html ---
# ○ 「ガーヴァン 1993 25年 ポート・フィニッシュ 55.5% 700mlザ・グレーンマン」のデータを取得し、ファイルに追記しました。
#    3.31秒待機します...
#
# --- 85/1076件目を処理中: https://www.saketry.com/111477.html ---
# ○ 「シングルモルト駒ケ岳 リミテッド・エディション 2019 48%」のデータを取得し、ファイルに追記しました。
#    2.74秒待機します...
#
# --- 86/1076件目を処理中: https://www.saketry.com/111484.html ---
# ○ 「宗像教授ラベル・スペイサイドリージョン 1979 38年 42.8％」のデータを取得し、ファイルに追記しました。
#    3.99秒待機します...
#
# --- 87/1076件目を処理中: https://www.saketry.com/111488.html ---
# ○ 「アードモア 1999 20年 ジョイント ウィズ ドランケンマスター 53.5%ディスティラリーズ・コレクション」のデータを取得し、ファイルに追記しました。
#    2.08秒待機します...
#
# --- 88/1076件目を処理中: https://www.saketry.com/111489.html ---
# ○ 「ブナハーブン ヘヴィリーピーテッド  ハニースモーク 56.6%ザ・クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    2.83秒待機します...
#
# --- 89/1076件目を処理中: https://www.saketry.com/111490.html ---
# ○ 「シークレット オークニー 2009 10年 58.0%ザ・クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    3.95秒待機します...
#
# --- 90/1076件目を処理中: https://www.saketry.com/111491.html ---
# ○ 「グレンギリー 2011 8年 マデイラ・フィニッシュ 53.5%ザ・クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    2.50秒待機します...
#
# --- 91/1076件目を処理中: https://www.saketry.com/111492.html ---
# ○ 「オールドロスデュー 1994 25年 バーボン・フィニッシュ 48.5%ザ・クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    4.00秒待機します...
#
# --- 92/1076件目を処理中: https://www.saketry.com/111493.html ---
# ○ 「キルノートン リオハ・カスク 54.0%ザ・クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    3.03秒待機します...
#
# --- 93/1076件目を処理中: https://www.saketry.com/111494.html ---
# ○ 「キャメロンブリッジ 1984 35年 44.5%ザ・クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    3.58秒待機します...
#
# --- 94/1076件目を処理中: https://www.saketry.com/111497.html ---
# ○ 「ウルフバーン スコッチモルト販売 40周年記念ボトル　50％ウルフバーン」のデータを取得し、ファイルに追記しました。
#    3.95秒待機します...
#
# --- 95/1076件目を処理中: https://www.saketry.com/111499.html ---
# ○ 「バルメナック 2008 11年 シェリーバット 56.5% 700mlハートブラザーズ ファイネット コレクション」のデータを取得し、ファイルに追記しました。
#    3.27秒待機します...
#
# --- 96/1076件目を処理中: https://www.saketry.com/111500.html ---
# ○ 「プルトニー 2006 13年 シェリーバット 53.6% 700mlハートブラザーズ ファイネスト・コレクション」のデータを取得し、ファイルに追記しました。
#    3.11秒待機します...
#
# --- 97/1076件目を処理中: https://www.saketry.com/111502.html ---
# ○ 「キングスバーンズ ドリーム・トゥ・ドラム シングルモルト 46％ 700mlウィームス」のデータを取得し、ファイルに追記しました。
#    3.62秒待機します...
#
# --- 98/1076件目を処理中: https://www.saketry.com/111504.html ---
# ○ 「グレンアラヒー 1990 29年 オロロソシェリーパンチョン 58.2％グレンアラヒー」のデータを取得し、ファイルに追記しました。
#    2.15秒待機します...
#
# --- 99/1076件目を処理中: https://www.saketry.com/111505.html ---
# ○ 「アードベッグ 2005 13年 バッチ17 48.4%ブティックウイスキー」のデータを取得し、ファイルに追記しました。
#    2.27秒待機します...
#
# --- 100/1076件目を処理中: https://www.saketry.com/111506.html ---
# ○ 「アラン 22年 バッチ8 48.4%ブティックウイスキー」のデータを取得し、ファイルに追記しました。
#    3.92秒待機します...
#
# --- 101/1076件目を処理中: https://www.saketry.com/111507.html ---
# ○ 「フェッターケアン 21年 バッチ3 48.6%ブティックウイスキー」のデータを取得し、ファイルに追記しました。
#    2.28秒待機します...
#
# --- 102/1076件目を処理中: https://www.saketry.com/111508.html ---
# ○ 「ブルックラディ 13年 バッチ11 47.6%ブティックウイスキー」のデータを取得し、ファイルに追記しました。
#    3.38秒待機します...
#
# --- 103/1076件目を処理中: https://www.saketry.com/111509.html ---
# ○ 「アラン マルサラカスク・フィニッシュ 2018 リミテッドエディション 50%アラン」のデータを取得し、ファイルに追記しました。
#    2.67秒待機します...
#
# --- 104/1076件目を処理中: https://www.saketry.com/111510.html ---
# ○ 「アラン マスター・オブ・ディスティリング２ 12年 51.8%アラン」のデータを取得し、ファイルに追記しました。
#    3.30秒待機します...
#
# --- 105/1076件目を処理中: https://www.saketry.com/111511.html ---
# ○ 「アラン コート・ロティカスク・フィニッシュ 2019 リミテッドエディション 50%アラン」のデータを取得し、ファイルに追記しました。
#    2.85秒待機します...
#
# --- 106/1076件目を処理中: https://www.saketry.com/111513.html ---
# ○ 「ティーリング シングルポットスティル 46％ 700ml」のデータを取得し、ファイルに追記しました。
#    2.07秒待機します...
#
# --- 107/1076件目を処理中: https://www.saketry.com/111514.html ---
# ○ 「コンパスボックス オーク・クロス 43％コンパスボックス」のデータを取得し、ファイルに追記しました。
#    3.72秒待機します...
#
# --- 108/1076件目を処理中: https://www.saketry.com/111515.html ---
# ○ 「コンパスボックス ザ・ストーリー・オブ・ザ・スパニアード 43%  バッチナンバー 2018-Bコンパスボックス」のデータを取得し、ファイルに追記しました。
#    3.33秒待機します...
#
# --- 109/1076件目を処理中: https://www.saketry.com/111522.html ---
# ○ 「ブナハーブン 1987 31年 "Raisin D'Etre" 44.7%ウィームス」のデータを取得し、ファイルに追記しました。
#    2.01秒待機します...
#
# --- 110/1076件目を処理中: https://www.saketry.com/111524.html ---
# ○ 「グレングラント 1995 23年 "Summer Sipping" 46.0%ウィームス」のデータを取得し、ファイルに追記しました。
#    3.65秒待機します...
#
# --- 111/1076件目を処理中: https://www.saketry.com/111530.html ---
# ○ 「スパイスキング ブレンデッドモルト 46%ウィームス」のデータを取得し、ファイルに追記しました。
#    3.14秒待機します...
#
# --- 112/1076件目を処理中: https://www.saketry.com/111531.html ---
# ○ 「長濱蒸溜所 ニューメイク 59% 500ml長濱蒸溜所」のデータを取得し、ファイルに追記しました。
#    3.38秒待機します...
#
# --- 113/1076件目を処理中: https://www.saketry.com/111532.html ---
# ○ 「ピート・チムニー ブレンデッドモルト 46% 700mlウィームス」のデータを取得し、ファイルに追記しました。
#    2.97秒待機します...
#
# --- 114/1076件目を処理中: https://www.saketry.com/111533.html ---
# ○ 「ブレアソール 1991 24年 Nuts Pears 46%ウィームス」のデータを取得し、ファイルに追記しました。
#    3.42秒待機します...
#
# --- 115/1076件目を処理中: https://www.saketry.com/111534.html ---
# ○ 「ブナハーブン 1991 27年 Toasted Brioche 46%ウィームス」のデータを取得し、ファイルに追記しました。
#    3.24秒待機します...
#
# --- 116/1076件目を処理中: https://www.saketry.com/111535.html ---
# ○ 「ブナハーブン 1988 30年 Antique Pomander 46%ウィームス」のデータを取得し、ファイルに追記しました。
#    2.07秒待機します...
#
# --- 117/1076件目を処理中: https://www.saketry.com/111537.html ---
# ○ 「ウルフバーン キルヴァー 5 50%キルヴァー・シリーズ」のデータを取得し、ファイルに追記しました。
#    2.71秒待機します...
#
# --- 118/1076件目を処理中: https://www.saketry.com/111546.html ---
# ○ 「キン肉マン正義超人ラベル・ブレンデッドモルト2001 17年 46.5%」のデータを取得し、ファイルに追記しました。
#    2.73秒待機します...
#
# --- 119/1076件目を処理中: https://www.saketry.com/111550.html ---
# ○ 「おやすみカラスまた来てね。ラベル・バーンサイド 1996 22年 50.4％」のデータを取得し、ファイルに追記しました。
#    3.13秒待機します...
#
# --- 120/1076件目を処理中: https://www.saketry.com/111562.html ---
# ○ 「アランバレルリザーブ 43% 700ml」のデータを取得し、ファイルに追記しました。
#    3.35秒待機します...
#
# --- 121/1076件目を処理中: https://www.saketry.com/111563.html ---
# ○ 「アランシェリーカスク 55.8% 700ml」のデータを取得し、ファイルに追記しました。
#    2.34秒待機します...
#
# --- 122/1076件目を処理中: https://www.saketry.com/111564.html ---
# ○ 「アランクウォーターカスク 56.2% 700ml」のデータを取得し、ファイルに追記しました。
#    3.64秒待機します...
#
# --- 123/1076件目を処理中: https://www.saketry.com/111566.html ---
# ○ 「アラン 18年 46%アラン」のデータを取得し、ファイルに追記しました。
#    2.28秒待機します...
#
# --- 124/1076件目を処理中: https://www.saketry.com/111569.html ---
# ○ 「リンクウッド 2010 9年 トーニーポートカスク 56%クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    2.77秒待機します...
#
# --- 125/1076件目を処理中: https://www.saketry.com/111571.html ---
# ○ 「オスロスク スペイサイドデザート モスカテルフィニッシュ 58.5%クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    2.08秒待機します...
#
# --- 126/1076件目を処理中: https://www.saketry.com/111573.html ---
# ○ 「インペリアル 1995 48.2%シングルモルツオブスコットランド」のデータを取得し、ファイルに追記しました。
#    3.35秒待機します...
#
# --- 127/1076件目を処理中: https://www.saketry.com/111583.html ---
# ○ 「ウィリアムソン ラフロイグ 2012 7年 55.1%ザ・モルトマン」のデータを取得し、ファイルに追記しました。
#    2.96秒待機します...
#
# --- 128/1076件目を処理中: https://www.saketry.com/111584.html ---
# ○ 「ベンネヴィス 1997 22年 52.0%ザ・モルトマン」のデータを取得し、ファイルに追記しました。
#    2.73秒待機します...
#
# --- 129/1076件目を処理中: https://www.saketry.com/111585.html ---
# ○ 「ヴァイタルスパーク 2013 5年 54.9%メドウサイド」のデータを取得し、ファイルに追記しました。
#    3.61秒待機します...
#
# --- 130/1076件目を処理中: https://www.saketry.com/111586.html ---
# ○ 「レダイグ 2007 12年 52.7%ザ・モルトマン」のデータを取得し、ファイルに追記しました。
#    2.81秒待機します...
#
# --- 131/1076件目を処理中: https://www.saketry.com/111587.html ---
# ○ 「リンクウッド 2007 11年 52.1%ザ・モルトマン」のデータを取得し、ファイルに追記しました。
#    2.99秒待機します...
#
# --- 132/1076件目を処理中: https://www.saketry.com/111588.html ---
# ○ 「エクスカリバー 1972 45年 42.2%メドウサイド」のデータを取得し、ファイルに追記しました。
#    3.32秒待機します...
#
# --- 133/1076件目を処理中: https://www.saketry.com/111589.html ---
# ○ 「ベンネヴィス 2005 14年 53.9%ザ・モルトマン」のデータを取得し、ファイルに追記しました。
#    4.00秒待機します...
#
# --- 134/1076件目を処理中: https://www.saketry.com/111590.html ---
# ○ 「シークレットスペイサイド 2006 12年 53.9%ザ・モルトマン」のデータを取得し、ファイルに追記しました。
#    3.53秒待機します...
#
# --- 135/1076件目を処理中: https://www.saketry.com/111594.html ---
# ○ 「サラリーマン金太郎ラベル・シークレットスペイサイドモルト1994」のデータを取得し、ファイルに追記しました。
#    3.24秒待機します...
#
# --- 136/1076件目を処理中: https://www.saketry.com/111596.html ---
# ○ 「ワンダーカクテル シークレット・アイラ 2013 5年 ポートウッド&ワンダーカクテルvol.1セット」のデータを取得し、ファイルに追記しました。
#    2.16秒待機します...
#
# --- 137/1076件目を処理中: https://www.saketry.com/111599.html ---
# ○ 「インチマリン 2009 9年 57.2%」のデータを取得し、ファイルに追記しました。
#    3.88秒待機します...
#
# --- 138/1076件目を処理中: https://www.saketry.com/111609.html ---
# ○ 「カリラ 2011 8年  59.4%クランデニー」のデータを取得し、ファイルに追記しました。
#    2.07秒待機します...
#
# --- 139/1076件目を処理中: https://www.saketry.com/111611.html ---
# ○ 「シークレットオークニー 2009 10年 57.5%クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    2.53秒待機します...
#
# --- 140/1076件目を処理中: https://www.saketry.com/111612.html ---
# ○ 「ウィリアムソン 2005 14年 マスカットフィニッシュ 54.0%ザ・クーパーズ・チョイス」のデータを取得し、ファイルに追記しました。
#    3.05秒待機します...
#
# --- 141/1076件目を処理中: https://www.saketry.com/111613.html ---
# ○ 「グレンアラヒー 2011 8年 モスカテルフィニッシュ 59%クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    2.32秒待機します...
#
# --- 142/1076件目を処理中: https://www.saketry.com/111614.html ---
# ○ 「グレンロセス 2007 12年 カディラック フィニッシュ 56.3%クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    2.30秒待機します...
#
# --- 143/1076件目を処理中: https://www.saketry.com/111615.html ---
# ○ 「ストラスクライド 1993 26年 52.5%クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    2.94秒待機します...
#
# --- 144/1076件目を処理中: https://www.saketry.com/111616.html ---
# ○ 「ポートダンダス 1999 20年 バーボンフィニッシュクーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    3.05秒待機します...
#
# --- 145/1076件目を処理中: https://www.saketry.com/111617.html ---
# ○ 「ロイヤルブラックラ 2010 9年 46% 700mlハートブラザーズ ファイネット コレクション」のデータを取得し、ファイルに追記しました。
#    2.50秒待機します...
#
# --- 146/1076件目を処理中: https://www.saketry.com/111618.html ---
# ○ 「アベラワー 2010 9年 46% 700mlハートブラザーズ ファイネット コレクション」のデータを取得し、ファイルに追記しました。
#    3.23秒待機します...
#
# --- 147/1076件目を処理中: https://www.saketry.com/111619.html ---
# ○ 「グレンバーギー 2010 9年 46% 700mlハートブラザーズ ファイネット コレクション」のデータを取得し、ファイルに追記しました。
#    2.44秒待機します...
#
# --- 148/1076件目を処理中: https://www.saketry.com/111620.html ---
# ○ 「ティーニニック 2007 11年 58.1% 700mlハートブラザーズ ファイネット コレクション」のデータを取得し、ファイルに追記しました。
#    2.74秒待機します...
#
# --- 149/1076件目を処理中: https://www.saketry.com/111621.html ---
# ○ 「タリバーディン 2005 13年 53.7% 700mlハートブラザーズ ファイネット コレクション」のデータを取得し、ファイルに追記しました。
#    2.32秒待機します...
#
# --- 150/1076件目を処理中: https://www.saketry.com/111622.html ---
# ○ 「モートラック 1991 24年 シェリーバット 51.6% 700mlハートブラザーズ ファイネット コレクション」のデータを取得し、ファイルに追記しました。
#    4.00秒待機します...
#
# --- 151/1076件目を処理中: https://www.saketry.com/111623.html ---
# ○ 「リンクウッド 1990 26年 シェリーバット 47.3% 700mlハートブラザーズ ファイネット コレクション」のデータを取得し、ファイルに追記しました。
#    3.77秒待機します...
#
# --- 152/1076件目を処理中: https://www.saketry.com/111624.html ---
# ○ 「ベンネヴィス 1999 20年 バーボンホグズヘッド 48.7% 700mlモルトマン」のデータを取得し、ファイルに追記しました。
#    3.99秒待機します...
#
# --- 153/1076件目を処理中: https://www.saketry.com/111626.html ---
# ○ 「アードモア 2008 10年 シェリーバット 52.9% 700mlモルトマン」のデータを取得し、ファイルに追記しました。
#    3.99秒待機します...
#
# --- 154/1076件目を処理中: https://www.saketry.com/111632.html ---
# ○ 「シティーハンター ラベル グレンファークラス2010 9年 60.4%漫画ラベルシリーズ」のデータを取得し、ファイルに追記しました。
#    2.80秒待機します...
#
# --- 155/1076件目を処理中: https://www.saketry.com/111633.html ---
# ○ 「アードモア 2009 9年 56%Whisky mew」のデータを取得し、ファイルに追記しました。
#    2.55秒待機します...
#
# --- 156/1076件目を処理中: https://www.saketry.com/111634.html ---
# ○ 「ウシュクベ デラックス 43% 750mlウシュクベ」のデータを取得し、ファイルに追記しました。
#    2.87秒待機します...
#
# --- 157/1076件目を処理中: https://www.saketry.com/111636.html ---
# ○ 「ウルフバーン ヘルプ・フォー・ヒーローズ 46%ウルフバーン」のデータを取得し、ファイルに追記しました。
#    2.75秒待機します...
#
# --- 158/1076件目を処理中: https://www.saketry.com/111639.html ---
# ○ 「シングルモルト駒ヶ岳 屋久島エージング Bottled in 2020駒ヶ岳」のデータを取得し、ファイルに追記しました。
#    3.07秒待機します...
#
# --- 159/1076件目を処理中: https://www.saketry.com/111643.html ---
# ○ 「グレンロセス ”オールド スコッツ ベーカリー” 22年 46% 700mlウィームス」のデータを取得し、ファイルに追記しました。
#    2.30秒待機します...
#
# --- 160/1076件目を処理中: https://www.saketry.com/111644.html ---
# ○ 「ボウモア "アース ウィンド ファイヤ!" 28年 46% 700mlウィームス」のデータを取得し、ファイルに追記しました。
#    2.72秒待機します...
#
# --- 161/1076件目を処理中: https://www.saketry.com/111646.html ---
# ○ 「サマー ガーランズ リンクウッド 21年 46% 700mlウィームス」のデータを取得し、ファイルに追記しました。
#    3.07秒待機します...
#
# --- 162/1076件目を処理中: https://www.saketry.com/111649.html ---
# ○ 「ザ ハイブ バッチストレングス2 ブレンデットモルト NCF 55.5% 700mlウィームス」のデータを取得し、ファイルに追記しました。
#    2.10秒待機します...
#
# --- 163/1076件目を処理中: https://www.saketry.com/111651.html ---
# ○ 「ピート チムニー バッチストレングス2  ブレンデットモルト NCF 57% 700mlウィームス」のデータを取得し、ファイルに追記しました。
#    3.06秒待機します...
#
# --- 164/1076件目を処理中: https://www.saketry.com/111652.html ---
# ○ 「ロード エルコー NAS 40% 700mlウィームス」のデータを取得し、ファイルに追記しました。
#    3.16秒待機します...
#
# --- 165/1076件目を処理中: https://www.saketry.com/111653.html ---
# ○ 「バニラ バースト ブレンデットモルト 46% 700mlウィームス」のデータを取得し、ファイルに追記しました。
#    2.86秒待機します...
#
# --- 166/1076件目を処理中: https://www.saketry.com/111654.html ---
# ○ 「フレーミング フィースト ブレンデットモルト 46% 700mlウィームス」のデータを取得し、ファイルに追記しました。
#    2.73秒待機します...
#
# --- 167/1076件目を処理中: https://www.saketry.com/111655.html ---
# ○ 「ブルーミング ゴース ブレンデットモルト 46% 700mlウィームス」のデータを取得し、ファイルに追記しました。
#    2.98秒待機します...
#
# --- 168/1076件目を処理中: https://www.saketry.com/111658.html ---
# ○ 「ゴーストシリーズ あかし カベルネフランカスク 61%小学館」のデータを取得し、ファイルに追記しました。
#    2.41秒待機します...
#
# --- 169/1076件目を処理中: https://www.saketry.com/111659.html ---
# ○ 「総務部総務課 山口六平太 グレンマレイ 2008 57.8%小学館」のデータを取得し、ファイルに追記しました。
#    2.67秒待機します...
#
# --- 170/1076件目を処理中: https://www.saketry.com/111660.html ---
# ○ 「シングルモルト津貫 ザ ファースト 59%本坊酒造」のデータを取得し、ファイルに追記しました。
#    2.43秒待機します...
#
# --- 171/1076件目を処理中: https://www.saketry.com/111666.html ---
# ○ 「テイスティング・セットVol. 12スコッチモルト販売」のデータを取得し、ファイルに追記しました。
#    3.79秒待機します...
#
# --- 172/1076件目を処理中: https://www.saketry.com/111679.html ---
# ○ 「ハートブラザーズ テイスティング・セット 20ml x 5ハートブラザーズ」のデータを取得し、ファイルに追記しました。
#    3.22秒待機します...
#
# --- 173/1076件目を処理中: https://www.saketry.com/111767.html ---
# ○ 「笑ゥせぇるすまん ラベル インペリアル1995 54.1％WHISKY MEW」のデータを取得し、ファイルに追記しました。
#    2.90秒待機します...
#
# --- 174/1076件目を処理中: https://www.saketry.com/111842.html ---
# ○ 「アイラ ピーテッド ブレンデット モルト 2009 56.4% デビルマンエリクサー・ディスティラーズ」のデータを取得し、ファイルに追記しました。
#    3.45秒待機します...
#
# --- 175/1076件目を処理中: https://www.saketry.com/111843.html ---
# ○ 「レダイグ 2005 55.1% デビルマンエリクサー・ディスティラーズ」のデータを取得し、ファイルに追記しました。
#    3.56秒待機します...
#
# --- 176/1076件目を処理中: https://www.saketry.com/111844.html ---
# ○ 「アードモア 2009 55.5% デビルマンエリクサー・ディスティラーズ」のデータを取得し、ファイルに追記しました。
#    2.79秒待機します...
#
# --- 177/1076件目を処理中: https://www.saketry.com/111847.html ---
# ○ 「オスロスク10年 62.5％ 700mlクランデニー」のデータを取得し、ファイルに追記しました。
#    3.65秒待機します...
#
# --- 178/1076件目を処理中: https://www.saketry.com/111849.html ---
# ○ 「カリラ スモークアンドシェリー オロロソフィニッシュ 57％ 700mlクーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    3.31秒待機します...
#
# --- 179/1076件目を処理中: https://www.saketry.com/111851.html ---
# ○ 「ダルムナック ピーチパフェ マディラフィニッシュ 61％クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    3.25秒待機します...
#
# --- 180/1076件目を処理中: https://www.saketry.com/111852.html ---
# ○ 「スペイバーン 2009 10年 カルバドスフィニッシュ 53%クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    3.55秒待機します...
#
# --- 181/1076件目を処理中: https://www.saketry.com/111857.html ---
# ○ 「インバーゴードン22年 シングルグレーンスコッチウイスキー 52.8%キャンベルメイヤー」のデータを取得し、ファイルに追記しました。
#    3.76秒待機します...
#
# --- 182/1076件目を処理中: https://www.saketry.com/111858.html ---
# ○ 「ストラスアイラ 2008 11年 55.6% 700mlハートブラザーズ ファイネット コレクション」のデータを取得し、ファイルに追記しました。
#    3.94秒待機します...
#
# --- 183/1076件目を処理中: https://www.saketry.com/111860.html ---
# ○ 「ベンリアック 2008 11年 シェリーカスク 55.7% 700mlハートブラザーズ ファイネット コレクション」のデータを取得し、ファイルに追記しました。
#    3.93秒待機します...
#
# --- 184/1076件目を処理中: https://www.saketry.com/111861.html ---
# ○ 「グレンマレイ 2008 11年 バーガンディカスク フィニッシュ 52.1% 700mlハートブラザーズ ファイネスト コレクション」のデータを取得し、ファイルに追記しました。
#    3.39秒待機します...
#
# --- 185/1076件目を処理中: https://www.saketry.com/111862.html ---
# ○ 「コッツウォルズ シングルモルトウイスキーミニ 46% 50mlコッツウォルズ」のデータを取得し、ファイルに追記しました。
#    2.31秒待機します...
#
# --- 186/1076件目を処理中: https://www.saketry.com/111865.html ---
# ○ 「コッツウォルズ シングルモルトウイスキー 46% 700mlコッツウォルズ」のデータを取得し、ファイルに追記しました。
#    2.53秒待機します...
#
# --- 187/1076件目を処理中: https://www.saketry.com/111872.html ---
# ○ 「テイスティング・セットVol. 15スコッチモルトセレクション」のデータを取得し、ファイルに追記しました。
#    2.94秒待機します...
#
# --- 188/1076件目を処理中: https://www.saketry.com/111874.html ---
# ○ 「グレンロセス 2007 10年 53.2% 700mlディスティラリーコレクション」のデータを取得し、ファイルに追記しました。
#    2.38秒待機します...
#
# --- 189/1076件目を処理中: https://www.saketry.com/111875.html ---
# ○ 「ピート・チムニー ブレンデッドモルト 46% 750mlウィームス」のデータを取得し、ファイルに追記しました。
#    2.93秒待機します...
#
# --- 190/1076件目を処理中: https://www.saketry.com/111876.html ---
# ○ 「ザ ハイブ ブレンデットモルト 46% 750mlウィームス」のデータを取得し、ファイルに追記しました。
#    3.49秒待機します...
#
# --- 191/1076件目を処理中: https://www.saketry.com/111877.html ---
# ○ 「スパイスキング ブレンデッドモルト 46% 750mlウィームス」のデータを取得し、ファイルに追記しました。
#    3.98秒待機します...
#
# --- 192/1076件目を処理中: https://www.saketry.com/111879.html ---
# ○ 「富士山麓シグニチャーブレンド 50% 700ml」のデータを取得し、ファイルに追記しました。
#    3.45秒待機します...
#
# --- 193/1076件目を処理中: https://www.saketry.com/111880.html ---
# ○ 「キリンウイスキー 陸 50% 500ml陸」のデータを取得し、ファイルに追記しました。
#    3.25秒待機します...
#
# --- 194/1076件目を処理中: https://www.saketry.com/111881.html ---
# ○ 「アマハガンワールドモルト エディション1 47％AMAHAGAN World Malt」のデータを取得し、ファイルに追記しました。
#    2.93秒待機します...
#
# --- 195/1076件目を処理中: https://www.saketry.com/111882.html ---
# ○ 「アマハガンワールドモルトエディション No2  レッドワインウッドフィニッシュ 47％AMAHAGAN World Malt Edition」のデータを取得し、ファイルに追記しました。
#    3.77秒待機します...
#
# --- 196/1076件目を処理中: https://www.saketry.com/111883.html ---
# ○ 「アマハガンワールドモルトエディション No3 ミズナラウッドフィニッシュ47%AMAHAGAN World Malt」のデータを取得し、ファイルに追記しました。
#    3.97秒待機します...
#
# --- 197/1076件目を処理中: https://www.saketry.com/111884.html ---
# ○ 「アマハガンワールドモルトエディション 山桜ウッドフィニッシュ 47％ 700mlAMAHAGAN World Malt Edition」のデータを取得し、ファイルに追記しました。
#    2.51秒待機します...
#
# --- 198/1076件目を処理中: https://www.saketry.com/111889.html ---
# ○ 「ウエストポート 1997 21年 50.5％ 700mlモルトウイスキーカンパニー」のデータを取得し、ファイルに追記しました。
#    2.96秒待機します...
#
# --- 199/1076件目を処理中: https://www.saketry.com/111890.html ---
# ○ 「クレイゲラヒ 2006 12年 PXシェリーカスクフィニッシュ 53％ 700mlモルトウイスキーカンパニー」のデータを取得し、ファイルに追記しました。
#    2.26秒待機します...
#
# --- 200/1076件目を処理中: https://www.saketry.com/111891.html ---
# ○ 「グレンロセス 2007 11年 オロロソシェリーカスクフィニッシュ 62.2％ 700mlモルトウイスキーカンパニー」のデータを取得し、ファイルに追記しました。
#    2.44秒待機します...
#
# --- 201/1076件目を処理中: https://www.saketry.com/111892.html ---
# ○ 「テイスティング・セットVol. 16スコッチモルトセレクション」のデータを取得し、ファイルに追記しました。
#    2.57秒待機します...
#
# --- 202/1076件目を処理中: https://www.saketry.com/111907.html ---
# ○ 「シークレットスペイサイド 1994 26年 50.3% 700mlウイスキペディア」のデータを取得し、ファイルに追記しました。
#    2.92秒待機します...
#
# --- 203/1076件目を処理中: https://www.saketry.com/111908.html ---
# ○ 「シークレットハイランド 2010 9年  52.6% 700mlディスティラリーズ・コレクション」のデータを取得し、ファイルに追記しました。
#    2.30秒待機します...
#
# --- 204/1076件目を処理中: https://www.saketry.com/111912.html ---
# ○ 「マルスモルテージ越百 モルトセレクション 43％ 700ml」のデータを取得し、ファイルに追記しました。
#    3.42秒待機します...
#
# --- 205/1076件目を処理中: https://www.saketry.com/111913.html ---
# ○ 「ブルー ジャイアント シュプリーム・ラベル トーモア1995 24年 47.2% 700mlウイスキーミュウ」のデータを取得し、ファイルに追記しました。
#    2.07秒待機します...
#
# --- 206/1076件目を処理中: https://www.saketry.com/111914.html ---
# ○ 「北斗の拳 ケンシロウラベル ティーニニック 1999 20年 47.1% 700ml漫画ラベルシリーズ」のデータを取得し、ファイルに追記しました。
#    2.26秒待機します...
#
# --- 207/1076件目を処理中: https://www.saketry.com/111915.html ---
# ○ 「ラオウラベル グレンロファース 1997 22年 51.8% 700ml漫画ラベルシリーズ」のデータを取得し、ファイルに追記しました。
#    2.45秒待機します...
#
# --- 208/1076件目を処理中: https://www.saketry.com/111917.html ---
# ○ 「マルスウイスキー 浅葱斑 48％ 700ml」のデータを取得し、ファイルに追記しました。
#    3.91秒待機します...
#
# --- 209/1076件目を処理中: https://www.saketry.com/111918.html ---
# ○ 「赤穂浪士シリーズ アードモア 1998 22年 700ml 49.7%酒育の会」のデータを取得し、ファイルに追記しました。
#    2.26秒待機します...
#
# --- 210/1076件目を処理中: https://www.saketry.com/111919.html ---
# ○ 「赤穂浪士シリーズ グレンエルギン 1998 21年 700ml 47.9%酒育の会」のデータを取得し、ファイルに追記しました。
#    2.70秒待機します...
#
# --- 211/1076件目を処理中: https://www.saketry.com/111920.html ---
# ○ 「ムーングロウ リミテッドエディション 2020 43％ 700ml」のデータを取得し、ファイルに追記しました。
#    3.55秒待機します...
#
# --- 212/1076件目を処理中: https://www.saketry.com/111922.html ---
# ○ 「レダイグ 2005 13年 シェリーカスク  57.4% 700mlザ・ウイスキー・エクスチェンジ」のデータを取得し、ファイルに追記しました。
#    2.88秒待機します...
#
# --- 213/1076件目を処理中: https://www.saketry.com/111924.html ---
# ○ 「赤穂浪士シリーズ シークレットオークニー 2000 17年 51.6%酒育の会」のデータを取得し、ファイルに追記しました。
#    3.36秒待機します...
#
# --- 214/1076件目を処理中: https://www.saketry.com/111926.html ---
# ○ 「ベルセルク ガッツラベル シークレットスペイサイド1993 26年 47.7％ 700ml漫画ラベルシリーズ」のデータを取得し、ファイルに追記しました。
#    2.19秒待機します...
#
# --- 215/1076件目を処理中: https://www.saketry.com/111927.html ---
# ○ 「ベルセルク ガッツラベル ベン・ネヴィス1996 23年 44.1% 700ml漫画ラベルシリーズ」のデータを取得し、ファイルに追記しました。
#    2.18秒待機します...
#
# --- 216/1076件目を処理中: https://www.saketry.com/111929.html ---
# ○ 「グレンマレイ 2007 52.1% 700mlザ・テイスター」のデータを取得し、ファイルに追記しました。
#    3.66秒待機します...
#
# --- 217/1076件目を処理中: https://www.saketry.com/111930.html ---
# ○ 「酒育の会 テイスティングセット 赤穂浪士ウイスキーエージェンシー」のデータを取得し、ファイルに追記しました。
#    2.76秒待機します...
#
# --- 218/1076件目を処理中: https://www.saketry.com/111935.html ---
# ○ 「アードモア EX-ラフロイグカスク 2008 11年 57.6% 700mlディスティラリーズ・コレクション」のデータを取得し、ファイルに追記しました。
#    3.89秒待機します...
#
# --- 219/1076件目を処理中: https://www.saketry.com/111937.html ---
# ○ 「テイスティング・セットVol. 18スコッチモルトセレクション」のデータを取得し、ファイルに追記しました。
#    3.01秒待機します...
#
# --- 220/1076件目を処理中: https://www.saketry.com/111938.html ---
# ○ 「キングダム 楊端和と山の民ラベル シークレット スペイサイド 1991 28年 44.9％ 700ml漫画ラベルシリーズ」のデータを取得し、ファイルに追記しました。
#    2.21秒待機します...
#
# --- 221/1076件目を処理中: https://www.saketry.com/111939.html ---
# ○ 「キングダム秦国の武将ラベル グレンロセス 2007 12年 51.1％ 700ml漫画ラベルシリーズ」のデータを取得し、ファイルに追記しました。
#    3.79秒待機します...
#
# --- 222/1076件目を処理中: https://www.saketry.com/111940.html ---
# ○ 「東京ラブストーリーラベル リンクウッド 2007 12年 55.1% 700ml漫画ラベルシリーズ」のデータを取得し、ファイルに追記しました。
#    2.34秒待機します...
#
# --- 223/1076件目を処理中: https://www.saketry.com/111941.html ---
# ○ 「イチローズモルト モルト＆グレーン ジャパニーズ ブレンデッド ウイスキー リミテッド エディション2020 48.5% 700mlイチローズモルト」のデータを取得し、ファイルに追記しました。
#    3.00秒待機します...
#
# --- 224/1076件目を処理中: https://www.saketry.com/111950.html ---
# ○ 「アイリッシュマン シングルモルト 40% 700ml」のデータを取得し、ファイルに追記しました。
#    3.99秒待機します...
#
# --- 225/1076件目を処理中: https://www.saketry.com/111951.html ---
# ○ 「カバラン ディスティラリーセレクト 40％ 700ml」のデータを取得し、ファイルに追記しました。
#    3.60秒待機します...
#
# --- 226/1076件目を処理中: https://www.saketry.com/111952.html ---
# ○ 「カバラン コンサートマスター シェリーフィニッシュ 40％ 700ml」のデータを取得し、ファイルに追記しました。
#    3.46秒待機します...
#
# --- 227/1076件目を処理中: https://www.saketry.com/111956.html ---
# ○ 「グレンフィディック12年 スペシャルリザーブ 40％ 700ml」のデータを取得し、ファイルに追記しました。
#    3.54秒待機します...
#
# --- 228/1076件目を処理中: https://www.saketry.com/111959.html ---
# ○ 「ザ・マッカラン 12年 シェリーオーク 40% 700mlザ・マッカラン」のデータを取得し、ファイルに追記しました。
#    2.33秒待機します...
#
# --- 229/1076件目を処理中: https://www.saketry.com/111960.html ---
# ○ 「グレンリベット 12年 40% 700ml」のデータを取得し、ファイルに追記しました。
#    2.08秒待機します...
#
# --- 230/1076件目を処理中: https://www.saketry.com/111961.html ---
# ○ 「アベラワー 12年 ダブルカスクマチュアード 40％ 700ml」のデータを取得し、ファイルに追記しました。
#    2.26秒待機します...
#
# --- 231/1076件目を処理中: https://www.saketry.com/111962.html ---
# ○ 「グレンモーレンジ 10年 40% 700ml」のデータを取得し、ファイルに追記しました。
#    2.50秒待機します...
#
# --- 232/1076件目を処理中: https://www.saketry.com/111963.html ---
# ○ 「タリスカー10年 45.8％ 700ml」のデータを取得し、ファイルに追記しました。
#    3.70秒待機します...
#
# --- 233/1076件目を処理中: https://www.saketry.com/111965.html ---
# ○ 「クライネリッシュ14年 46％ 700ml」のデータを取得し、ファイルに追記しました。
#    2.98秒待機します...
#
# --- 234/1076件目を処理中: https://www.saketry.com/111966.html ---
# ○ 「グレンドロナック トラディショナリーピーテッド48% 700ml」のデータを取得し、ファイルに追記しました。
#    2.66秒待機します...
#
# --- 235/1076件目を処理中: https://www.saketry.com/111970.html ---
# ○ 「ザ・グレナリー ブレンデッドグレーン1973  46年 50.1%ザ・グレナリー」のデータを取得し、ファイルに追記しました。
#    3.13秒待機します...
#
# --- 236/1076件目を処理中: https://www.saketry.com/111971.html ---
# ○ 「ヴァイタルスパーク バッチ4 2009 10年 53.5％ 500mlメドウサイド」のデータを取得し、ファイルに追記しました。
#    2.10秒待機します...
#
# --- 237/1076件目を処理中: https://www.saketry.com/111972.html ---
# ○ 「ウルフバーン オーロラ ミニチュア 46% 50mlウルフバーン」のデータを取得し、ファイルに追記しました。
#    3.41秒待機します...
#
# --- 238/1076件目を処理中: https://www.saketry.com/111973.html ---
# ○ 「ウルフバーン ラングスキップ ミニチュア 58% 50mlウルフバーン」のデータを取得し、ファイルに追記しました。
#    3.79秒待機します...
#
# --- 239/1076件目を処理中: https://www.saketry.com/111974.html ---
# × エラーが発生したため、このURLの処理をスキップします: HTTPSConnectionPool(host='www.saketry.com', port=443): Read timed out. (read timeout=10)
#    2.80秒待機します...
#
# --- 240/1076件目を処理中: https://www.saketry.com/111975.html ---
# ○ 「キルノートン シークレット・アイラ テンプラニーリョ・ワイン・カスク・マチュアード 56.5% 700mlザ・クーパーズ・チョイス」のデータを取得し、ファイルに追記しました。
#    2.98秒待機します...
#
# --- 241/1076件目を処理中: https://www.saketry.com/111976.html ---
# ○ 「カリラ 2008 12年 アマローネ.・カスク・フィニッシュ 54.5% 700mlザ・クーパズ・チョイス」のデータを取得し、ファイルに追記しました。
#    3.26秒待機します...
#
# --- 242/1076件目を処理中: https://www.saketry.com/111977.html ---
# ○ 「シークレットオークニー 2010 10Y ジャマイカンラムフィニッシュ 56% 700mlザ・クーパーズ・チョイス」のデータを取得し、ファイルに追記しました。
#    3.45秒待機します...
#
# --- 243/1076件目を処理中: https://www.saketry.com/111978.html ---
# ○ 「ダフタウン2008  10年 シェリーフィニッシュ 56% 700mlザ・クーパズ・チョイス」のデータを取得し、ファイルに追記しました。
#    2.97秒待機します...
#
# --- 244/1076件目を処理中: https://www.saketry.com/111979.html ---
# ○ 「グレンエルギン 2009  11年 サント・クロワ・デュ・モン・フィニッシュ 55% 700mlザ・クーパーズ・チョイス」のデータを取得し、ファイルに追記しました。
#    2.22秒待機します...
#
# --- 245/1076件目を処理中: https://www.saketry.com/111980.html ---
# ○ 「トーモア 20011 9年 カルヴァドス・カスク・フィニッシュ 54％ 700mlザ・クーパーズ・チョイス」のデータを取得し、ファイルに追記しました。
#    3.17秒待機します...
#
# --- 246/1076件目を処理中: https://www.saketry.com/111981.html ---
# ○ 「ロッホローモンド 1995 24年 バーボン・カスク・マチュアード 51% 700mlザ・クーパーズ・チョイス」のデータを取得し、ファイルに追記しました。
#    3.86秒待機します...
#
# --- 247/1076件目を処理中: https://www.saketry.com/111990.html ---
# ○ 「オルトモア 2008 12年 シェリーホグスヘッド 53.2％ 700mlモルトマン」のデータを取得し、ファイルに追記しました。
#    3.45秒待機します...
#
# --- 248/1076件目を処理中: https://www.saketry.com/111991.html ---
# ○ 「ブレンデットモルト シェリーバット 1992 27年 42% 700mlモルトマン」のデータを取得し、ファイルに追記しました。
#    3.50秒待機します...
#
# --- 249/1076件目を処理中: https://www.saketry.com/111992.html ---
# ○ 「カリラ バーボンホグスヘッド 6年 55.2％ 700ml モルトマン【日本向けスペシャル限定ボトリング】」のデータを取得し、ファイルに追記しました。
#    2.31秒待機します...
#
# --- 250/1076件目を処理中: https://www.saketry.com/111993.html ---
# ○ 「黄昏流星群JUKUJO ラベル クラインリーシュ 2010 9年 57.8% 700ml漫画ラベルシリーズ」のデータを取得し、ファイルに追記しました。
#    3.19秒待機します...
#
# --- 251/1076件目を処理中: https://www.saketry.com/111994.html ---
# ○ 「黄昏流星群SHITTORIラベル グレンエルギン2006 13年 57.1% 700ml漫画ラベルシリーズ」のデータを取得し、ファイルに追記しました。
#    2.58秒待機します...
#
# --- 252/1076件目を処理中: https://www.saketry.com/111995.html ---
# ○ 「「北斗の拳」北斗の拳ver. ラベル シークレットハイランド 1983 36年 50.3% 700ml漫画ラベルシリーズ」のデータを取得し、ファイルに追記しました。
#    2.51秒待機します...
#
# --- 253/1076件目を処理中: https://www.saketry.com/111998.html ---
# ○ 「クランデニー テイスティング・セット 20ml x 5クランデニー」のデータを取得し、ファイルに追記しました。
#    2.70秒待機します...
#
# --- 254/1076件目を処理中: https://www.saketry.com/111999.html ---
# ○ 「ザ.・クーパーズチョイス テイスティング・セット 20ml x 5ザ・クーパーズ・チョイス」のデータを取得し、ファイルに追記しました。
#    2.50秒待機します...
#
# --- 255/1076件目を処理中: https://www.saketry.com/112000.html ---
# ○ 「ザ・モルトマン シェリー テイスティング・セット 20ml x 3ザ・モルトマン」のデータを取得し、ファイルに追記しました。
#    2.00秒待機します...
#
# --- 256/1076件目を処理中: https://www.saketry.com/112004.html ---
# ○ 「タムデュー 12年 43% 700mlタムデュー」のデータを取得し、ファイルに追記しました。
#    3.97秒待機します...
#
# --- 257/1076件目を処理中: https://www.saketry.com/112005.html ---
# ○ 「タムデュー 15年 46% 700mlタムデュー」のデータを取得し、ファイルに追記しました。
#    2.80秒待機します...
#
# --- 258/1076件目を処理中: https://www.saketry.com/112006.html ---
# ○ 「タムデュー バッチ・ストレングス 004 57.8% 700mlタムデュー」のデータを取得し、ファイルに追記しました。
#    2.59秒待機します...
#
# --- 259/1076件目を処理中: https://www.saketry.com/112007.html ---
# ○ 「コッツウォルズ シングルモルトウイスキー 46% 200mlコッツウォルズ」のデータを取得し、ファイルに追記しました。
#    3.67秒待機します...
#
# --- 260/1076件目を処理中: https://www.saketry.com/112008.html ---
# ○ 「ストラスミル キャンディード・ナッツ 2006 12年 46% 700mlウィームス・モルツ」のデータを取得し、ファイルに追記しました。
#    3.01秒待機します...
#
# --- 261/1076件目を処理中: https://www.saketry.com/112010.html ---
# ○ 「ブナハーブン ハニー・アイム・ホーム 1988 30年 47% 700mlウィームス・モルツ」のデータを取得し、ファイルに追記しました。
#    2.89秒待機します...
#
# --- 262/1076件目を処理中: https://www.saketry.com/112014.html ---
# ○ 「インチマリン シングル・カスク 2006 12年 50.4% 700mlインチマリン【日本向けスペシャル限定ボトリング】」のデータを取得し、ファイルに追記しました。
#    2.95秒待機します...
#
# --- 263/1076件目を処理中: https://www.saketry.com/112016.html ---
# ○ 「イーグル・レア 10年 ケンタッキー ストレート バーボン ウイスキー 45% 700mlバッファロートレース」のデータを取得し、ファイルに追記しました。
#    2.87秒待機します...
#
# --- 264/1076件目を処理中: https://www.saketry.com/112023.html ---
# ○ 「シークレット スペイサイド ディスティラリー 1994 26年 49.7% 700mlディスティラリーズ・コレクション」のデータを取得し、ファイルに追記しました。
#    2.27秒待機します...
#
# --- 265/1076件目を処理中: https://www.saketry.com/112033.html ---
# ○ 「グレンファークラス 12年 43% 700mlグレンファークラス」のデータを取得し、ファイルに追記しました。
#    3.95秒待機します...
#
# --- 266/1076件目を処理中: https://www.saketry.com/112034.html ---
# ○ 「グレンファークラス 17年 43% 700mlグレンファークラス」のデータを取得し、ファイルに追記しました。
#    2.57秒待機します...
#
# --- 267/1076件目を処理中: https://www.saketry.com/112035.html ---
# ○ 「グレンファークラス 21年 43% 700mlグレンファークラス」のデータを取得し、ファイルに追記しました。
#    3.45秒待機します...
#
# --- 268/1076件目を処理中: https://www.saketry.com/112036.html ---
# ○ 「グレンファークラス 25年 43% 700mlグレンファークラス」のデータを取得し、ファイルに追記しました。
#    2.18秒待機します...
#
# --- 269/1076件目を処理中: https://www.saketry.com/112037.html ---
# ○ 「グレンファークラス 105 60% 700mlグレンファークラス」のデータを取得し、ファイルに追記しました。
#    2.06秒待機します...
#
# --- 270/1076件目を処理中: https://www.saketry.com/112038.html ---
# ○ 「グレンファークラス 12年 カスクストレングス 58.9% 700mlグレンファークラス」のデータを取得し、ファイルに追記しました。
#    2.75秒待機します...
#
# --- 271/1076件目を処理中: https://www.saketry.com/112039.html ---
# ○ 「グレンファークラス ザ・ファミリー・カスク 1990 30年 55.2% 700mlグレンファークラス」のデータを取得し、ファイルに追記しました。
#    2.51秒待機します...
#
# --- 272/1076件目を処理中: https://www.saketry.com/112040.html ---
# ○ 「グレンファークラス ザ・ファミリー・カスク 1998 21年 57.9% 700mlグレンファークラス」のデータを取得し、ファイルに追記しました。
#    2.46秒待機します...
#
# --- 273/1076件目を処理中: https://www.saketry.com/112041.html ---
# ○ 「グレンファークラス ザ・ファミリー・カスク 2003 17年 58.3% 700mlグレンファークラス」のデータを取得し、ファイルに追記しました。
#    2.16秒待機します...
#
# --- 274/1076件目を処理中: https://www.saketry.com/112042.html ---
# ○ 「あしたのジョー シークレットハイランドディスティラリー 1985YO 34年 47.6% 700ml漫画ラベルシリーズ」のデータを取得し、ファイルに追記しました。
#    2.93秒待機します...
#
# --- 275/1076件目を処理中: https://www.saketry.com/112043.html ---
# ○ 「あしたのジョー アルターベーン 1993 26年 48.9% 700ml漫画ラベルシリーズ」のデータを取得し、ファイルに追記しました。
#    2.91秒待機します...
#
# --- 276/1076件目を処理中: https://www.saketry.com/112044.html ---
# ○ 「マジンガーZ シークレットスペイサイドディスティラリー 1997 23年 51.9% 700ml漫画ラベルシリーズ」のデータを取得し、ファイルに追記しました。
#    2.88秒待機します...
#
# --- 277/1076件目を処理中: https://www.saketry.com/112045.html ---
# ○ 「ゲッターロボ ウィリアムソン 2006 14年 52.8% 700ml漫画ラベルシリーズ」のデータを取得し、ファイルに追記しました。
#    2.36秒待機します...
#
# --- 278/1076件目を処理中: https://www.saketry.com/112049.html ---
# ○ 「レトロラベル ベン ネヴィス 1997 24年 シェリー バット 53.7% 700mlエリクサー・ディスティラーズ」のデータを取得し、ファイルに追記しました。
#    2.20秒待機します...
#
# --- 279/1076件目を処理中: https://www.saketry.com/112057.html ---
# ○ 「シングルモルト 駒ケ岳 屋久島エージング Bottled in 2021 56% 700mlマルスウイスキー」のデータを取得し、ファイルに追記しました。
#    2.12秒待機します...
#
# --- 280/1076件目を処理中: https://www.saketry.com/112058.html ---
# ○ 「グレンファークラス テイスティング・セット Vol. 1Glenfarclas」のデータを取得し、ファイルに追記しました。
#    3.85秒待機します...
#
# --- 281/1076件目を処理中: https://www.saketry.com/112059.html ---
# ○ 「グレンマレイ 1991 25年 50.9% 700mlザンジバー ビッグ ボックス」のデータを取得し、ファイルに追記しました。
#    2.61秒待機します...
#
# --- 282/1076件目を処理中: https://www.saketry.com/112060.html ---
# ○ 「ブナハーブン 1989 28年 45.8% 700mlザンジバー ザ・クラン」のデータを取得し、ファイルに追記しました。
#    2.53秒待機します...
#
# --- 283/1076件目を処理中: https://www.saketry.com/112061.html ---
# ○ 「ベンリアック 1999 19年 54.8% 700mlザンジバー ザ・クラン」のデータを取得し、ファイルに追記しました。
#    2.17秒待機します...
#
# --- 284/1076件目を処理中: https://www.saketry.com/112062.html ---
# ○ 「ハイランド パーク 1999 19年 49.1 700mlザンジバー ザ・クラン」のデータを取得し、ファイルに追記しました。
#    2.65秒待機します...
#
# --- 285/1076件目を処理中: https://www.saketry.com/112063.html ---
# ○ 「トマーティン 1994 25年 50% 700mlザンジバー ザ・クラン」のデータを取得し、ファイルに追記しました。
#    3.67秒待機します...
#
# --- 286/1076件目を処理中: https://www.saketry.com/112064.html ---
# ○ 「スプリングバンク 2000 18年 47.9% 700mlザンジバー ザ・クラン」のデータを取得し、ファイルに追記しました。
#    2.41秒待機します...
#
# --- 287/1076件目を処理中: https://www.saketry.com/112065.html ---
# ○ 「スペイサイド・リージョン エジンバラ 42年 1975-2017 49.8% 700mlザンジバー ファッジーノ」のデータを取得し、ファイルに追記しました。
#    3.68秒待機します...
#
# --- 288/1076件目を処理中: https://www.saketry.com/112066.html ---
# ○ 「アイラスター 2010-2019 8年 50% 700mlノーススター」のデータを取得し、ファイルに追記しました。
#    3.44秒待機します...
#
# --- 289/1076件目を処理中: https://www.saketry.com/112067.html ---
# ○ 「ノーススター スペイサイドスター 2006-2018 12年 50% 700mlノーススター」のデータを取得し、ファイルに追記しました。
#    2.20秒待機します...
#
# --- 290/1076件目を処理中: https://www.saketry.com/112068.html ---
# ○ 「ハイランドスター 2007-2018 11年 50% 700mlノーススター」のデータを取得し、ファイルに追記しました。
#    3.10秒待機します...
#
# --- 291/1076件目を処理中: https://www.saketry.com/112069.html ---
# ○ 「アイランドスター 2008-2018 シリーズ 2 10YO 50% 700mlノーススター」のデータを取得し、ファイルに追記しました。
#    2.09秒待機します...
#
# --- 292/1076件目を処理中: https://www.saketry.com/112070.html ---
# ○ 「グレンタレット ルーアックモア 2010-2019 8年 58.3% 700mlノーススター」のデータを取得し、ファイルに追記しました。
#    3.59秒待機します...
#
# --- 293/1076件目を処理中: https://www.saketry.com/112071.html ---
# ○ 「インチガワー 2007-2019 11年 52.5% 700mlノーススター」のデータを取得し、ファイルに追記しました。
#    2.67秒待機します...
#
# --- 294/1076件目を処理中: https://www.saketry.com/112072.html ---
# ○ 「イングリッシュ ウイスキー 2007-2019 11年 49.8% 700mlノーススター」のデータを取得し、ファイルに追記しました。
#    3.16秒待機します...
#
# --- 295/1076件目を処理中: https://www.saketry.com/112073.html ---
# ○ 「ブレンデッドグレーン 1982-2019 36年 52.5% 700mlノーススター」のデータを取得し、ファイルに追記しました。
#    3.77秒待機します...
#
# --- 296/1076件目を処理中: https://www.saketry.com/112074.html ---
# ○ 「ヴェガ ブレンデッドモルト 1990-2019 28年 46.7% 700mlノーススター」のデータを取得し、ファイルに追記しました。
#    2.05秒待機します...
#
# --- 297/1076件目を処理中: https://www.saketry.com/112075.html ---
# ○ 「ヴェガ ブレンデッドモルト 1996-2019 22年 43.9% 700mlノーススター」のデータを取得し、ファイルに追記しました。
#    3.57秒待機します...
#
# --- 298/1076件目を処理中: https://www.saketry.com/112076.html ---
# ○ 「トーモア 1988 30年 ヘラ 50.7% 700mlアクア・ヴィーテ ギリシャ神話」のデータを取得し、ファイルに追記しました。
#    3.19秒待機します...
#
# --- 299/1076件目を処理中: https://www.saketry.com/112077.html ---
# ○ 「レダイグ 1997 22年 アレス 52.3% 700mlアクア・ヴィーテ ギリシャ神話」のデータを取得し、ファイルに追記しました。
#    3.40秒待機します...
#
# --- 300/1076件目を処理中: https://www.saketry.com/112078.html ---
# ○ 「ブナハーブン1989-2018 29年 エーテル 48.8% 700mlアクア・ヴィーテ ファイブエレメンツ」のデータを取得し、ファイルに追記しました。
#    3.68秒待機します...
#
# --- 301/1076件目を処理中: https://www.saketry.com/112079.html ---
# ○ 「カリラ  5年 "Joint Bottle With Bar TCRC" 59% 700mlアクア・ヴィーテ ジョイントボトルシリーズ」のデータを取得し、ファイルに追記しました。
#    2.73秒待機します...
#
# --- 302/1076件目を処理中: https://www.saketry.com/112080.html ---
# ○ 「グレンマレイ 1992 21年 60.1% 700mlダン・イーダン」のデータを取得し、ファイルに追記しました。
#    3.71秒待機します...
#
# --- 303/1076件目を処理中: https://www.saketry.com/112082.html ---
# ○ 「ロングモーン 2010 9年 53.5% 700mlハートブラザーズ ファイネスト・コレクション」のデータを取得し、ファイルに追記しました。
#    2.81秒待機します...
#
# --- 304/1076件目を処理中: https://www.saketry.com/112083.html ---
# ○ 「ストラスアイラ 2010 9年 アルマニャック 53.8% 700mlハートブラザーズ ファイネスト・コレクション」のデータを取得し、ファイルに追記しました。
#    3.08秒待機します...
#
# --- 305/1076件目を処理中: https://www.saketry.com/112084.html ---
# ○ 「トマーティン 2010 10年 ポートフィン 53.8% 700mlハートブラザーズ ファイネスト・コレクション」のデータを取得し、ファイルに追記しました。
#    3.98秒待機します...
#
# --- 306/1076件目を処理中: https://www.saketry.com/112086.html ---
# ○ 「ダルユーイン 1999 21年 52.8% 700mlハートブラザーズ ファイネスト・コレクション」のデータを取得し、ファイルに追記しました。
#    3.99秒待機します...
#
# --- 307/1076件目を処理中: https://www.saketry.com/112088.html ---
# ○ 「オークニー 2006 12年 バーボン樽 60.4% 700mlザンジバー キュンストラーシリーズ」のデータを取得し、ファイルに追記しました。
#    2.27秒待機します...
#
# --- 308/1076件目を処理中: https://www.saketry.com/112089.html ---
# ○ 「グレンロセス 2007 11年 シェリーバット Ralfy.co 10th Anniversary 51.4% 700mlノーススター」のデータを取得し、ファイルに追記しました。
#    2.92秒待機します...
#
# --- 309/1076件目を処理中: https://www.saketry.com/112098.html ---
# ○ 「あかし トーニー ポート カスク 2016 4年 61.5% 500mlラベルシリーズ」のデータを取得し、ファイルに追記しました。
#    2.83秒待機します...
#
# --- 310/1076件目を処理中: https://www.saketry.com/112100.html ---
# ○ 「ベルセルク アイリッシュ ウイスキー 2002 17YO 50.3% 700ml漫画ラベルシリーズ」のデータを取得し、ファイルに追記しました。
#    3.59秒待機します...
#
# --- 311/1076件目を処理中: https://www.saketry.com/112104.html ---
# ○ 「キルホーマン マキヤーベイ 46% 700mlキルホーマン」のデータを取得し、ファイルに追記しました。
#    3.53秒待機します...
#
# --- 312/1076件目を処理中: https://www.saketry.com/112105.html ---
# ○ 「クランデニー タリスカー 2010 9年 プレーンリフィルホグスヘッド 55.5% 700mlクランデニー」のデータを取得し、ファイルに追記しました。
#    3.39秒待機します...
#
# --- 313/1076件目を処理中: https://www.saketry.com/112106.html ---
# ○ 「コッツウォルズ シェリーカスク シングルモルトウイスキー 57.4% 700mlコッツウォルズ」のデータを取得し、ファイルに追記しました。
#    2.48秒待機します...
#
# --- 314/1076件目を処理中: https://www.saketry.com/112108.html ---
# ○ 「グレンゴイン18YO 43% 700mlグレンゴイン」のデータを取得し、ファイルに追記しました。
#    3.43秒待機します...
#
# --- 315/1076件目を処理中: https://www.saketry.com/112109.html ---
# ○ 「スプリングバンク 1993 22年 リフィルシェリーホグスヘッド 51.9% 700mlザ・ボトラーズ」のデータを取得し、ファイルに追記しました。
#    2.85秒待機します...
#
# --- 316/1076件目を処理中: https://www.saketry.com/112111.html ---
# ○ 「ザ・イリデセント・カスク グレンエルギン 2010 10年 ホグスヘッド 54.5% 700ml」のデータを取得し、ファイルに追記しました。
#    2.35秒待機します...
#
# --- 317/1076件目を処理中: https://www.saketry.com/112112.html ---
# ○ 「ザ・イリデセント・カスク キャンベルタウンブレンデッドモルト 2014 6年 ホグズヘッド 56.5% 700ml」のデータを取得し、ファイルに追記しました。
#    2.73秒待機します...
#
# --- 318/1076件目を処理中: https://www.saketry.com/112113.html ---
# ○ 「カリラ 2008 12年 ホグズヘッド 55% 700mlディスティラリーズ・コレクション」のデータを取得し、ファイルに追記しました。
#    2.17秒待機します...
#
# --- 319/1076件目を処理中: https://www.saketry.com/112115.html ---
# ○ 「バルブレア 19年 55.9% 700mlアートオブウイスキー」のデータを取得し、ファイルに追記しました。
#    3.75秒待機します...
#
# --- 320/1076件目を処理中: https://www.saketry.com/112116.html ---
# ○ 「ベンネヴィス 1996 23年 52.1% 700mlザ・ウイスキー・エクスチェンジ」のデータを取得し、ファイルに追記しました。
#    3.11秒待機します...
#
# --- 321/1076件目を処理中: https://www.saketry.com/112117.html ---
# ○ 「ブナハーブン 1997 22年 51.3% 700ml ザ・ウイスキー・エクスチェンジ」のデータを取得し、ファイルに追記しました。
#    2.76秒待機します...
#
# --- 322/1076件目を処理中: https://www.saketry.com/112118.html ---
# ○ 「カリラ 2008 12年 58.5% 700mlザ・ウィスキー エクスチェンジ」のデータを取得し、ファイルに追記しました。
#    2.11秒待機します...
#
# --- 323/1076件目を処理中: https://www.saketry.com/112119.html ---
# ○ 「クライヌリッシュ 21年 56.1% 700ml アートオブウイスキー」のデータを取得し、ファイルに追記しました。
#    3.86秒待機します...
#
# --- 324/1076件目を処理中: https://www.saketry.com/112120.html ---
# ○ 「グレンエルギン 12年 55.8% 700mlザ・ウイスキー・エクスチェンジ」のデータを取得し、ファイルに追記しました。
#    2.54秒待機します...
#
# --- 325/1076件目を処理中: https://www.saketry.com/112121.html ---
# ○ 「グレンロッシー 2009 11年 カスク 56.5% 700ml ザ・ウイスキー・エクスチェンジ」のデータを取得し、ファイルに追記しました。
#    3.56秒待機します...
#
# --- 326/1076件目を処理中: https://www.saketry.com/112122.html ---
# ○ 「グレンロセス 27年 51.1% 700mlアートオブウイスキー」のデータを取得し、ファイルに追記しました。
#    2.82秒待機します...
#
# --- 327/1076件目を処理中: https://www.saketry.com/112123.html ---
# ○ 「グレントファース 19年 53.5% 700mlアートオブウイスキー」のデータを取得し、ファイルに追記しました。
#    3.77秒待機します...
#
# --- 328/1076件目を処理中: https://www.saketry.com/112125.html ---
# ○ 「ミルトンダフ 17年 54.5% 700ml アートオブウイスキー」のデータを取得し、ファイルに追記しました。
#    2.10秒待機します...
#
# --- 329/1076件目を処理中: https://www.saketry.com/112126.html ---
# ○ 「スプリングバンク 24年 51.7% 700mlアートオブウイスキー」のデータを取得し、ファイルに追記しました。
#    2.28秒待機します...
#
# --- 330/1076件目を処理中: https://www.saketry.com/112127.html ---
# ○ 「グレントファース 1996 25年 カスク #1197 48.5% 700mlディスティラリーズ・コレクション」のデータを取得し、ファイルに追記しました。
#    3.49秒待機します...
#
# --- 331/1076件目を処理中: https://www.saketry.com/112128.html ---
# ○ 「タリスカー シェリー・ウッド 1993 27年 50.5%ハートブラザーズ・ファイネスト・コレクション」のデータを取得し、ファイルに追記しました。
#    3.36秒待機します...
#
# --- 332/1076件目を処理中: https://www.saketry.com/112130.html ---
# ○ 「フレーミングハート ブレンデッドモルトスコッチウイスキー 48.9% 700mlコンパスボックス」のデータを取得し、ファイルに追記しました。
#    2.82秒待機します...
#
# --- 333/1076件目を処理中: https://www.saketry.com/112131.html ---
# ○ 「ザ・スパイス・ツリー ブレンデッドモルトスコッチウイスキー 46% 700mlコンパスボックス」のデータを取得し、ファイルに追記しました。
#    3.26秒待機します...
#
# --- 334/1076件目を処理中: https://www.saketry.com/112132.html ---
# ○ 「ブティック・ウイスキー・カンパニー ワールド・ウイスキー・ブレンド 41.6% 700mlブティック・ウイスキー・カンパニー」のデータを取得し、ファイルに追記しました。
#    2.66秒待機します...
#
# --- 335/1076件目を処理中: https://www.saketry.com/112134.html ---
# ○ 「グレンアラヒー ナパヴァレーレッドワインカスク 2010 10年 53.7% 700mlグレンアラヒー」のデータを取得し、ファイルに追記しました。
#    3.86秒待機します...
#
# --- 336/1076件目を処理中: https://www.saketry.com/112135.html ---
# ○ 「モートラック 16年 52.6% 700mlハートブラザーズファイネスト・コレクション」のデータを取得し、ファイルに追記しました。
#    3.41秒待機します...
#
# ...
# ○ 「イクイノックス＆ソルスティス オータム エディション 2023 アバフェルディ 10年 48.5% 700mlイクイノックス＆ソルスティス」のデータを取得し、ファイルに追記しました。
#    3.50秒待機します...
#
# --- 977/1076件目を処理中: https://www.saketry.com/113192.html ---
# ○ 「オールド・オークニー OO2 19年 53% 700mlオールド・オークニー」のデータを取得し、ファイルに追記しました。
#    3.16秒待機します...
#
# --- 978/1076件目を処理中: https://www.saketry.com/113193.html ---
# ○ 「イクイノックス＆ソルスティス ウィンターエディション 2023 ミルトンダフ 11年 1st フィル・シェリーホグスヘッド 48.5% 700mlイクイノックス＆ソルスティス」のデータを取得し、ファイルに追記しました。
#    3.51秒待機します...
#
# --- 979/1076件目を処理中: https://www.saketry.com/113194.html ---
# ○ 「エディション No.84 オーヘントッシャン 31年 2nd フィル・バレル 53.6% 700mlウイスキースポンジ」のデータを取得し、ファイルに追記しました。
#    2.36秒待機します...
#
# --- 980/1076件目を処理中: https://www.saketry.com/113207.html ---
# ○ 「ブレアソール 1992 31年 43.3% 700mlザ・モルトマン」のデータを取得し、ファイルに追記しました。
#    2.15秒待機します...
#
# --- 981/1076件目を処理中: https://www.saketry.com/113218.html ---
# ○ 「YUZA シングルモルト ジャパニーズウイスキー サードエディション 2023 55% 700mledition シリーズ」のデータを取得し、ファイルに追記しました。
#    3.88秒待機します...
#
# --- 982/1076件目を処理中: https://www.saketry.com/113219.html ---
# ○ 「YUZA スプリング イン ジャパン 2024 55% 700ML限定シリーズ」のデータを取得し、ファイルに追記しました。
#    2.77秒待機します...
#
# --- 983/1076件目を処理中: https://www.saketry.com/113231.html ---
# ○ 「「ミワさんなりすます」ラベル アードモア 2010 12年 48.1% 700ML漫画ラベル」のデータを取得し、ファイルに追記しました。
#    2.74秒待機します...
#
# --- 984/1076件目を処理中: https://www.saketry.com/113232.html ---
# ○ 「「村松誠イラスト」ラベル "猫” TOMARTIN 2008 13年 49.4% 700MLウイスキー・ミュウ」のデータを取得し、ファイルに追記しました。
#    2.95秒待機します...
#
# --- 985/1076件目を処理中: https://www.saketry.com/113233.html ---
# ○ 「「村松誠イラスト」ラベル "犬” TOMARTIN 2008 13年 49.4% 700ML漫画ラベル」のデータを取得し、ファイルに追記しました。
#    2.57秒待機します...
#
# --- 986/1076件目を処理中: https://www.saketry.com/113234.html ---
# ○ 「「三丁目の夕日」ラベル あかし 3年 (トロンセ樽) 63% 500ML漫画ラベル」のデータを取得し、ファイルに追記しました。
#    2.15秒待機します...
#
# --- 987/1076件目を処理中: https://www.saketry.com/113235.html ---
# ○ 「嘉之助「ダブル ディスティラリー」53% 700MLダブル ディスティラリー」のデータを取得し、ファイルに追記しました。
#    3.81秒待機します...
#
# --- 988/1076件目を処理中: https://www.saketry.com/113236.html ---
# ○ 「MARS The.Y.A. #03 51% 700mlMARS The.Y.A.」のデータを取得し、ファイルに追記しました。
#    2.60秒待機します...
#
# --- 989/1076件目を処理中: https://www.saketry.com/113237.html ---
# ○ 「ザ クライドサイド 2018 5年 FOR  スリーリバーズ 20th アニバーサリー 58.6% 700mlクライドサイド」のデータを取得し、ファイルに追記しました。
#    2.56秒待機します...
#
# --- 990/1076件目を処理中: https://www.saketry.com/113239.html ---
# ○ 「『釣りバカ日誌』ラベル シークレットアイラ 2013 ８年 53.4% 700ml漫画ラベル」のデータを取得し、ファイルに追記しました。
#    3.70秒待機します...
#
# --- 991/1076件目を処理中: https://www.saketry.com/113241.html ---
# ○ 「『黄昏流星群』ラベル シークレットアイラ 2018 4年 53.7% 700ML漫画ラベル」のデータを取得し、ファイルに追記しました。
#    3.17秒待機します...
#
# --- 992/1076件目を処理中: https://www.saketry.com/113242.html ---
# ○ 「シークレットハイランド 2010 13年 シェリーカスク 52.1% 700mlディスティラリーズ・コレクション」のデータを取得し、ファイルに追記しました。
#    2.05秒待機します...
#
# --- 993/1076件目を処理中: https://www.saketry.com/113243.html ---
# ○ 「シークレットオークニー  2006 17年 ホグスヘッド 51.7% 700mlディスティラリーズ・コレクション」のデータを取得し、ファイルに追記しました。
#    3.27秒待機します...
#
# --- 994/1076件目を処理中: https://www.saketry.com/113244.html ---
# ○ 「バルメナック 2013 10年 シェリーホグスヘッド 53.8% 700mlディスティラリーズ・コレクション」のデータを取得し、ファイルに追記しました。
#    3.31秒待機します...
#
# --- 995/1076件目を処理中: https://www.saketry.com/113245.html ---
# ○ 「グレンロセス 1992 30年 ホグスヘッド 48.3% 700mlザ・テイスター」のデータを取得し、ファイルに追記しました。
#    2.80秒待機します...
#
# --- 996/1076件目を処理中: https://www.saketry.com/113246.html ---
# ○ 「【限定377本】シークレットアイラ 2017 6年 ウイスキペディア×Pen コラボレーションボトル 53.9% 700mlウイスキペディア×Pen」のデータを取得し、ファイルに追記しました。
#    3.41秒待機します...
#
# --- 997/1076件目を処理中: https://www.saketry.com/113247.html ---
# ○ 「【限定58本】シークレットアイラ 2009 14年 ウイスキペディア×Pen コラボレーションボトル 51.7% 700mlウイスキペディア×Pen」のデータを取得し、ファイルに追記しました。
#    3.90秒待機します...
#
# --- 998/1076件目を処理中: https://www.saketry.com/113248.html ---
# ○ 「ベンネヴィス 1998 25年 ホグスヘッド 能登チャリティーボトル 49.4% 700mlザ・モルトマン」のデータを取得し、ファイルに追記しました。
#    2.69秒待機します...
#
# --- 999/1076件目を処理中: https://www.saketry.com/113249.html ---
# ○ 「ノックデュー 2013 10年 シェリーカスク 能登チャリティーボトル 54.8% 700mlザ・モルトマン」のデータを取得し、ファイルに追記しました。
#    2.98秒待機します...
#
# --- 1000/1076件目を処理中: https://www.saketry.com/113251.html ---
# ○ 「『銀河英雄伝説』ラインハルト ラベル プルトニー 2013 9年 52.3% 700ML漫画ラベルシリーズ」のデータを取得し、ファイルに追記しました。
#    2.05秒待機します...
#
# --- 1001/1076件目を処理中: https://www.saketry.com/113252.html ---
# ○ 「『銀河英雄伝説』ヤン・ウェンリー・ラベル カリラ 2010 12年 53.4% 700ML漫画ラベル」のデータを取得し、ファイルに追記しました。
#    3.55秒待機します...
#
# --- 1002/1076件目を処理中: https://www.saketry.com/113253.html ---
# ○ 「『西伊豆木負』ラベル 川瀬巴水 ベンネヴィス 2012  10年 56.1% 700MLアートエクスプレッション」のデータを取得し、ファイルに追記しました。
#    2.61秒待機します...
#
# --- 1003/1076件目を処理中: https://www.saketry.com/113254.html ---
# ○ 「『東京十二景 馬込の月』ラベル  川瀬巴水 クラインリーシュ 2011 12年 61.0% 700MLアートエクスプレッション」のデータを取得し、ファイルに追記しました。
#    2.81秒待機します...
#
# --- 1004/1076件目を処理中: https://www.saketry.com/113265.html ---
# ○ 「アードモア 2013 10年 52.5% 700mlザ・クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    3.21秒待機します...
#
# --- 1005/1076件目を処理中: https://www.saketry.com/113266.html ---
# ○ 「ブレアソール 2011 12年 マスカットカスクフィニッシュ 52.5% 700mlザ・クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    3.80秒待機します...
#
# --- 1006/1076件目を処理中: https://www.saketry.com/113267.html ---
# ○ 「ベンリネス 2011 12年 マルティニークラムカスクフィニッシュ 51.5% 700mlザ・クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    2.12秒待機します...
#
# --- 1007/1076件目を処理中: https://www.saketry.com/113268.html ---
# ○ 「カンバス 1991 32年 47.5% 700mlザ・クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    2.34秒待機します...
#
# --- 1008/1076件目を処理中: https://www.saketry.com/113270.html ---
# ○ 「グレンロッシー2011 12年 カルヴァドスカスクフィニッシュ 54.5% 700mlザ・クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    2.36秒待機します...
#
# --- 1009/1076件目を処理中: https://www.saketry.com/113271.html ---
# ○ 「グレンマレイ 2015 8年 マルサラ フィニッシュ 58.5% 700mlザ・クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    3.06秒待機します...
#
# --- 1010/1076件目を処理中: https://www.saketry.com/113272.html ---
# ○ 「リンクウッド 2011 12年 オロロソシェリーカスクフィニッシュ 54% 700mlザ・クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    2.77秒待機します...
#
# --- 1011/1076件目を処理中: https://www.saketry.com/113273.html ---
# ○ 「タムデュー 2015 8年 マデイラカスクフィニッシュ 57.4% 700mlザ・クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    2.56秒待機します...
#
# --- 1012/1076件目を処理中: https://www.saketry.com/113274.html ---
# ○ 「ディーンストン 2014 8年 マルサラ フィニッシュ 54% 700mlザ・クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    2.02秒待機します...
#
# --- 1013/1076件目を処理中: https://www.saketry.com/113275.html ---
# ○ 「インバーゴードン2005 18年 マルサラ フィニッシュ 47.8% 700mlザ・クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    3.23秒待機します...
#
# --- 1014/1076件目を処理中: https://www.saketry.com/113276.html ---
# ○ 「トーモア 2015 7年 オロロソ シェリー カスク フィニッシュ 57% 700mlザ・クーパーズチョイス」のデータを取得し、ファイルに追記しました。
#    3.40秒待機します...
#
# --- 1015/1076件目を処理中: https://www.saketry.com/113297.html ---
# ○ 「エディション No.85 ベンネヴィス 10年 リフィルバット / リフィル・クォーターカスク・フィニッシュ 52.0% 700mlウイスキースポンジ」のデータを取得し、ファイルに追記しました。
#    2.24秒待機します...
#
# --- 1016/1076件目を処理中: https://www.saketry.com/113301.html ---
# ○ 「エディション No.89 ‘ゴーン グラント’ 31年 2nd フィル・バレル 43.9% 700mlウイスキースポンジ」のデータを取得し、ファイルに追記しました。
#    2.25秒待機します...
#
# --- 1017/1076件目を処理中: https://www.saketry.com/113302.html ---
# ○ 「イクイノックス＆ソルスティス スプリングエディション 2024 ティーニニック 12年 シングルリフィル・ホグスヘッド 48.5% 700mlイクイノックス＆ソルスティス」のデータを取得し、ファイルに追記しました。
#    2.44秒待機します...
#
# --- 1018/1076件目を処理中: https://www.saketry.com/113303.html ---
# ○ 「エディション No.90 ブラドノック 34年 リフィルバレル 55.1% 700mlウイスキースポンジ」のデータを取得し、ファイルに追記しました。
#    2.29秒待機します...
#
# --- 1019/1076件目を処理中: https://www.saketry.com/113310.html ---
# ○ 「コッツウォルズ リザーブ シングルモルトウイスキー 1st フィル・バーボンカスク / レッドワインカスク 50% 700mlコッツウォルズ」のデータを取得し、ファイルに追記しました。
#    2.88秒待機します...
#
# --- 1020/1076件目を処理中: https://www.saketry.com/113311.html ---
# ○ 「グレンバーギー 2010 13年 オロロソ シェリー フィニッシュ 53.3% 700mlザ・ウイスキー・セラー プライベート・セラーズ・コレクション」のデータを取得し、ファイルに追記しました。
#    2.96秒待機します...
#
# --- 1021/1076件目を処理中: https://www.saketry.com/113312.html ---
# ○ 「カリラ 2012 11年 コート・ロティ ワインカスク フィニッシュ 55.2% 700mlザ・ウイスキー・セラー プライベート・セラーズ・コレクション」のデータを取得し、ファイルに追記しました。
#    3.43秒待機します...
#
# --- 1022/1076件目を処理中: https://www.saketry.com/113313.html ---
# ○ 「ノースブリティッシュ 1989 33年 リフィル バーボンバレル 50.1% 700mlザ・ウイスキー・セラー プライベート・セラーズ・コレクション」のデータを取得し、ファイルに追記しました。
#    2.58秒待機します...
#
# --- 1023/1076件目を処理中: https://www.saketry.com/113314.html ---
# ○ 「ロブスト シガーモルト 2015 8年 オロロソシェリーカスク 52.5% 700mlザ・ウイスキー・セラー プライベート・セラーズ・コレクション」のデータを取得し、ファイルに追記しました。
#    3.22秒待機します...
#
# --- 1024/1076件目を処理中: https://www.saketry.com/113315.html ---
# ○ 「グレンスペイ 2009 14年 ルピアック ワインカスク フィニッシュ 54.7% 700mlピンテイル」のデータを取得し、ファイルに追記しました。
#    3.36秒待機します...
#
# --- 1025/1076件目を処理中: https://www.saketry.com/113316.html ---
# ○ 「オスロスク 2008 15年 フォンディジョン ワインカスク フィニッシュ 54.3% 700mlピンテイル」のデータを取得し、ファイルに追記しました。
#    2.83秒待機します...
#
# --- 1026/1076件目を処理中: https://www.saketry.com/113317.html ---
# ○ 「ベンネヴィス 1997 25年 ホグスヘッド 47.6% 700mlスピリッツ ショップ セレクション」のデータを取得し、ファイルに追記しました。
#    3.67秒待機します...
#
# --- 1027/1076件目を処理中: https://www.saketry.com/113318.html ---
# ○ 「レダイグ 2005 14年 ホグスヘッド 57.8% 700mlスピリッツ ショップ セレクション」のデータを取得し、ファイルに追記しました。
#    3.09秒待機します...
#
# --- 1028/1076件目を処理中: https://www.saketry.com/113319.html ---
# ○ 「グレンエルギン 2008 12年 シェリーバット 58.7% 700mlスピリッツ ショップ セレクション」のデータを取得し、ファイルに追記しました。
#    3.74秒待機します...
#
# --- 1029/1076件目を処理中: https://www.saketry.com/113320.html ---
# ○ 「オスロスク 2010 12年 ホグスヘッド 60.8% 700mlスピリッツ ショップ セレクション」のデータを取得し、ファイルに追記しました。
#    2.95秒待機します...
#
# --- 1030/1076件目を処理中: https://www.saketry.com/113322.html ---
# ○ 「インチガワー 2010 12年 ホグスヘッド 57.6% 700mlスピリッツ ショップ セレクション」のデータを取得し、ファイルに追記しました。
#    2.18秒待機します...
#
# --- 1031/1076件目を処理中: https://www.saketry.com/113323.html ---
# ○ 「ガーヴァン 2006 17年 ファインブルターニュカスクフィニッシュ 53.7% 700mlピンテイル」のデータを取得し、ファイルに追記しました。
#    2.81秒待機します...
#
# --- 1032/1076件目を処理中: https://www.saketry.com/113325.html ---
# ○ 「シングルモルト 駒ヶ岳 2024 エディション 50% 700MLシングルモルト駒ヶ岳」のデータを取得し、ファイルに追記しました。
#    3.58秒待機します...
#
# --- 1033/1076件目を処理中: https://www.saketry.com/113332.html ---
# ○ 「イチローズ モルト アンド グレーン 20th アニバーサリーエディション 48% 700MLICHRO`S MALT」のデータを取得し、ファイルに追記しました。
#    2.19秒待機します...
#
# --- 1034/1076件目を処理中: https://www.saketry.com/113356.html ---
# ○ 「インバーゴードン 1974 50年 バーボンバレル 43.2% 700mlザ・グレーンマン」のデータを取得し、ファイルに追記しました。
#    2.03秒待機します...
#
# --- 1035/1076件目を処理中: https://www.saketry.com/113357.html ---
# ○ 「ダルユーイン 2009 14年 リフィル シェリーバット 53.1% 700mlザ・モルトマン」のデータを取得し、ファイルに追記しました。
#    2.83秒待機します...
#
# --- 1036/1076件目を処理中: https://www.saketry.com/113358.html ---
# ○ 「グレンロッシー 1997 26年 リフィル シェリーバット 47.6% 700mlザ・モルトマン」のデータを取得し、ファイルに追記しました。
#    3.19秒待機します...
#
# --- 1037/1076件目を処理中: https://www.saketry.com/113360.html ---
# ○ 「アイランズ ブレンデッドモルト 1999 22年 バーボン ホグスヘッド 46.5% 700mlザ・モルトマン」のデータを取得し、ファイルに追記しました。
#    2.80秒待機します...
#
# --- 1038/1076件目を処理中: https://www.saketry.com/113362.html ---
# ○ 「ブレンデットスコッチ 信濃屋  25年 48.2% 700mlザ・モルトマン」のデータを取得し、ファイルに追記しました。
#    3.29秒待機します...
#
# --- 1039/1076件目を処理中: https://www.saketry.com/113363.html ---
# ○ 「ブレンデットスコッチ 信濃屋 37年 43.8% 700mlザ・モルトマン」のデータを取得し、ファイルに追記しました。
#    2.91秒待機します...
#
# --- 1040/1076件目を処理中: https://www.saketry.com/113364.html ---
# ○ 「リンクウッド 2006 17年 マデイラカスク フィニッシュ ジャパン・エクスクルーシブ 52.2% 700mlザ・モルトマン」のデータを取得し、ファイルに追記しました。
#    2.49秒待機します...
#
# --- 1041/1076件目を処理中: https://www.saketry.com/113365.html ---
# ○ 「ウルフバーン マンサニージャカスクフィニッシュ 46% 700mlウルフバーン」のデータを取得し、ファイルに追記しました。
#    2.21秒待機します...
#
# --- 1042/1076件目を処理中: https://www.saketry.com/113366.html ---
# ○ 「ウルフバーン ウィック・ハーバー・トラスト ブラックサタデー 46% 700mlウルフバーン」のデータを取得し、ファイルに追記しました。
#    3.88秒待機します...
#
# --- 1043/1076件目を処理中: https://www.saketry.com/113374.html ---
# ○ 「ウルフバーン ジャパン・エクスクルーシブ 7 2017 7年 カスク No.245 50% 700mlウルフバーン」のデータを取得し、ファイルに追記しました。
#    2.21秒待機します...
#
# --- 1044/1076件目を処理中: https://www.saketry.com/113385.html ---
# ○ 「ウルフバーン メリークリスマス 10年 46% 350mlウルフバーン」のデータを取得し、ファイルに追記しました。
#    2.29秒待機します...
#
# --- 1045/1076件目を処理中: https://www.saketry.com/113386.html ---
# ○ 「ブルックラディ 1991 32年 リフィル ホグスヘッド 49.3% 700mlザ・モルトマン」のデータを取得し、ファイルに追記しました。
#    2.33秒待機します...
#
# --- 1046/1076件目を処理中: https://www.saketry.com/113389.html ---
# ○ 「アードナッホー ファースト リリース 50％ 700MLアードナッホー」のデータを取得し、ファイルに追記しました。
#    3.50秒待機します...
#
# --- 1047/1076件目を処理中: https://www.saketry.com/113402.html ---
# ○ 「アイル・オブ・ハリス ザ・ヒーラック オロロソカスク シングルモルトウイスキー 46% 700mlアイル・オブ・ハリス」のデータを取得し、ファイルに追記しました。
#    3.26秒待機します...
#
# --- 1048/1076件目を処理中: https://www.saketry.com/113404.html ---
# ○ 「エディション No.67 オールド・ロスデュー 1993 29年 リフィル・ホグスヘッド 57.1％ 700mlウイスキースポンジ」のデータを取得し、ファイルに追記しました。
#    2.29秒待機します...
#
# --- 1049/1076件目を処理中: https://www.saketry.com/113405.html ---
# ○ 「『めぞん一刻』音無響子ラベル／グレングラント 1998 25年 リフィル・シェリーバット 48.9% 700ml漫画ラベルシリーズ」のデータを取得し、ファイルに追記しました。
#    2.97秒待機します...
#
# --- 1050/1076件目を処理中: https://www.saketry.com/113406.html ---
# ○ 「『めぞん一刻』音無響子＆五代裕作ラベル／キルダルトン 2009 ホグスヘッド 54.2% 700ml漫画ラベルシリーズ」のデータを取得し、ファイルに追記しました。
#    2.62秒待機します...
#
# --- 1051/1076件目を処理中: https://www.saketry.com/113407.html ---
# ○ 「『旅みやげ第三集 別府の朝』ラベル 川瀬巴水 アン・オークニー2006 17年  59.1% 700MLアートエクスプレッション」のデータを取得し、ファイルに追記しました。
#    2.67秒待機します...
#
# --- 1052/1076件目を処理中: https://www.saketry.com/113408.html ---
# ○ 「成田一徹「THE DUFFTOWN」ラベル／レダイグ 2009 14年 ホグスヘッド 50.5% 700ml成田一徹 ラベル・ウイスキー」のデータを取得し、ファイルに追記しました。
#    2.48秒待機します...
#
# --- 1053/1076件目を処理中: https://www.saketry.com/113409.html ---
# ○ 「成田一徹「AUGUSTA」ラベル／ウエストポート 2006 17年 ホグスヘッド 51.2% 700ml成田一徹 ラベル・ウイスキー」のデータを取得し、ファイルに追記しました。
#    3.91秒待機します...
#
# --- 1054/1076件目を処理中: https://www.saketry.com/113410.html ---
# ○ 「『笑ゥせぇるすまん』ラベル／ベンネヴィス 1997 25年 シェリーバット 48.7% 700ml漫画ラベルシリーズ」のデータを取得し、ファイルに追記しました。
#    3.20秒待機します...
#
# --- 1055/1076件目を処理中: https://www.saketry.com/113411.html ---
# ○ 「パート6 カリラ 13年 リフィル・シェリーホグスヘッド / ファーストフィル・シェリーホグスヘッド 53% 700mlアイラスポンジ」のデータを取得し、ファイルに追記しました。
#    3.66秒待機します...
#
# --- 1056/1076件目を処理中: https://www.saketry.com/113412.html ---
# ○ 「エディション No.95 ‘サイドバーン’ 31年 2nd フィル・バレル / 1st フィル・バレル 51.4% 700mlウイスキースポンジ」のデータを取得し、ファイルに追記しました。
#    2.50秒待機します...
#
# --- 1057/1076件目を処理中: https://www.saketry.com/113413.html ---
# ○ 「エディション No.4 レダイグ 29年 2nd フィル・シェリーバット 52.0% 700mlウエスティースポンジ」のデータを取得し、ファイルに追記しました。
#    2.28秒待機します...
#
# --- 1058/1076件目を処理中: https://www.saketry.com/113414.html ---
# ○ 「イクイノックス＆ソルスティス サマーエディション 2024 モートラック 16年 48.5% 700mlウイスキースポンジ」のデータを取得し、ファイルに追記しました。
#    3.17秒待機します...
#
# --- 1059/1076件目を処理中: https://www.saketry.com/113415.html ---
# ○ 「エディション No.94 インチマリン 15年 2nd フィル・ホグスヘッド 53% 700mlウイスキースポンジ」のデータを取得し、ファイルに追記しました。
#    2.43秒待機します...
#
# --- 1060/1076件目を処理中: https://www.saketry.com/113416.html ---
# ○ 「エディション No.92 アベラワー 33年 49.7% 700mlウイスキースポンジ」のデータを取得し、ファイルに追記しました。
#    2.85秒待機します...
#
# --- 1061/1076件目を処理中: https://www.saketry.com/113419.html ---
# ○ 「シングルモルト津貫 2025 エディション 49% 700ML津貫」のデータを取得し、ファイルに追記しました。
#    2.24秒待機します...
#
# --- 1062/1076件目を処理中: https://www.saketry.com/113443.html ---
# ○ 「コッツウォルズ  ハーベスト・シリーズ No.3 アンバーメドウ シングルモルトウイスキー 51.6% 700mlコッツウォルズ」のデータを取得し、ファイルに追記しました。
#    3.22秒待機します...
#
# --- 1063/1076件目を処理中: https://www.saketry.com/113444.html ---
# ○ 「アードベッグ 2007 16年 スコッチモルト販売45周年記念ボトル 54.1% 700mlザ・モルトマン」のデータを取得し、ファイルに追記しました。
#    3.43秒待機します...
#
# --- 1064/1076件目を処理中: https://www.saketry.com/113445.html ---
# ○ 「ベンリネス 2010 14年 リフィル シェリーカスク 58.2% 700mlザ・モルトマン」のデータを取得し、ファイルに追記しました。
#    3.04秒待機します...
#
# --- 1065/1076件目を処理中: https://www.saketry.com/113452.html ---
# ○ 「コッツウォルズ シングルモルトウイスキー 母の日限定ラッピング 46% 200mlコッツウォルズ」のデータを取得し、ファイルに追記しました。
#    3.51秒待機します...
#
# --- 1066/1076件目を処理中: https://www.saketry.com/113467.html ---
# ○ 「MARS The Y.A. #04 50％ 700mlMARS The.Y.A.」のデータを取得し、ファイルに追記しました。
#    2.75秒待機します...
#
# --- 1067/1076件目を処理中: https://www.saketry.com/113468.html ---
# ○ 「ザ・ヒーラック シャトー・ビアック シングルモルトウイスキー 50% 700mlアイル・オブ・ハリス」のデータを取得し、ファイルに追記しました。
#    3.87秒待機します...
#
# --- 1068/1076件目を処理中: https://www.saketry.com/113472.html ---
# ○ 「リンクウッド 2009 13年 バーボンカスク 51.3％ 700mlザ・テイスター」のデータを取得し、ファイルに追記しました。
#    3.18秒待機します...
#
# --- 1069/1076件目を処理中: https://www.saketry.com/208525.html ---
# ○ 「マルス 津貫ニューポット ノンピーテッド 2016 60% 250ml」のデータを取得し、ファイルに追記しました。
#    3.29秒待機します...
#
# --- 1070/1076件目を処理中: https://www.saketry.com/208734.html ---
# ○ 「ホワイト ドッグ マッシュ #1 62.5% 375mlバッファロートレース」のデータを取得し、ファイルに追記しました。
#    2.17秒待機します...
#
# --- 1071/1076件目を処理中: https://www.saketry.com/41-03.html ---
# ○ 「コーキゲン シングルモルト」のデータを取得し、ファイルに追記しました。
#    2.45秒待機します...
#
# --- 1072/1076件目を処理中: https://www.saketry.com/600205.html ---
# ○ 「レベルイェル チェリー バーボンリキュール  35% 750mlREBEL YELL」のデータを取得し、ファイルに追記しました。
#    2.07秒待機します...
#
# --- 1073/1076件目を処理中: https://www.saketry.com/ob03-2019.html ---
# ○ 「Secret Speyside Distillery(シークレット スペイサイド ディスティラリー) 1994 24年 49.3%」のデータを取得し、ファイルに追記しました。
#    2.32秒待機します...
#
# --- 1074/1076件目を処理中: https://www.saketry.com/single-barrel.html ---
# ○ 「ギャリソン･ブラザーズ　シングルバレル」のデータを取得し、ファイルに追記しました。
#    3.65秒待機します...
#
# --- 1075/1076件目を処理中: https://www.saketry.com/straight.html ---
# ○ 「ギャリソン･ブラザーズ　ストレート」のデータを取得し、ファイルに追記しました。
#    3.14秒待機します...
#
# --- 1076/1076件目を処理中: https://www.saketry.com/thompson-bros-2010-10-529-700mlbr-thompson-bros-clone-.html ---
# ○ 「THOMPSON BROS. カリラ 2010 10年 52.9% 700MLTHOMPSON BROS.」のデータを取得し、ファイルに追記しました。
#    3.36秒待機します...
#
# --- 全ての処理が完了しました！ ---
# 'output\whisky_dataset_final.csv'にデータが保存されています。

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
from pathlib import Path

# --- プログラムの本体 ---
# 1. URLリストが書かれたファイル名を指定
url_file = 'whisky_urls.txt' 

# 2. 【ループ前】抽出した全データを格納するための空のリストを用意
all_whisky_data = []

# 3. URLリストを読み込む
try:
    with open(url_file, 'r', encoding='utf-8') as f:
        urls = [line.strip() for line in f if line.strip()]
    print(f"--- {len(urls)}件のURLを読み込みました。詳細情報の収集を開始します。 ---")
except FileNotFoundError:
    print(f"エラー: '{url_file}' が見つかりません。先に`url_collector.py`を実行してください。")
    exit()

# 4. 【ループ中】各URLを順番に処理
for i, url in enumerate(urls):
    print(f"\n--- {i+1}/{len(urls)}件目を処理中: {url} ---")
    
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')

        # ▼ 各情報の抽出ロジック
        product_name_tag = soup.find('h1', class_='ty-product-block-title')
        product_name = product_name_tag.find('bdi').text.strip() if product_name_tag else '商品名不明'

        description_area = soup.find('div', id='content_description')
        tasting_note_parts = []
        if description_area:
            paragraphs = description_area.find_all('p')
            for p in paragraphs:
                text = p.text.strip()
                if text.startswith(('香り：', '味わい：', 'フィニッシュ：', 'アロマ：', 'フレーバー：')):
                    tasting_note_parts.append(text)
        tasting_note = '\n'.join(tasting_note_parts)

        spec_data = {}
        spec_area = soup.find('div', id='content_features')
        if spec_area:
            spec_items = spec_area.find_all('div', class_='ty-product-feature')
            for item in spec_items:
                key_tag = item.find('span', class_='ty-product-feature__label')
                value_tag = item.find('div', class_='ty-product-feature__value')
                if key_tag and value_tag:
                    key = key_tag.text.strip().replace(':', '')
                    value = value_tag.text.strip()
                    spec_data[key] = value
        
        # １ページ分の全データを一つの辞書にまとめる
        single_whisky_data = {
            '商品名': product_name,
            'テイスティングノート': tasting_note,
            'URL': url,
            **spec_data
        }
        
        # ★★★ データをメモリ上のリストに溜め込む ★★★
        all_whisky_data.append(single_whisky_data)
        print(f"○ 「{product_name}」のデータを正常に取得しました。")

    except Exception as e:
        print(f"× エラーが発生したため、このURLの処理をスキップします: {e}")
    
    wait_time = random.uniform(2, 4)
    print(f"   {wait_time:.2f}秒待機します...")
    time.sleep(wait_time)

# 5. 【ループ後】全データが溜まったリストを、一括でCSVファイルに保存
if all_whisky_data:
    # ★★★ ここでPandasがカラムを自動で揃えてくれる ★★★
    df = pd.DataFrame(all_whisky_data)
    
    output_dir = Path('output')
    output_dir.mkdir(parents=True, exist_ok=True)
    file_path = output_dir / 'whisky_dataset_final.csv'
    
    df.to_csv(file_path, index=False, encoding='utf-8-sig')
    
    print(f"\n--- 全ての処理が完了しました！ ---")
    print(f"{len(all_whisky_data)}件のデータを抽出し、'{file_path}'に保存しました。")
else:
    print("\nデータを一件も抽出できませんでした。")
# Out:
# --- 1076件のURLを読み込みました。詳細情報の収集を開始します。 ---
#
# --- 1/1076件目を処理中: https://www.saketry.com/103120.html ---
# ○ 「クラシック オブ アイラ (10L樽)」のデータを正常に取得しました。
#    3.83秒待機します...
#
# --- 2/1076件目を処理中: https://www.saketry.com/103237.html ---
# ○ 「ハイランド・クラシック (10L樽)」のデータを正常に取得しました。
#    2.34秒待機します...
#
# --- 3/1076件目を処理中: https://www.saketry.com/105095.html ---
# ○ 「クラシック オブ アイラ 58% 700mlスコッチモルトセールス」のデータを正常に取得しました。
#    2.27秒待機します...
#
# --- 4/1076件目を処理中: https://www.saketry.com/110066.html ---
# ○ 「タリバーディン 1991 19年 46％ザ・モルトマン」のデータを正常に取得しました。
#    2.85秒待機します...
#
# --- 5/1076件目を処理中: https://www.saketry.com/110371.html ---
# ○ 「燻酒 アイラ シングルモルト 50% 700ml燻酒」のデータを正常に取得しました。
#    2.08秒待機します...
#
# --- 6/1076件目を処理中: https://www.saketry.com/110408.html ---
# ○ 「ミズナラウッドリザーブ 46%イチローズモルト」のデータを正常に取得しました。
#    2.85秒待機します...
#
# --- 7/1076件目を処理中: https://www.saketry.com/110409.html ---
# ○ 「イチローズモルトワインウッドリザーブ 46% 700mlイチローズモルト」のデータを正常に取得しました。
#    2.34秒待機します...
#
# --- 8/1076件目を処理中: https://www.saketry.com/110484.html ---
# ○ 「アラン ポートカスク・フィニッシュ 50%」のデータを正常に取得しました。
#    3.84秒待機します...
#
# --- 9/1076件目を処理中: https://www.saketry.com/110503.html ---
# ○ 「ティーリング シングルモルト 46% 700mlティーリング」のデータを正常に取得しました。
#    3.37秒待機します...
#
# --- 10/1076件目を処理中: https://www.saketry.com/110540.html ---
# ○ 「アードレア　2009　5年　50.4%リキッドサン」のデータを正常に取得しました。
#    3.75秒待機します...
#
# --- 11/1076件目を処理中: https://www.saketry.com/110545.html ---
# ○ 「コーヴァル バーボン 47% 750mlコーヴァル」のデータを正常に取得しました。
#    3.69秒待機します...
#
# --- 12/1076件目を処理中: https://www.saketry.com/110546.html ---
# ○ 「コーヴァル フォーグレーン 47% 750mlコーヴァル」のデータを正常に取得しました。
#    2.97秒待機します...
#
# --- 13/1076件目を処理中: https://www.saketry.com/110547.html ---
# ○ 「コーヴァル　ミレット　40%」のデータを正常に取得しました。
#    2.64秒待機します...
#
# --- 14/1076件目を処理中: https://www.saketry.com/110548.html ---
# ○ 「コーヴァル　ライ　40%」のデータを正常に取得しました。
#    3.23秒待機します...
#
# --- 15/1076件目を処理中: https://www.saketry.com/110574.html ---
# ○ 「アムルット　シングルモルト　ミニチュア　46%アムルット・ディスティラリー」のデータを正常に取得しました。
#    3.22秒待機します...
#
# --- 16/1076件目を処理中: https://www.saketry.com/110575.html ---
# ○ 「アムルット　フュージョン　シングルモルト　ミニチュア　50%アムルット・ディスティラリー」のデータを正常に取得しました。
#    2.30秒待機します...
#
# --- 17/1076件目を処理中: https://www.saketry.com/110576.html ---
# ○ 「アムルット　ピーテッド　シングルモルト　ミニチュア　46%アムルット・ディスティラリー」のデータを正常に取得しました。
#    3.99秒待機します...
#
# --- 18/1076件目を処理中: https://www.saketry.com/110588.html ---
# ○ 「トマーティン　クアトロ　46%　（750ml×4本）」のデータを正常に取得しました。
#    3.02秒待機します...
#
# --- 19/1076件目を処理中: https://www.saketry.com/110614.html ---
# ○ 「ディーンストン　2006　8年　シェリーフィニッシュ　56.5%カスク＆シスル」のデータを正常に取得しました。
#    3.01秒待機します...
#
# --- 20/1076件目を処理中: https://www.saketry.com/110624.html ---
# ○ 「ウシュクベ・リザーブ　43%トゥエンティオークス」のデータを正常に取得しました。
#    3.79秒待機します...
#
# --- 21/1076件目を処理中: https://www.saketry.com/110708.html ---
# ○ 「ウルフバーン ノースランド 46% 700mlウルフバーン」のデータを正常に取得しました。
#    2.12秒待機します...
#
# --- 22/1076件目を処理中: https://www.saketry.com/110740.html ---
# ○ 「キルホーマン　サナイグ　46%」のデータを正常に取得しました。
#    3.16秒待機します...
#
# --- 23/1076件目を処理中: https://www.saketry.com/110810.html ---
# ○ 「トマーティン 12年 43% 700mlトマーティン」のデータを正常に取得しました。
#    2.80秒待機します...
#
# --- 24/1076件目を処理中: https://www.saketry.com/110833.html ---
# ○ 「ウルフバーン オーロラ 46% 700mlウルフバーン」のデータを正常に取得しました。
#    3.47秒待機します...
#
# --- 25/1076件目を処理中: https://www.saketry.com/110890.html ---
# ○ 「アラン ソーテルヌ・カスク・フィニッシュ 50%」のデータを正常に取得しました。
#    2.86秒待機します...
#
# --- 26/1076件目を処理中: https://www.saketry.com/110891.html ---
# ○ 「アラン　マクリー・ムーア　46%」のデータを正常に取得しました。
#    3.98秒待機します...
#
# --- 27/1076件目を処理中: https://www.saketry.com/110892.html ---
# ○ 「アラン　マクリー・ムーア　カスクストレングス　58.2%」のデータを正常に取得しました。
#    3.03秒待機します...
#
# --- 28/1076件目を処理中: https://www.saketry.com/110896.html ---
# ○ 「トマーティン　1995　21年　オロロソ・フィニッシュ　46%」のデータを正常に取得しました。
#    3.80秒待機します...
#
# --- 29/1076件目を処理中: https://www.saketry.com/110897.html ---
# ○ 「トマーティン　ク・ボカン　2005　11年　リミテッド・エディション　46%」のデータを正常に取得しました。
#    3.00秒待機します...
#
# --- 30/1076件目を処理中: https://www.saketry.com/110974.html ---
# ○ 「トマーティン　カスクストレングス　57.5%」のデータを正常に取得しました。
#    2.97秒待機します...
#
# --- 31/1076件目を処理中: https://www.saketry.com/110975.html ---
# ○ 「トマーティン　18年　46%」のデータを正常に取得しました。
#    3.99秒待機します...
#
# --- 32/1076件目を処理中: https://www.saketry.com/110995.html ---
# ○ 「ブレンデッド モルト スコッチ ウイスキー キメラ Cask ref:CH1-2016 46% 700mlブラックアダー」のデータを正常に取得しました。
#    3.90秒待機します...
#
# --- 33/1076件目を処理中: https://www.saketry.com/111007.html ---
# ○ 「ピートリーク エンバース EMB3 59%ブラックアダー」のデータを正常に取得しました。
#    2.56秒待機します...
#
# --- 34/1076件目を処理中: https://www.saketry.com/111020.html ---
# ○ 「キルホーマン ロッホゴルム 2017リリース 46% 700ml キルホーマン」のデータを正常に取得しました。
#    2.27秒待機します...
#
# --- 35/1076件目を処理中: https://www.saketry.com/111060.html ---
# ○ 「ウルフバーン モーヴェン 46% 700mlウルフバーン」のデータを正常に取得しました。
#    3.09秒待機します...
#
# --- 36/1076件目を処理中: https://www.saketry.com/111145.html ---
# ○ 「トマーティン 2001 16年 52.5%ザ・クーパーズ・チョイス」のデータを正常に取得しました。
#    2.26秒待機します...
#
# --- 37/1076件目を処理中: https://www.saketry.com/111151.html ---
# ○ 「ウシュクベ  カスク プルーフ 10L樽 50%トゥエンティオークス」のデータを正常に取得しました。
#    3.67秒待機します...
#
# --- 38/1076件目を処理中: https://www.saketry.com/111161.html ---
# ○ 「トマーティン ファイブ ヴァーチューズ ウッド 46% 700mlトマーティン」のデータを正常に取得しました。
#    2.46秒待機します...
#
# --- 39/1076件目を処理中: https://www.saketry.com/111162.html ---
# ○ 「トマーティン ファイブ ヴァーチューズ ファイア 46% 700mlトマーティン」のデータを正常に取得しました。
#    3.61秒待機します...
#
# --- 40/1076件目を処理中: https://www.saketry.com/111170.html ---
# ○ 「ウルフバーン Batch No.270 46%」のデータを正常に取得しました。
#    2.73秒待機します...
#
# --- 41/1076件目を処理中: https://www.saketry.com/111186.html ---
# ○ 「ウルフバーン キルヴァー 3 50%」のデータを正常に取得しました。
#    3.15秒待機します...
#
# --- 42/1076件目を処理中: https://www.saketry.com/111190.html ---
# ○ 「ベンリネス 2001 15年 46% 700mlザ・クーパーズ・チョイス」のデータを正常に取得しました。
#    3.31秒待機します...
#
# --- 43/1076件目を処理中: https://www.saketry.com/111198.html ---
# ○ 「ブナハーブン 2005 12年 48%クランデニー」のデータを正常に取得しました。
#    3.33秒待機します...
#
# --- 44/1076件目を処理中: https://www.saketry.com/111199.html ---
# ○ 「フェッターケアン 2007 10年 48%クランデニー」のデータを正常に取得しました。
#    2.95秒待機します...
#
# --- 45/1076件目を処理中: https://www.saketry.com/111200.html ---
# ○ 「グレンバーギー 2009 7年 48%クランデニー」のデータを正常に取得しました。
#    3.67秒待機します...
#
# --- 46/1076件目を処理中: https://www.saketry.com/111201.html ---
# ○ 「スペイバーン 2008 8年 48%クランデニー」のデータを正常に取得しました。
#    2.56秒待機します...
#
# --- 47/1076件目を処理中: https://www.saketry.com/111211.html ---
# ○ 「ポール・ジョン エディテッド 46% 700mlポール・ジョン」のデータを正常に取得しました。
#    2.47秒待機します...
#
# --- 48/1076件目を処理中: https://www.saketry.com/111212.html ---
# ○ 「ポール・ジョン ボールド 46% 700mlポール・ジョン」のデータを正常に取得しました。
#    2.84秒待機します...
#
# --- 49/1076件目を処理中: https://www.saketry.com/111213.html ---
# ○ 「ポール・ジョン クラシック 55.2% 700mlポール・ジョン」のデータを正常に取得しました。
#    3.12秒待機します...
#
# --- 50/1076件目を処理中: https://www.saketry.com/111214.html ---
# ○ 「ポール・ジョン ピーテッド 55.5% 700mlポール・ジョン」のデータを正常に取得しました。
#    3.97秒待機します...
#
# --- 51/1076件目を処理中: https://www.saketry.com/111216.html ---
# ○ 「キルホーマン 2011 6年 フレッシュ・バーボン 58% スコッチモルトセレクション」のデータを正常に取得しました。
#    2.65秒待機します...
#
# --- 52/1076件目を処理中: https://www.saketry.com/111219.html ---
# ○ 「トマーティン ファイブ ヴァーチューズ ウォーター 46% 700mlトマーティン」のデータを正常に取得しました。
#    2.34秒待機します...
#
# --- 53/1076件目を処理中: https://www.saketry.com/111220.html ---
# ○ 「トマーティン ファイブ ヴァーチューズ メタル 46% 700mlトマーティン」のデータを正常に取得しました。
#    2.03秒待機します...
#
# --- 54/1076件目を処理中: https://www.saketry.com/111229.html ---
# ○ 「ダルユーイン 2007 10年 48%クランデニー」のデータを正常に取得しました。
#    2.22秒待機します...
#
# --- 55/1076件目を処理中: https://www.saketry.com/111247.html ---
# ○ 「トマーティン 14年 ポートカスク 46% 700mlトマーティン」のデータを正常に取得しました。
#    2.74秒待機します...
#
# --- 56/1076件目を処理中: https://www.saketry.com/111249.html ---
# ○ 「キルホーマン マキヤーベイ グラス１脚付きセット 46.0% 700ml」のデータを正常に取得しました。
#    3.60秒待機します...
#
# --- 57/1076件目を処理中: https://www.saketry.com/111253.html ---
# ○ 「ウルフバーン ラングスキップ 58% 700mlウルフバーン」のデータを正常に取得しました。
#    2.94秒待機します...
#
# --- 58/1076件目を処理中: https://www.saketry.com/111261.html ---
# ○ 「ウルフバーン ノースランド ミニチュア 46% 50mlウルフバーン」のデータを正常に取得しました。
#    3.48秒待機します...
#
# --- 59/1076件目を処理中: https://www.saketry.com/111262.html ---
# ○ 「ウルフバーン モーヴェン ミニチュア 46% 50mlウルフバーン」のデータを正常に取得しました。
#    3.12秒待機します...
#
# --- 60/1076件目を処理中: https://www.saketry.com/111275.html ---
# ○ 「ベンリネス 1997 16年 56.5% 700mlハートブラザーズ ファイネスト・コレクション」のデータを正常に取得しました。
#    2.51秒待機します...
#
# --- 61/1076件目を処理中: https://www.saketry.com/111283.html ---
# ○ 「ポール・ジョン カニャ 50%ポール・ジョン」のデータを正常に取得しました。
#    3.93秒待機します...
#
# --- 62/1076件目を処理中: https://www.saketry.com/111293.html ---
# ○ 「フェッターケアン 2007 11年 60.1%クランデニー」のデータを正常に取得しました。
#    2.45秒待機します...
#
# --- 63/1076件目を処理中: https://www.saketry.com/111294.html ---
# ○ 「ブナハーブン 2007 10年 57.5%クランデニー」のデータを正常に取得しました。
#    3.89秒待機します...
#
# --- 64/1076件目を処理中: https://www.saketry.com/111331.html ---
# ○ 「スペイサイド　ブレンデッド・モルト 46%　ザ・スピークイージー」のデータを正常に取得しました。
#    2.25秒待機します...
#
# --- 65/1076件目を処理中: https://www.saketry.com/111332.html ---
# ○ 「ローランド　ブレンデッド・モルト 46%ザ・スピークイージー」のデータを正常に取得しました。
#    2.59秒待機します...
#
# --- 66/1076件目を処理中: https://www.saketry.com/111346.html ---
# ○ 「モートラック 2007 11年 53.0%クランデニー」のデータを正常に取得しました。
#    3.66秒待機します...
#
# --- 67/1076件目を処理中: https://www.saketry.com/111349.html ---
# ○ 「ウルフバーン キルヴァー 4 50.0%」のデータを正常に取得しました。
#    2.21秒待機します...
#
# --- 68/1076件目を処理中: https://www.saketry.com/111351.html ---
# ○ 「グレンアラヒー 12年 46% 700ml」のデータを正常に取得しました。
#    3.81秒待機します...
#
# --- 69/1076件目を処理中: https://www.saketry.com/111361.html ---
# ○ 「ハイランド ブレンデッド・モルト 46% 700mlザ・スピークイージー」のデータを正常に取得しました。
#    3.30秒待機します...
#
# --- 70/1076件目を処理中: https://www.saketry.com/111362.html ---
# ○ 「アイランズ　ブレンデッド・モルト 46%ザ・スピークイージー」のデータを正常に取得しました。
#    2.82秒待機します...
#
# --- 71/1076件目を処理中: https://www.saketry.com/111405.html ---
# ○ 「クレイゲラキ 2010 8年 48% 700mlクランデニー」のデータを正常に取得しました。
#    2.52秒待機します...
#
# --- 72/1076件目を処理中: https://www.saketry.com/111410.html ---
# ○ 「オスロスク スペイサイド デザート バニュルス フィニッシュ 58.5%ザ・クーパーズチョイス」のデータを正常に取得しました。
#    2.61秒待機します...
#
# --- 73/1076件目を処理中: https://www.saketry.com/111425.html ---
# ○ 「アイル オブ ジュラ 1998 20年 SMS 40周年記念 52.2%スコッチモルト販売」のデータを正常に取得しました。
#    2.97秒待機します...
#
# --- 74/1076件目を処理中: https://www.saketry.com/111435.html ---
# ○ 「アードモア 1998 20年 51.6%ザ・シングルモルツ・オブ・スコットランド」のデータを正常に取得しました。
#    2.40秒待機します...
#
# --- 75/1076件目を処理中: https://www.saketry.com/111442.html ---
# ○ 「プロメテウス 28年 リミテッド・リリース 53.0%プロメテウス」のデータを正常に取得しました。
#    3.71秒待機します...
#
# --- 76/1076件目を処理中: https://www.saketry.com/111443.html ---
# ○ 「1770 グラスゴー シングルモルト リリース No.2 46%」のデータを正常に取得しました。
#    2.22秒待機します...
#
# --- 77/1076件目を処理中: https://www.saketry.com/111444.html ---
# ○ 「リトルミル 1988 30年 シェリー・バット 51.1% 700mlハートブラザーズ レジェンズ」のデータを正常に取得しました。
#    3.19秒待機します...
#
# --- 78/1076件目を処理中: https://www.saketry.com/111451.html ---
# ○ 「ダルモア 2007 11年 ポートパイプ 55.1% 700mlハートブラザーズ ファイネット コレクション」のデータを正常に取得しました。
#    2.74秒待機します...
#
# --- 79/1076件目を処理中: https://www.saketry.com/111452.html ---
# ○ 「ダルモア 2007 11年 シェリーバット 55.6% 700mlハートブラザーズ ファイネット コレクション」のデータを正常に取得しました。
#    3.65秒待機します...
#
# --- 80/1076件目を処理中: https://www.saketry.com/111453.html ---
# ○ 「ダルモア 2007 11年 57.5% 700mlハートブラザーズ ファイネット コレクション」のデータを正常に取得しました。
#    2.79秒待機します...
#
# --- 81/1076件目を処理中: https://www.saketry.com/111454.html ---
# ○ 「レダイグ 2005 11年 シェリーバット 56.5%ハートブラザーズ ファイネスト コレクション」のデータを正常に取得しました。
#    2.73秒待機します...
#
# --- 82/1076件目を処理中: https://www.saketry.com/111455.html ---
# ○ 「グレントファース 1996 22年 50.2% 700mlハートブラザーズ ファイネット コレクション」のデータを正常に取得しました。
#    2.60秒待機します...
#
# --- 83/1076件目を処理中: https://www.saketry.com/111462.html ---
# ○ 「カンバス 1990 28年 トリプルカスク 48.3%ザ・グレーンマン」のデータを正常に取得しました。
#    3.33秒待機します...
#
# --- 84/1076件目を処理中: https://www.saketry.com/111463.html ---
# ○ 「ガーヴァン 1993 25年 ポート・フィニッシュ 55.5% 700mlザ・グレーンマン」のデータを正常に取得しました。
#    3.62秒待機します...
#
# --- 85/1076件目を処理中: https://www.saketry.com/111477.html ---
# ○ 「シングルモルト駒ケ岳 リミテッド・エディション 2019 48%」のデータを正常に取得しました。
#    2.14秒待機します...
#
# --- 86/1076件目を処理中: https://www.saketry.com/111484.html ---
# ○ 「宗像教授ラベル・スペイサイドリージョン 1979 38年 42.8％」のデータを正常に取得しました。
#    2.42秒待機します...
#
# --- 87/1076件目を処理中: https://www.saketry.com/111488.html ---
# ○ 「アードモア 1999 20年 ジョイント ウィズ ドランケンマスター 53.5%ディスティラリーズ・コレクション」のデータを正常に取得しました。
#    3.64秒待機します...
#
# --- 88/1076件目を処理中: https://www.saketry.com/111489.html ---
# ○ 「ブナハーブン ヘヴィリーピーテッド  ハニースモーク 56.6%ザ・クーパーズチョイス」のデータを正常に取得しました。
#    3.26秒待機します...
#
# --- 89/1076件目を処理中: https://www.saketry.com/111490.html ---
# ○ 「シークレット オークニー 2009 10年 58.0%ザ・クーパーズチョイス」のデータを正常に取得しました。
#    3.20秒待機します...
#
# --- 90/1076件目を処理中: https://www.saketry.com/111491.html ---
# ○ 「グレンギリー 2011 8年 マデイラ・フィニッシュ 53.5%ザ・クーパーズチョイス」のデータを正常に取得しました。
#    3.26秒待機します...
#
# --- 91/1076件目を処理中: https://www.saketry.com/111492.html ---
# ○ 「オールドロスデュー 1994 25年 バーボン・フィニッシュ 48.5%ザ・クーパーズチョイス」のデータを正常に取得しました。
#    3.41秒待機します...
#
# --- 92/1076件目を処理中: https://www.saketry.com/111493.html ---
# ○ 「キルノートン リオハ・カスク 54.0%ザ・クーパーズチョイス」のデータを正常に取得しました。
#    2.71秒待機します...
#
# --- 93/1076件目を処理中: https://www.saketry.com/111494.html ---
# ○ 「キャメロンブリッジ 1984 35年 44.5%ザ・クーパーズチョイス」のデータを正常に取得しました。
#    3.88秒待機します...
#
# --- 94/1076件目を処理中: https://www.saketry.com/111497.html ---
# ○ 「ウルフバーン スコッチモルト販売 40周年記念ボトル　50％ウルフバーン」のデータを正常に取得しました。
#    3.87秒待機します...
#
# --- 95/1076件目を処理中: https://www.saketry.com/111499.html ---
# ○ 「バルメナック 2008 11年 シェリーバット 56.5% 700mlハートブラザーズ ファイネット コレクション」のデータを正常に取得しました。
#    3.63秒待機します...
#
# --- 96/1076件目を処理中: https://www.saketry.com/111500.html ---
# ○ 「プルトニー 2006 13年 シェリーバット 53.6% 700mlハートブラザーズ ファイネスト・コレクション」のデータを正常に取得しました。
#    3.25秒待機します...
#
# --- 97/1076件目を処理中: https://www.saketry.com/111502.html ---
# ○ 「キングスバーンズ ドリーム・トゥ・ドラム シングルモルト 46％ 700mlウィームス」のデータを正常に取得しました。
#    2.81秒待機します...
#
# --- 98/1076件目を処理中: https://www.saketry.com/111504.html ---
# ○ 「グレンアラヒー 1990 29年 オロロソシェリーパンチョン 58.2％グレンアラヒー」のデータを正常に取得しました。
#    2.37秒待機します...
#
# --- 99/1076件目を処理中: https://www.saketry.com/111505.html ---
# ○ 「アードベッグ 2005 13年 バッチ17 48.4%ブティックウイスキー」のデータを正常に取得しました。
#    3.07秒待機します...
#
# --- 100/1076件目を処理中: https://www.saketry.com/111506.html ---
# ○ 「アラン 22年 バッチ8 48.4%ブティックウイスキー」のデータを正常に取得しました。
#    2.84秒待機します...
#
# --- 101/1076件目を処理中: https://www.saketry.com/111507.html ---
# ○ 「フェッターケアン 21年 バッチ3 48.6%ブティックウイスキー」のデータを正常に取得しました。
#    2.77秒待機します...
#
# --- 102/1076件目を処理中: https://www.saketry.com/111508.html ---
# ○ 「ブルックラディ 13年 バッチ11 47.6%ブティックウイスキー」のデータを正常に取得しました。
#    2.43秒待機します...
#
# --- 103/1076件目を処理中: https://www.saketry.com/111509.html ---
# ○ 「アラン マルサラカスク・フィニッシュ 2018 リミテッドエディション 50%アラン」のデータを正常に取得しました。
#    3.38秒待機します...
#
# --- 104/1076件目を処理中: https://www.saketry.com/111510.html ---
# ○ 「アラン マスター・オブ・ディスティリング２ 12年 51.8%アラン」のデータを正常に取得しました。
#    2.34秒待機します...
#
# --- 105/1076件目を処理中: https://www.saketry.com/111511.html ---
# ○ 「アラン コート・ロティカスク・フィニッシュ 2019 リミテッドエディション 50%アラン」のデータを正常に取得しました。
#    2.34秒待機します...
#
# --- 106/1076件目を処理中: https://www.saketry.com/111513.html ---
# ○ 「ティーリング シングルポットスティル 46％ 700ml」のデータを正常に取得しました。
#    2.70秒待機します...
#
# --- 107/1076件目を処理中: https://www.saketry.com/111514.html ---
# ○ 「コンパスボックス オーク・クロス 43％コンパスボックス」のデータを正常に取得しました。
#    3.64秒待機します...
#
# --- 108/1076件目を処理中: https://www.saketry.com/111515.html ---
# ○ 「コンパスボックス ザ・ストーリー・オブ・ザ・スパニアード 43%  バッチナンバー 2018-Bコンパスボックス」のデータを正常に取得しました。
#    2.39秒待機します...
#
# --- 109/1076件目を処理中: https://www.saketry.com/111522.html ---
# ○ 「ブナハーブン 1987 31年 "Raisin D'Etre" 44.7%ウィームス」のデータを正常に取得しました。
#    4.00秒待機します...
#
# --- 110/1076件目を処理中: https://www.saketry.com/111524.html ---
# ○ 「グレングラント 1995 23年 "Summer Sipping" 46.0%ウィームス」のデータを正常に取得しました。
#    2.10秒待機します...
#
# --- 111/1076件目を処理中: https://www.saketry.com/111530.html ---
# ○ 「スパイスキング ブレンデッドモルト 46%ウィームス」のデータを正常に取得しました。
#    2.56秒待機します...
#
# --- 112/1076件目を処理中: https://www.saketry.com/111531.html ---
# ○ 「長濱蒸溜所 ニューメイク 59% 500ml長濱蒸溜所」のデータを正常に取得しました。
#    3.47秒待機します...
#
# --- 113/1076件目を処理中: https://www.saketry.com/111532.html ---
# ○ 「ピート・チムニー ブレンデッドモルト 46% 700mlウィームス」のデータを正常に取得しました。
#    2.82秒待機します...
#
# --- 114/1076件目を処理中: https://www.saketry.com/111533.html ---
# ○ 「ブレアソール 1991 24年 Nuts Pears 46%ウィームス」のデータを正常に取得しました。
#    3.73秒待機します...
#
# --- 115/1076件目を処理中: https://www.saketry.com/111534.html ---
# ○ 「ブナハーブン 1991 27年 Toasted Brioche 46%ウィームス」のデータを正常に取得しました。
#    2.07秒待機します...
#
# --- 116/1076件目を処理中: https://www.saketry.com/111535.html ---
# ○ 「ブナハーブン 1988 30年 Antique Pomander 46%ウィームス」のデータを正常に取得しました。
#    3.73秒待機します...
#
# --- 117/1076件目を処理中: https://www.saketry.com/111537.html ---
# ○ 「ウルフバーン キルヴァー 5 50%キルヴァー・シリーズ」のデータを正常に取得しました。
#    3.80秒待機します...
#
# --- 118/1076件目を処理中: https://www.saketry.com/111546.html ---
# ○ 「キン肉マン正義超人ラベル・ブレンデッドモルト2001 17年 46.5%」のデータを正常に取得しました。
#    2.44秒待機します...
#
# --- 119/1076件目を処理中: https://www.saketry.com/111550.html ---
# ○ 「おやすみカラスまた来てね。ラベル・バーンサイド 1996 22年 50.4％」のデータを正常に取得しました。
#    2.97秒待機します...
#
# --- 120/1076件目を処理中: https://www.saketry.com/111562.html ---
# ○ 「アランバレルリザーブ 43% 700ml」のデータを正常に取得しました。
#    3.36秒待機します...
#
# --- 121/1076件目を処理中: https://www.saketry.com/111563.html ---
# ○ 「アランシェリーカスク 55.8% 700ml」のデータを正常に取得しました。
#    3.49秒待機します...
#
# --- 122/1076件目を処理中: https://www.saketry.com/111564.html ---
# ○ 「アランクウォーターカスク 56.2% 700ml」のデータを正常に取得しました。
#    2.64秒待機します...
#
# --- 123/1076件目を処理中: https://www.saketry.com/111566.html ---
# ○ 「アラン 18年 46%アラン」のデータを正常に取得しました。
#    3.05秒待機します...
#
# --- 124/1076件目を処理中: https://www.saketry.com/111569.html ---
# ○ 「リンクウッド 2010 9年 トーニーポートカスク 56%クーパーズチョイス」のデータを正常に取得しました。
#    2.68秒待機します...
#
# --- 125/1076件目を処理中: https://www.saketry.com/111571.html ---
# ○ 「オスロスク スペイサイドデザート モスカテルフィニッシュ 58.5%クーパーズチョイス」のデータを正常に取得しました。
#    2.55秒待機します...
#
# --- 126/1076件目を処理中: https://www.saketry.com/111573.html ---
# ○ 「インペリアル 1995 48.2%シングルモルツオブスコットランド」のデータを正常に取得しました。
#    2.13秒待機します...
#
# --- 127/1076件目を処理中: https://www.saketry.com/111583.html ---
# ○ 「ウィリアムソン ラフロイグ 2012 7年 55.1%ザ・モルトマン」のデータを正常に取得しました。
#    3.17秒待機します...
#
# --- 128/1076件目を処理中: https://www.saketry.com/111584.html ---
# ○ 「ベンネヴィス 1997 22年 52.0%ザ・モルトマン」のデータを正常に取得しました。
#    3.54秒待機します...
#
# --- 129/1076件目を処理中: https://www.saketry.com/111585.html ---
# ○ 「ヴァイタルスパーク 2013 5年 54.9%メドウサイド」のデータを正常に取得しました。
#    3.02秒待機します...
#
# --- 130/1076件目を処理中: https://www.saketry.com/111586.html ---
# ○ 「レダイグ 2007 12年 52.7%ザ・モルトマン」のデータを正常に取得しました。
#    3.06秒待機します...
#
# --- 131/1076件目を処理中: https://www.saketry.com/111587.html ---
# ○ 「リンクウッド 2007 11年 52.1%ザ・モルトマン」のデータを正常に取得しました。
#    2.90秒待機します...
#
# --- 132/1076件目を処理中: https://www.saketry.com/111588.html ---
# ○ 「エクスカリバー 1972 45年 42.2%メドウサイド」のデータを正常に取得しました。
#    2.70秒待機します...
#
# --- 133/1076件目を処理中: https://www.saketry.com/111589.html ---
# ○ 「ベンネヴィス 2005 14年 53.9%ザ・モルトマン」のデータを正常に取得しました。
#    3.21秒待機します...
#
# --- 134/1076件目を処理中: https://www.saketry.com/111590.html ---
# ○ 「シークレットスペイサイド 2006 12年 53.9%ザ・モルトマン」のデータを正常に取得しました。
#    3.01秒待機します...
#
# --- 135/1076件目を処理中: https://www.saketry.com/111594.html ---
# ○ 「サラリーマン金太郎ラベル・シークレットスペイサイドモルト1994」のデータを正常に取得しました。
#    3.47秒待機します...
#
# --- 136/1076件目を処理中: https://www.saketry.com/111596.html ---
# ○ 「ワンダーカクテル シークレット・アイラ 2013 5年 ポートウッド&ワンダーカクテルvol.1セット」のデータを正常に取得しました。
#    3.61秒待機します...
#
# --- 137/1076件目を処理中: https://www.saketry.com/111599.html ---
# ○ 「インチマリン 2009 9年 57.2%」のデータを正常に取得しました。
#    2.17秒待機します...
#
# --- 138/1076件目を処理中: https://www.saketry.com/111609.html ---
# ○ 「カリラ 2011 8年  59.4%クランデニー」のデータを正常に取得しました。
#    3.57秒待機します...
#
# --- 139/1076件目を処理中: https://www.saketry.com/111611.html ---
# ○ 「シークレットオークニー 2009 10年 57.5%クーパーズチョイス」のデータを正常に取得しました。
#    3.05秒待機します...
#
# --- 140/1076件目を処理中: https://www.saketry.com/111612.html ---
# ○ 「ウィリアムソン 2005 14年 マスカットフィニッシュ 54.0%ザ・クーパーズ・チョイス」のデータを正常に取得しました。
#    2.55秒待機します...
#
# --- 141/1076件目を処理中: https://www.saketry.com/111613.html ---
# ○ 「グレンアラヒー 2011 8年 モスカテルフィニッシュ 59%クーパーズチョイス」のデータを正常に取得しました。
#    2.74秒待機します...
#
# --- 142/1076件目を処理中: https://www.saketry.com/111614.html ---
# ○ 「グレンロセス 2007 12年 カディラック フィニッシュ 56.3%クーパーズチョイス」のデータを正常に取得しました。
#    3.98秒待機します...
#
# --- 143/1076件目を処理中: https://www.saketry.com/111615.html ---
# ○ 「ストラスクライド 1993 26年 52.5%クーパーズチョイス」のデータを正常に取得しました。
#    2.38秒待機します...
#
# --- 144/1076件目を処理中: https://www.saketry.com/111616.html ---
# ○ 「ポートダンダス 1999 20年 バーボンフィニッシュクーパーズチョイス」のデータを正常に取得しました。
#    3.22秒待機します...
#
# --- 145/1076件目を処理中: https://www.saketry.com/111617.html ---
# ○ 「ロイヤルブラックラ 2010 9年 46% 700mlハートブラザーズ ファイネット コレクション」のデータを正常に取得しました。
#    3.53秒待機します...
#
# --- 146/1076件目を処理中: https://www.saketry.com/111618.html ---
# ○ 「アベラワー 2010 9年 46% 700mlハートブラザーズ ファイネット コレクション」のデータを正常に取得しました。
#    3.20秒待機します...
#
# --- 147/1076件目を処理中: https://www.saketry.com/111619.html ---
# ○ 「グレンバーギー 2010 9年 46% 700mlハートブラザーズ ファイネット コレクション」のデータを正常に取得しました。
#    3.82秒待機します...
#
# --- 148/1076件目を処理中: https://www.saketry.com/111620.html ---
# ○ 「ティーニニック 2007 11年 58.1% 700mlハートブラザーズ ファイネット コレクション」のデータを正常に取得しました。
#    2.95秒待機します...
#
# --- 149/1076件目を処理中: https://www.saketry.com/111621.html ---
# ○ 「タリバーディン 2005 13年 53.7% 700mlハートブラザーズ ファイネット コレクション」のデータを正常に取得しました。
#    2.08秒待機します...
#
# --- 150/1076件目を処理中: https://www.saketry.com/111622.html ---
# ○ 「モートラック 1991 24年 シェリーバット 51.6% 700mlハートブラザーズ ファイネット コレクション」のデータを正常に取得しました。
#    2.85秒待機します...
#
# --- 151/1076件目を処理中: https://www.saketry.com/111623.html ---
# ○ 「リンクウッド 1990 26年 シェリーバット 47.3% 700mlハートブラザーズ ファイネット コレクション」のデータを正常に取得しました。
#    3.68秒待機します...
#
# --- 152/1076件目を処理中: https://www.saketry.com/111624.html ---
# ○ 「ベンネヴィス 1999 20年 バーボンホグズヘッド 48.7% 700mlモルトマン」のデータを正常に取得しました。
#    3.75秒待機します...
#
# --- 153/1076件目を処理中: https://www.saketry.com/111626.html ---
# ○ 「アードモア 2008 10年 シェリーバット 52.9% 700mlモルトマン」のデータを正常に取得しました。
#    2.11秒待機します...
#
# --- 154/1076件目を処理中: https://www.saketry.com/111632.html ---
# ○ 「シティーハンター ラベル グレンファークラス2010 9年 60.4%漫画ラベルシリーズ」のデータを正常に取得しました。
#    2.53秒待機します...
#
# --- 155/1076件目を処理中: https://www.saketry.com/111633.html ---
# ○ 「アードモア 2009 9年 56%Whisky mew」のデータを正常に取得しました。
#    3.22秒待機します...
#
# --- 156/1076件目を処理中: https://www.saketry.com/111634.html ---
# ○ 「ウシュクベ デラックス 43% 750mlウシュクベ」のデータを正常に取得しました。
#    2.47秒待機します...
#
# --- 157/1076件目を処理中: https://www.saketry.com/111636.html ---
# ○ 「ウルフバーン ヘルプ・フォー・ヒーローズ 46%ウルフバーン」のデータを正常に取得しました。
#    3.65秒待機します...
#
# --- 158/1076件目を処理中: https://www.saketry.com/111639.html ---
# ○ 「シングルモルト駒ヶ岳 屋久島エージング Bottled in 2020駒ヶ岳」のデータを正常に取得しました。
#    2.60秒待機します...
#
# --- 159/1076件目を処理中: https://www.saketry.com/111643.html ---
# ○ 「グレンロセス ”オールド スコッツ ベーカリー” 22年 46% 700mlウィームス」のデータを正常に取得しました。
#    3.76秒待機します...
#
# --- 160/1076件目を処理中: https://www.saketry.com/111644.html ---
# ○ 「ボウモア "アース ウィンド ファイヤ!" 28年 46% 700mlウィームス」のデータを正常に取得しました。
#    2.74秒待機します...
#
# --- 161/1076件目を処理中: https://www.saketry.com/111646.html ---
# ○ 「サマー ガーランズ リンクウッド 21年 46% 700mlウィームス」のデータを正常に取得しました。
#    2.56秒待機します...
#
# --- 162/1076件目を処理中: https://www.saketry.com/111649.html ---
# ○ 「ザ ハイブ バッチストレングス2 ブレンデットモルト NCF 55.5% 700mlウィームス」のデータを正常に取得しました。
#    2.54秒待機します...
#
# --- 163/1076件目を処理中: https://www.saketry.com/111651.html ---
# ○ 「ピート チムニー バッチストレングス2  ブレンデットモルト NCF 57% 700mlウィームス」のデータを正常に取得しました。
#    2.93秒待機します...
#
# --- 164/1076件目を処理中: https://www.saketry.com/111652.html ---
# ○ 「ロード エルコー NAS 40% 700mlウィームス」のデータを正常に取得しました。
#    2.14秒待機します...
#
# --- 165/1076件目を処理中: https://www.saketry.com/111653.html ---
# ○ 「バニラ バースト ブレンデットモルト 46% 700mlウィームス」のデータを正常に取得しました。
#    2.30秒待機します...
#
# --- 166/1076件目を処理中: https://www.saketry.com/111654.html ---
# ○ 「フレーミング フィースト ブレンデットモルト 46% 700mlウィームス」のデータを正常に取得しました。
#    3.82秒待機します...
#
# --- 167/1076件目を処理中: https://www.saketry.com/111655.html ---
# ○ 「ブルーミング ゴース ブレンデットモルト 46% 700mlウィームス」のデータを正常に取得しました。
#    3.33秒待機します...
#
# --- 168/1076件目を処理中: https://www.saketry.com/111658.html ---
# ○ 「ゴーストシリーズ あかし カベルネフランカスク 61%小学館」のデータを正常に取得しました。
#    3.73秒待機します...
#
# --- 169/1076件目を処理中: https://www.saketry.com/111659.html ---
# ○ 「総務部総務課 山口六平太 グレンマレイ 2008 57.8%小学館」のデータを正常に取得しました。
#    2.99秒待機します...
#
# --- 170/1076件目を処理中: https://www.saketry.com/111660.html ---
# ○ 「シングルモルト津貫 ザ ファースト 59%本坊酒造」のデータを正常に取得しました。
#    2.84秒待機します...
#
# --- 171/1076件目を処理中: https://www.saketry.com/111666.html ---
# ○ 「テイスティング・セットVol. 12スコッチモルト販売」のデータを正常に取得しました。
#    3.82秒待機します...
#
# --- 172/1076件目を処理中: https://www.saketry.com/111679.html ---
# ○ 「ハートブラザーズ テイスティング・セット 20ml x 5ハートブラザーズ」のデータを正常に取得しました。
#    2.79秒待機します...
#
# --- 173/1076件目を処理中: https://www.saketry.com/111767.html ---
# ○ 「笑ゥせぇるすまん ラベル インペリアル1995 54.1％WHISKY MEW」のデータを正常に取得しました。
#    2.33秒待機します...
#
# --- 174/1076件目を処理中: https://www.saketry.com/111842.html ---
# ○ 「アイラ ピーテッド ブレンデット モルト 2009 56.4% デビルマンエリクサー・ディスティラーズ」のデータを正常に取得しました。
#    2.65秒待機します...
#
# --- 175/1076件目を処理中: https://www.saketry.com/111843.html ---
# ○ 「レダイグ 2005 55.1% デビルマンエリクサー・ディスティラーズ」のデータを正常に取得しました。
#    2.70秒待機します...
#
# --- 176/1076件目を処理中: https://www.saketry.com/111844.html ---
# ○ 「アードモア 2009 55.5% デビルマンエリクサー・ディスティラーズ」のデータを正常に取得しました。
#    2.69秒待機します...
#
# --- 177/1076件目を処理中: https://www.saketry.com/111847.html ---
# ○ 「オスロスク10年 62.5％ 700mlクランデニー」のデータを正常に取得しました。
#    2.33秒待機します...
#
# --- 178/1076件目を処理中: https://www.saketry.com/111849.html ---
# ○ 「カリラ スモークアンドシェリー オロロソフィニッシュ 57％ 700mlクーパーズチョイス」のデータを正常に取得しました。
#    3.86秒待機します...
#
# --- 179/1076件目を処理中: https://www.saketry.com/111851.html ---
# ○ 「ダルムナック ピーチパフェ マディラフィニッシュ 61％クーパーズチョイス」のデータを正常に取得しました。
#    3.45秒待機します...
#
# --- 180/1076件目を処理中: https://www.saketry.com/111852.html ---
# ○ 「スペイバーン 2009 10年 カルバドスフィニッシュ 53%クーパーズチョイス」のデータを正常に取得しました。
#    3.30秒待機します...
#
# --- 181/1076件目を処理中: https://www.saketry.com/111857.html ---
# ○ 「インバーゴードン22年 シングルグレーンスコッチウイスキー 52.8%キャンベルメイヤー」のデータを正常に取得しました。
#    3.03秒待機します...
#
# --- 182/1076件目を処理中: https://www.saketry.com/111858.html ---
# ○ 「ストラスアイラ 2008 11年 55.6% 700mlハートブラザーズ ファイネット コレクション」のデータを正常に取得しました。
#    2.96秒待機します...
#
# --- 183/1076件目を処理中: https://www.saketry.com/111860.html ---
# ○ 「ベンリアック 2008 11年 シェリーカスク 55.7% 700mlハートブラザーズ ファイネット コレクション」のデータを正常に取得しました。
#    2.80秒待機します...
#
# --- 184/1076件目を処理中: https://www.saketry.com/111861.html ---
# ○ 「グレンマレイ 2008 11年 バーガンディカスク フィニッシュ 52.1% 700mlハートブラザーズ ファイネスト コレクション」のデータを正常に取得しました。
#    3.37秒待機します...
#
# --- 185/1076件目を処理中: https://www.saketry.com/111862.html ---
# ○ 「コッツウォルズ シングルモルトウイスキーミニ 46% 50mlコッツウォルズ」のデータを正常に取得しました。
#    2.64秒待機します...
#
# --- 186/1076件目を処理中: https://www.saketry.com/111865.html ---
# ○ 「コッツウォルズ シングルモルトウイスキー 46% 700mlコッツウォルズ」のデータを正常に取得しました。
#    3.35秒待機します...
#
# --- 187/1076件目を処理中: https://www.saketry.com/111872.html ---
# ○ 「テイスティング・セットVol. 15スコッチモルトセレクション」のデータを正常に取得しました。
#    2.24秒待機します...
#
# --- 188/1076件目を処理中: https://www.saketry.com/111874.html ---
# ○ 「グレンロセス 2007 10年 53.2% 700mlディスティラリーコレクション」のデータを正常に取得しました。
#    2.50秒待機します...
#
# --- 189/1076件目を処理中: https://www.saketry.com/111875.html ---
# ○ 「ピート・チムニー ブレンデッドモルト 46% 750mlウィームス」のデータを正常に取得しました。
#    2.56秒待機します...
#
# --- 190/1076件目を処理中: https://www.saketry.com/111876.html ---
# ○ 「ザ ハイブ ブレンデットモルト 46% 750mlウィームス」のデータを正常に取得しました。
#    2.83秒待機します...
#
# --- 191/1076件目を処理中: https://www.saketry.com/111877.html ---
# ○ 「スパイスキング ブレンデッドモルト 46% 750mlウィームス」のデータを正常に取得しました。
#    2.59秒待機します...
#
# --- 192/1076件目を処理中: https://www.saketry.com/111879.html ---
# ○ 「富士山麓シグニチャーブレンド 50% 700ml」のデータを正常に取得しました。
#    3.37秒待機します...
#
# --- 193/1076件目を処理中: https://www.saketry.com/111880.html ---
# ○ 「キリンウイスキー 陸 50% 500ml陸」のデータを正常に取得しました。
#    2.73秒待機します...
#
# --- 194/1076件目を処理中: https://www.saketry.com/111881.html ---
# ○ 「アマハガンワールドモルト エディション1 47％AMAHAGAN World Malt」のデータを正常に取得しました。
#    2.08秒待機します...
#
# --- 195/1076件目を処理中: https://www.saketry.com/111882.html ---
# ○ 「アマハガンワールドモルトエディション No2  レッドワインウッドフィニッシュ 47％AMAHAGAN World Malt Edition」のデータを正常に取得しました。
#    2.66秒待機します...
#
# --- 196/1076件目を処理中: https://www.saketry.com/111883.html ---
# ○ 「アマハガンワールドモルトエディション No3 ミズナラウッドフィニッシュ47%AMAHAGAN World Malt」のデータを正常に取得しました。
#    2.49秒待機します...
#
# --- 197/1076件目を処理中: https://www.saketry.com/111884.html ---
# ○ 「アマハガンワールドモルトエディション 山桜ウッドフィニッシュ 47％ 700mlAMAHAGAN World Malt Edition」のデータを正常に取得しました。
#    2.14秒待機します...
#
# --- 198/1076件目を処理中: https://www.saketry.com/111889.html ---
# ○ 「ウエストポート 1997 21年 50.5％ 700mlモルトウイスキーカンパニー」のデータを正常に取得しました。
#    2.61秒待機します...
#
# --- 199/1076件目を処理中: https://www.saketry.com/111890.html ---
# ○ 「クレイゲラヒ 2006 12年 PXシェリーカスクフィニッシュ 53％ 700mlモルトウイスキーカンパニー」のデータを正常に取得しました。
#    3.33秒待機します...
#
# --- 200/1076件目を処理中: https://www.saketry.com/111891.html ---
# ○ 「グレンロセス 2007 11年 オロロソシェリーカスクフィニッシュ 62.2％ 700mlモルトウイスキーカンパニー」のデータを正常に取得しました。
#    3.58秒待機します...
#
# --- 201/1076件目を処理中: https://www.saketry.com/111892.html ---
# ○ 「テイスティング・セットVol. 16スコッチモルトセレクション」のデータを正常に取得しました。
#    3.71秒待機します...
#
# --- 202/1076件目を処理中: https://www.saketry.com/111907.html ---
# ○ 「シークレットスペイサイド 1994 26年 50.3% 700mlウイスキペディア」のデータを正常に取得しました。
#    3.64秒待機します...
#
# --- 203/1076件目を処理中: https://www.saketry.com/111908.html ---
# ○ 「シークレットハイランド 2010 9年  52.6% 700mlディスティラリーズ・コレクション」のデータを正常に取得しました。
#    3.77秒待機します...
#
# --- 204/1076件目を処理中: https://www.saketry.com/111912.html ---
# ○ 「マルスモルテージ越百 モルトセレクション 43％ 700ml」のデータを正常に取得しました。
#    2.59秒待機します...
#
# --- 205/1076件目を処理中: https://www.saketry.com/111913.html ---
# ○ 「ブルー ジャイアント シュプリーム・ラベル トーモア1995 24年 47.2% 700mlウイスキーミュウ」のデータを正常に取得しました。
#    2.53秒待機します...
#
# --- 206/1076件目を処理中: https://www.saketry.com/111914.html ---
# ○ 「北斗の拳 ケンシロウラベル ティーニニック 1999 20年 47.1% 700ml漫画ラベルシリーズ」のデータを正常に取得しました。
#    2.42秒待機します...
#
# --- 207/1076件目を処理中: https://www.saketry.com/111915.html ---
# ○ 「ラオウラベル グレンロファース 1997 22年 51.8% 700ml漫画ラベルシリーズ」のデータを正常に取得しました。
#    2.82秒待機します...
#
# --- 208/1076件目を処理中: https://www.saketry.com/111917.html ---
# ○ 「マルスウイスキー 浅葱斑 48％ 700ml」のデータを正常に取得しました。
#    2.07秒待機します...
#
# --- 209/1076件目を処理中: https://www.saketry.com/111918.html ---
# ○ 「赤穂浪士シリーズ アードモア 1998 22年 700ml 49.7%酒育の会」のデータを正常に取得しました。
#    3.08秒待機します...
#
# --- 210/1076件目を処理中: https://www.saketry.com/111919.html ---
# ○ 「赤穂浪士シリーズ グレンエルギン 1998 21年 700ml 47.9%酒育の会」のデータを正常に取得しました。
#    3.49秒待機します...
#
# --- 211/1076件目を処理中: https://www.saketry.com/111920.html ---
# ○ 「ムーングロウ リミテッドエディション 2020 43％ 700ml」のデータを正常に取得しました。
#    3.59秒待機します...
#
# --- 212/1076件目を処理中: https://www.saketry.com/111922.html ---
# ○ 「レダイグ 2005 13年 シェリーカスク  57.4% 700mlザ・ウイスキー・エクスチェンジ」のデータを正常に取得しました。
#    2.08秒待機します...
#
# --- 213/1076件目を処理中: https://www.saketry.com/111924.html ---
# ○ 「赤穂浪士シリーズ シークレットオークニー 2000 17年 51.6%酒育の会」のデータを正常に取得しました。
#    2.41秒待機します...
#
# --- 214/1076件目を処理中: https://www.saketry.com/111926.html ---
# ○ 「ベルセルク ガッツラベル シークレットスペイサイド1993 26年 47.7％ 700ml漫画ラベルシリーズ」のデータを正常に取得しました。
#    3.85秒待機します...
#
# --- 215/1076件目を処理中: https://www.saketry.com/111927.html ---
# ○ 「ベルセルク ガッツラベル ベン・ネヴィス1996 23年 44.1% 700ml漫画ラベルシリーズ」のデータを正常に取得しました。
#    3.35秒待機します...
#
# --- 216/1076件目を処理中: https://www.saketry.com/111929.html ---
# ○ 「グレンマレイ 2007 52.1% 700mlザ・テイスター」のデータを正常に取得しました。
#    3.29秒待機します...
#
# --- 217/1076件目を処理中: https://www.saketry.com/111930.html ---
# ○ 「酒育の会 テイスティングセット 赤穂浪士ウイスキーエージェンシー」のデータを正常に取得しました。
#    3.10秒待機します...
#
# --- 218/1076件目を処理中: https://www.saketry.com/111935.html ---
# ○ 「アードモア EX-ラフロイグカスク 2008 11年 57.6% 700mlディスティラリーズ・コレクション」のデータを正常に取得しました。
#    3.35秒待機します...
#
# --- 219/1076件目を処理中: https://www.saketry.com/111937.html ---
# ○ 「テイスティング・セットVol. 18スコッチモルトセレクション」のデータを正常に取得しました。
#    3.68秒待機します...
#
# --- 220/1076件目を処理中: https://www.saketry.com/111938.html ---
# ○ 「キングダム 楊端和と山の民ラベル シークレット スペイサイド 1991 28年 44.9％ 700ml漫画ラベルシリーズ」のデータを正常に取得しました。
#    2.83秒待機します...
#
# --- 221/1076件目を処理中: https://www.saketry.com/111939.html ---
# ○ 「キングダム秦国の武将ラベル グレンロセス 2007 12年 51.1％ 700ml漫画ラベルシリーズ」のデータを正常に取得しました。
#    2.62秒待機します...
#
# --- 222/1076件目を処理中: https://www.saketry.com/111940.html ---
# ○ 「東京ラブストーリーラベル リンクウッド 2007 12年 55.1% 700ml漫画ラベルシリーズ」のデータを正常に取得しました。
#    2.38秒待機します...
#
# --- 223/1076件目を処理中: https://www.saketry.com/111941.html ---
# ○ 「イチローズモルト モルト＆グレーン ジャパニーズ ブレンデッド ウイスキー リミテッド エディション2020 48.5% 700mlイチローズモルト」のデータを正常に取得しました。
#    2.24秒待機します...
#
# --- 224/1076件目を処理中: https://www.saketry.com/111950.html ---
# ○ 「アイリッシュマン シングルモルト 40% 700ml」のデータを正常に取得しました。
#    3.60秒待機します...
#
# --- 225/1076件目を処理中: https://www.saketry.com/111951.html ---
# ○ 「カバラン ディスティラリーセレクト 40％ 700ml」のデータを正常に取得しました。
#    2.97秒待機します...
#
# --- 226/1076件目を処理中: https://www.saketry.com/111952.html ---
# ○ 「カバラン コンサートマスター シェリーフィニッシュ 40％ 700ml」のデータを正常に取得しました。
#    3.51秒待機します...
#
# --- 227/1076件目を処理中: https://www.saketry.com/111956.html ---
# ○ 「グレンフィディック12年 スペシャルリザーブ 40％ 700ml」のデータを正常に取得しました。
#    3.24秒待機します...
#
# --- 228/1076件目を処理中: https://www.saketry.com/111959.html ---
# ○ 「ザ・マッカラン 12年 シェリーオーク 40% 700mlザ・マッカラン」のデータを正常に取得しました。
#    3.26秒待機します...
#
# --- 229/1076件目を処理中: https://www.saketry.com/111960.html ---
# ○ 「グレンリベット 12年 40% 700ml」のデータを正常に取得しました。
#    2.96秒待機します...
#
# --- 230/1076件目を処理中: https://www.saketry.com/111961.html ---
# ○ 「アベラワー 12年 ダブルカスクマチュアード 40％ 700ml」のデータを正常に取得しました。
#    3.97秒待機します...
#
# --- 231/1076件目を処理中: https://www.saketry.com/111962.html ---
# ○ 「グレンモーレンジ 10年 40% 700ml」のデータを正常に取得しました。
#    2.39秒待機します...
#
# --- 232/1076件目を処理中: https://www.saketry.com/111963.html ---
# ○ 「タリスカー10年 45.8％ 700ml」のデータを正常に取得しました。
#    3.07秒待機します...
#
# --- 233/1076件目を処理中: https://www.saketry.com/111965.html ---
# ○ 「クライネリッシュ14年 46％ 700ml」のデータを正常に取得しました。
#    2.73秒待機します...
#
# --- 234/1076件目を処理中: https://www.saketry.com/111966.html ---
# ○ 「グレンドロナック トラディショナリーピーテッド48% 700ml」のデータを正常に取得しました。
#    2.60秒待機します...
#
# --- 235/1076件目を処理中: https://www.saketry.com/111970.html ---
# ○ 「ザ・グレナリー ブレンデッドグレーン1973  46年 50.1%ザ・グレナリー」のデータを正常に取得しました。
#    2.19秒待機します...
#
# --- 236/1076件目を処理中: https://www.saketry.com/111971.html ---
# ○ 「ヴァイタルスパーク バッチ4 2009 10年 53.5％ 500mlメドウサイド」のデータを正常に取得しました。
#    2.79秒待機します...
#
# --- 237/1076件目を処理中: https://www.saketry.com/111972.html ---
# ○ 「ウルフバーン オーロラ ミニチュア 46% 50mlウルフバーン」のデータを正常に取得しました。
#    3.60秒待機します...
#
# --- 238/1076件目を処理中: https://www.saketry.com/111973.html ---
# ○ 「ウルフバーン ラングスキップ ミニチュア 58% 50mlウルフバーン」のデータを正常に取得しました。
#    2.43秒待機します...
#
# --- 239/1076件目を処理中: https://www.saketry.com/111974.html ---
# ○ 「ウルフバーン バッチ 204 46% 700mlウルフバーン」のデータを正常に取得しました。
#    3.49秒待機します...
#
# --- 240/1076件目を処理中: https://www.saketry.com/111975.html ---
# ○ 「キルノートン シークレット・アイラ テンプラニーリョ・ワイン・カスク・マチュアード 56.5% 700mlザ・クーパーズ・チョイス」のデータを正常に取得しました。
#    3.06秒待機します...
#
# --- 241/1076件目を処理中: https://www.saketry.com/111976.html ---
# ○ 「カリラ 2008 12年 アマローネ.・カスク・フィニッシュ 54.5% 700mlザ・クーパズ・チョイス」のデータを正常に取得しました。
#    3.16秒待機します...
#
# --- 242/1076件目を処理中: https://www.saketry.com/111977.html ---
# ○ 「シークレットオークニー 2010 10Y ジャマイカンラムフィニッシュ 56% 700mlザ・クーパーズ・チョイス」のデータを正常に取得しました。
#    3.24秒待機します...
#
# --- 243/1076件目を処理中: https://www.saketry.com/111978.html ---
# ○ 「ダフタウン2008  10年 シェリーフィニッシュ 56% 700mlザ・クーパズ・チョイス」のデータを正常に取得しました。
#    2.07秒待機します...
#
# --- 244/1076件目を処理中: https://www.saketry.com/111979.html ---
# ○ 「グレンエルギン 2009  11年 サント・クロワ・デュ・モン・フィニッシュ 55% 700mlザ・クーパーズ・チョイス」のデータを正常に取得しました。
#    3.52秒待機します...
#
# --- 245/1076件目を処理中: https://www.saketry.com/111980.html ---
# ○ 「トーモア 20011 9年 カルヴァドス・カスク・フィニッシュ 54％ 700mlザ・クーパーズ・チョイス」のデータを正常に取得しました。
#    2.76秒待機します...
#
# --- 246/1076件目を処理中: https://www.saketry.com/111981.html ---
# ○ 「ロッホローモンド 1995 24年 バーボン・カスク・マチュアード 51% 700mlザ・クーパーズ・チョイス」のデータを正常に取得しました。
#    2.50秒待機します...
#
# --- 247/1076件目を処理中: https://www.saketry.com/111990.html ---
# ○ 「オルトモア 2008 12年 シェリーホグスヘッド 53.2％ 700mlモルトマン」のデータを正常に取得しました。
#    2.86秒待機します...
#
# --- 248/1076件目を処理中: https://www.saketry.com/111991.html ---
# ○ 「ブレンデットモルト シェリーバット 1992 27年 42% 700mlモルトマン」のデータを正常に取得しました。
#    2.30秒待機します...
#
# --- 249/1076件目を処理中: https://www.saketry.com/111992.html ---
# ○ 「カリラ バーボンホグスヘッド 6年 55.2％ 700ml モルトマン【日本向けスペシャル限定ボトリング】」のデータを正常に取得しました。
#    3.82秒待機します...
#
# --- 250/1076件目を処理中: https://www.saketry.com/111993.html ---
# ○ 「黄昏流星群JUKUJO ラベル クラインリーシュ 2010 9年 57.8% 700ml漫画ラベルシリーズ」のデータを正常に取得しました。
#    3.33秒待機します...
#
# --- 251/1076件目を処理中: https://www.saketry.com/111994.html ---
# ○ 「黄昏流星群SHITTORIラベル グレンエルギン2006 13年 57.1% 700ml漫画ラベルシリーズ」のデータを正常に取得しました。
#    3.21秒待機します...
#
# --- 252/1076件目を処理中: https://www.saketry.com/111995.html ---
# ○ 「「北斗の拳」北斗の拳ver. ラベル シークレットハイランド 1983 36年 50.3% 700ml漫画ラベルシリーズ」のデータを正常に取得しました。
#    3.59秒待機します...
#
# --- 253/1076件目を処理中: https://www.saketry.com/111998.html ---
# ○ 「クランデニー テイスティング・セット 20ml x 5クランデニー」のデータを正常に取得しました。
#    2.30秒待機します...
#
# --- 254/1076件目を処理中: https://www.saketry.com/111999.html ---
# ○ 「ザ.・クーパーズチョイス テイスティング・セット 20ml x 5ザ・クーパーズ・チョイス」のデータを正常に取得しました。
#    2.16秒待機します...
#
# --- 255/1076件目を処理中: https://www.saketry.com/112000.html ---
# ○ 「ザ・モルトマン シェリー テイスティング・セット 20ml x 3ザ・モルトマン」のデータを正常に取得しました。
#    3.11秒待機します...
#
# --- 256/1076件目を処理中: https://www.saketry.com/112004.html ---
# ○ 「タムデュー 12年 43% 700mlタムデュー」のデータを正常に取得しました。
#    3.38秒待機します...
#
# --- 257/1076件目を処理中: https://www.saketry.com/112005.html ---
# ○ 「タムデュー 15年 46% 700mlタムデュー」のデータを正常に取得しました。
#    3.30秒待機します...
#
# --- 258/1076件目を処理中: https://www.saketry.com/112006.html ---
# ○ 「タムデュー バッチ・ストレングス 004 57.8% 700mlタムデュー」のデータを正常に取得しました。
#    2.79秒待機します...
#
# --- 259/1076件目を処理中: https://www.saketry.com/112007.html ---
# ○ 「コッツウォルズ シングルモルトウイスキー 46% 200mlコッツウォルズ」のデータを正常に取得しました。
#    2.05秒待機します...
#
# --- 260/1076件目を処理中: https://www.saketry.com/112008.html ---
# ○ 「ストラスミル キャンディード・ナッツ 2006 12年 46% 700mlウィームス・モルツ」のデータを正常に取得しました。
#    2.45秒待機します...
#
# --- 261/1076件目を処理中: https://www.saketry.com/112010.html ---
# ○ 「ブナハーブン ハニー・アイム・ホーム 1988 30年 47% 700mlウィームス・モルツ」のデータを正常に取得しました。
#    3.62秒待機します...
#
# --- 262/1076件目を処理中: https://www.saketry.com/112014.html ---
# ○ 「インチマリン シングル・カスク 2006 12年 50.4% 700mlインチマリン【日本向けスペシャル限定ボトリング】」のデータを正常に取得しました。
#    3.59秒待機します...
#
# --- 263/1076件目を処理中: https://www.saketry.com/112016.html ---
# ○ 「イーグル・レア 10年 ケンタッキー ストレート バーボン ウイスキー 45% 700mlバッファロートレース」のデータを正常に取得しました。
#    3.02秒待機します...
#
# --- 264/1076件目を処理中: https://www.saketry.com/112023.html ---
# ○ 「シークレット スペイサイド ディスティラリー 1994 26年 49.7% 700mlディスティラリーズ・コレクション」のデータを正常に取得しました。
#    3.69秒待機します...
#
# --- 265/1076件目を処理中: https://www.saketry.com/112033.html ---
# ○ 「グレンファークラス 12年 43% 700mlグレンファークラス」のデータを正常に取得しました。
#    3.42秒待機します...
#
# --- 266/1076件目を処理中: https://www.saketry.com/112034.html ---
# ○ 「グレンファークラス 17年 43% 700mlグレンファークラス」のデータを正常に取得しました。
#    3.39秒待機します...
#
# --- 267/1076件目を処理中: https://www.saketry.com/112035.html ---
# ○ 「グレンファークラス 21年 43% 700mlグレンファークラス」のデータを正常に取得しました。
#    3.04秒待機します...
#
# --- 268/1076件目を処理中: https://www.saketry.com/112036.html ---
# ○ 「グレンファークラス 25年 43% 700mlグレンファークラス」のデータを正常に取得しました。
#    2.90秒待機します...
#
# --- 269/1076件目を処理中: https://www.saketry.com/112037.html ---
# ○ 「グレンファークラス 105 60% 700mlグレンファークラス」のデータを正常に取得しました。
#    3.28秒待機します...
#
# --- 270/1076件目を処理中: https://www.saketry.com/112038.html ---
# ○ 「グレンファークラス 12年 カスクストレングス 58.9% 700mlグレンファークラス」のデータを正常に取得しました。
#    3.24秒待機します...
#
# --- 271/1076件目を処理中: https://www.saketry.com/112039.html ---
# ○ 「グレンファークラス ザ・ファミリー・カスク 1990 30年 55.2% 700mlグレンファークラス」のデータを正常に取得しました。
#    2.02秒待機します...
#
# --- 272/1076件目を処理中: https://www.saketry.com/112040.html ---
# ○ 「グレンファークラス ザ・ファミリー・カスク 1998 21年 57.9% 700mlグレンファークラス」のデータを正常に取得しました。
#    3.25秒待機します...
#
# --- 273/1076件目を処理中: https://www.saketry.com/112041.html ---
# ○ 「グレンファークラス ザ・ファミリー・カスク 2003 17年 58.3% 700mlグレンファークラス」のデータを正常に取得しました。
#    3.41秒待機します...
#
# --- 274/1076件目を処理中: https://www.saketry.com/112042.html ---
# ○ 「あしたのジョー シークレットハイランドディスティラリー 1985YO 34年 47.6% 700ml漫画ラベルシリーズ」のデータを正常に取得しました。
#    3.81秒待機します...
#
# --- 275/1076件目を処理中: https://www.saketry.com/112043.html ---
# ○ 「あしたのジョー アルターベーン 1993 26年 48.9% 700ml漫画ラベルシリーズ」のデータを正常に取得しました。
#    3.75秒待機します...
#
# --- 276/1076件目を処理中: https://www.saketry.com/112044.html ---
# ○ 「マジンガーZ シークレットスペイサイドディスティラリー 1997 23年 51.9% 700ml漫画ラベルシリーズ」のデータを正常に取得しました。
#    3.62秒待機します...
#
# --- 277/1076件目を処理中: https://www.saketry.com/112045.html ---
# ○ 「ゲッターロボ ウィリアムソン 2006 14年 52.8% 700ml漫画ラベルシリーズ」のデータを正常に取得しました。
#    3.09秒待機します...
#
# --- 278/1076件目を処理中: https://www.saketry.com/112049.html ---
# ○ 「レトロラベル ベン ネヴィス 1997 24年 シェリー バット 53.7% 700mlエリクサー・ディスティラーズ」のデータを正常に取得しました。
#    2.51秒待機します...
#
# --- 279/1076件目を処理中: https://www.saketry.com/112057.html ---
# ○ 「シングルモルト 駒ケ岳 屋久島エージング Bottled in 2021 56% 700mlマルスウイスキー」のデータを正常に取得しました。
#    2.83秒待機します...
#
# --- 280/1076件目を処理中: https://www.saketry.com/112058.html ---
# ○ 「グレンファークラス テイスティング・セット Vol. 1Glenfarclas」のデータを正常に取得しました。
#    3.57秒待機します...
#
# --- 281/1076件目を処理中: https://www.saketry.com/112059.html ---
# ○ 「グレンマレイ 1991 25年 50.9% 700mlザンジバー ビッグ ボックス」のデータを正常に取得しました。
#    3.22秒待機します...
#
# --- 282/1076件目を処理中: https://www.saketry.com/112060.html ---
# ○ 「ブナハーブン 1989 28年 45.8% 700mlザンジバー ザ・クラン」のデータを正常に取得しました。
#    2.01秒待機します...
#
# --- 283/1076件目を処理中: https://www.saketry.com/112061.html ---
# ○ 「ベンリアック 1999 19年 54.8% 700mlザンジバー ザ・クラン」のデータを正常に取得しました。
#    2.52秒待機します...
#
# --- 284/1076件目を処理中: https://www.saketry.com/112062.html ---
# ○ 「ハイランド パーク 1999 19年 49.1 700mlザンジバー ザ・クラン」のデータを正常に取得しました。
#    3.87秒待機します...
#
# --- 285/1076件目を処理中: https://www.saketry.com/112063.html ---
# ○ 「トマーティン 1994 25年 50% 700mlザンジバー ザ・クラン」のデータを正常に取得しました。
#    2.07秒待機します...
#
# --- 286/1076件目を処理中: https://www.saketry.com/112064.html ---
# ○ 「スプリングバンク 2000 18年 47.9% 700mlザンジバー ザ・クラン」のデータを正常に取得しました。
#    3.44秒待機します...
#
# --- 287/1076件目を処理中: https://www.saketry.com/112065.html ---
# ○ 「スペイサイド・リージョン エジンバラ 42年 1975-2017 49.8% 700mlザンジバー ファッジーノ」のデータを正常に取得しました。
#    2.04秒待機します...
#
# --- 288/1076件目を処理中: https://www.saketry.com/112066.html ---
# ○ 「アイラスター 2010-2019 8年 50% 700mlノーススター」のデータを正常に取得しました。
#    2.31秒待機します...
#
# --- 289/1076件目を処理中: https://www.saketry.com/112067.html ---
# ○ 「ノーススター スペイサイドスター 2006-2018 12年 50% 700mlノーススター」のデータを正常に取得しました。
#    2.94秒待機します...
#
# --- 290/1076件目を処理中: https://www.saketry.com/112068.html ---
# ○ 「ハイランドスター 2007-2018 11年 50% 700mlノーススター」のデータを正常に取得しました。
#    2.80秒待機します...
#
# --- 291/1076件目を処理中: https://www.saketry.com/112069.html ---
# ○ 「アイランドスター 2008-2018 シリーズ 2 10YO 50% 700mlノーススター」のデータを正常に取得しました。
#    2.91秒待機します...
#
# --- 292/1076件目を処理中: https://www.saketry.com/112070.html ---
# ○ 「グレンタレット ルーアックモア 2010-2019 8年 58.3% 700mlノーススター」のデータを正常に取得しました。
#    3.34秒待機します...
#
# --- 293/1076件目を処理中: https://www.saketry.com/112071.html ---
# ○ 「インチガワー 2007-2019 11年 52.5% 700mlノーススター」のデータを正常に取得しました。
#    4.00秒待機します...
#
# --- 294/1076件目を処理中: https://www.saketry.com/112072.html ---
# ○ 「イングリッシュ ウイスキー 2007-2019 11年 49.8% 700mlノーススター」のデータを正常に取得しました。
#    3.62秒待機します...
#
# --- 295/1076件目を処理中: https://www.saketry.com/112073.html ---
# ○ 「ブレンデッドグレーン 1982-2019 36年 52.5% 700mlノーススター」のデータを正常に取得しました。
#    3.80秒待機します...
#
# --- 296/1076件目を処理中: https://www.saketry.com/112074.html ---
# ○ 「ヴェガ ブレンデッドモルト 1990-2019 28年 46.7% 700mlノーススター」のデータを正常に取得しました。
#    3.06秒待機します...
#
# --- 297/1076件目を処理中: https://www.saketry.com/112075.html ---
# ○ 「ヴェガ ブレンデッドモルト 1996-2019 22年 43.9% 700mlノーススター」のデータを正常に取得しました。
#    2.92秒待機します...
#
# --- 298/1076件目を処理中: https://www.saketry.com/112076.html ---
# ○ 「トーモア 1988 30年 ヘラ 50.7% 700mlアクア・ヴィーテ ギリシャ神話」のデータを正常に取得しました。
#    3.14秒待機します...
#
# --- 299/1076件目を処理中: https://www.saketry.com/112077.html ---
# ○ 「レダイグ 1997 22年 アレス 52.3% 700mlアクア・ヴィーテ ギリシャ神話」のデータを正常に取得しました。
#    3.14秒待機します...
#
# --- 300/1076件目を処理中: https://www.saketry.com/112078.html ---
# ○ 「ブナハーブン1989-2018 29年 エーテル 48.8% 700mlアクア・ヴィーテ ファイブエレメンツ」のデータを正常に取得しました。
#    2.43秒待機します...
#
# --- 301/1076件目を処理中: https://www.saketry.com/112079.html ---
# ○ 「カリラ  5年 "Joint Bottle With Bar TCRC" 59% 700mlアクア・ヴィーテ ジョイントボトルシリーズ」のデータを正常に取得しました。
#    2.68秒待機します...
#
# --- 302/1076件目を処理中: https://www.saketry.com/112080.html ---
# ○ 「グレンマレイ 1992 21年 60.1% 700mlダン・イーダン」のデータを正常に取得しました。
#    2.69秒待機します...
#
# --- 303/1076件目を処理中: https://www.saketry.com/112082.html ---
# ○ 「ロングモーン 2010 9年 53.5% 700mlハートブラザーズ ファイネスト・コレクション」のデータを正常に取得しました。
#    3.20秒待機します...
#
# --- 304/1076件目を処理中: https://www.saketry.com/112083.html ---
# ○ 「ストラスアイラ 2010 9年 アルマニャック 53.8% 700mlハートブラザーズ ファイネスト・コレクション」のデータを正常に取得しました。
#    2.94秒待機します...
#
# --- 305/1076件目を処理中: https://www.saketry.com/112084.html ---
# ○ 「トマーティン 2010 10年 ポートフィン 53.8% 700mlハートブラザーズ ファイネスト・コレクション」のデータを正常に取得しました。
#    2.55秒待機します...
#
# --- 306/1076件目を処理中: https://www.saketry.com/112086.html ---
# ○ 「ダルユーイン 1999 21年 52.8% 700mlハートブラザーズ ファイネスト・コレクション」のデータを正常に取得しました。
#    2.42秒待機します...
#
# --- 307/1076件目を処理中: https://www.saketry.com/112088.html ---
# ○ 「オークニー 2006 12年 バーボン樽 60.4% 700mlザンジバー キュンストラーシリーズ」のデータを正常に取得しました。
#    2.48秒待機します...
#
# --- 308/1076件目を処理中: https://www.saketry.com/112089.html ---
# ○ 「グレンロセス 2007 11年 シェリーバット Ralfy.co 10th Anniversary 51.4% 700mlノーススター」のデータを正常に取得しました。
#    3.98秒待機します...
#
# --- 309/1076件目を処理中: https://www.saketry.com/112098.html ---
# ○ 「あかし トーニー ポート カスク 2016 4年 61.5% 500mlラベルシリーズ」のデータを正常に取得しました。
#    3.80秒待機します...
#
# --- 310/1076件目を処理中: https://www.saketry.com/112100.html ---
# ○ 「ベルセルク アイリッシュ ウイスキー 2002 17YO 50.3% 700ml漫画ラベルシリーズ」のデータを正常に取得しました。
#    2.88秒待機します...
#
# --- 311/1076件目を処理中: https://www.saketry.com/112104.html ---
# ○ 「キルホーマン マキヤーベイ 46% 700mlキルホーマン」のデータを正常に取得しました。
#    2.14秒待機します...
#
# --- 312/1076件目を処理中: https://www.saketry.com/112105.html ---
# ○ 「クランデニー タリスカー 2010 9年 プレーンリフィルホグスヘッド 55.5% 700mlクランデニー」のデータを正常に取得しました。
#    2.56秒待機します...
#
# --- 313/1076件目を処理中: https://www.saketry.com/112106.html ---
# ○ 「コッツウォルズ シェリーカスク シングルモルトウイスキー 57.4% 700mlコッツウォルズ」のデータを正常に取得しました。
#    3.41秒待機します...
#
# --- 314/1076件目を処理中: https://www.saketry.com/112108.html ---
# ○ 「グレンゴイン18YO 43% 700mlグレンゴイン」のデータを正常に取得しました。
#    2.66秒待機します...
#
# --- 315/1076件目を処理中: https://www.saketry.com/112109.html ---
# ○ 「スプリングバンク 1993 22年 リフィルシェリーホグスヘッド 51.9% 700mlザ・ボトラーズ」のデータを正常に取得しました。
#    3.91秒待機します...
#
# --- 316/1076件目を処理中: https://www.saketry.com/112111.html ---
# ○ 「ザ・イリデセント・カスク グレンエルギン 2010 10年 ホグスヘッド 54.5% 700ml」のデータを正常に取得しました。
#    2.01秒待機します...
#
# --- 317/1076件目を処理中: https://www.saketry.com/112112.html ---
# ○ 「ザ・イリデセント・カスク キャンベルタウンブレンデッドモルト 2014 6年 ホグズヘッド 56.5% 700ml」のデータを正常に取得しました。
#    3.78秒待機します...
#
# --- 318/1076件目を処理中: https://www.saketry.com/112113.html ---
# ○ 「カリラ 2008 12年 ホグズヘッド 55% 700mlディスティラリーズ・コレクション」のデータを正常に取得しました。
#    2.20秒待機します...
#
# --- 319/1076件目を処理中: https://www.saketry.com/112115.html ---
# ○ 「バルブレア 19年 55.9% 700mlアートオブウイスキー」のデータを正常に取得しました。
#    3.29秒待機します...
#
# --- 320/1076件目を処理中: https://www.saketry.com/112116.html ---
# ○ 「ベンネヴィス 1996 23年 52.1% 700mlザ・ウイスキー・エクスチェンジ」のデータを正常に取得しました。
#    2.05秒待機します...
#
# --- 321/1076件目を処理中: https://www.saketry.com/112117.html ---
# ○ 「ブナハーブン 1997 22年 51.3% 700ml ザ・ウイスキー・エクスチェンジ」のデータを正常に取得しました。
#    2.52秒待機します...
#
# --- 322/1076件目を処理中: https://www.saketry.com/112118.html ---
# ○ 「カリラ 2008 12年 58.5% 700mlザ・ウィスキー エクスチェンジ」のデータを正常に取得しました。
#    3.52秒待機します...
#
# --- 323/1076件目を処理中: https://www.saketry.com/112119.html ---
# ○ 「クライヌリッシュ 21年 56.1% 700ml アートオブウイスキー」のデータを正常に取得しました。
#    3.87秒待機します...
#
# --- 324/1076件目を処理中: https://www.saketry.com/112120.html ---
# ○ 「グレンエルギン 12年 55.8% 700mlザ・ウイスキー・エクスチェンジ」のデータを正常に取得しました。
#    2.45秒待機します...
#
# --- 325/1076件目を処理中: https://www.saketry.com/112121.html ---
# ○ 「グレンロッシー 2009 11年 カスク 56.5% 700ml ザ・ウイスキー・エクスチェンジ」のデータを正常に取得しました。
#    3.78秒待機します...
#
# --- 326/1076件目を処理中: https://www.saketry.com/112122.html ---
# ○ 「グレンロセス 27年 51.1% 700mlアートオブウイスキー」のデータを正常に取得しました。
#    3.92秒待機します...
#
# --- 327/1076件目を処理中: https://www.saketry.com/112123.html ---
# ○ 「グレントファース 19年 53.5% 700mlアートオブウイスキー」のデータを正常に取得しました。
#    3.17秒待機します...
#
# --- 328/1076件目を処理中: https://www.saketry.com/112125.html ---
# ○ 「ミルトンダフ 17年 54.5% 700ml アートオブウイスキー」のデータを正常に取得しました。
#    3.04秒待機します...
#
# --- 329/1076件目を処理中: https://www.saketry.com/112126.html ---
# ○ 「スプリングバンク 24年 51.7% 700mlアートオブウイスキー」のデータを正常に取得しました。
#    3.70秒待機します...
#
# --- 330/1076件目を処理中: https://www.saketry.com/112127.html ---
# ○ 「グレントファース 1996 25年 カスク #1197 48.5% 700mlディスティラリーズ・コレクション」のデータを正常に取得しました。
#    2.40秒待機します...
#
# --- 331/1076件目を処理中: https://www.saketry.com/112128.html ---
# ○ 「タリスカー シェリー・ウッド 1993 27年 50.5%ハートブラザーズ・ファイネスト・コレクション」のデータを正常に取得しました。
#    2.87秒待機します...
#
# --- 332/1076件目を処理中: https://www.saketry.com/112130.html ---
# ○ 「フレーミングハート ブレンデッドモルトスコッチウイスキー 48.9% 700mlコンパスボックス」のデータを正常に取得しました。
#    3.13秒待機します...
#
# --- 333/1076件目を処理中: https://www.saketry.com/112131.html ---
# ○ 「ザ・スパイス・ツリー ブレンデッドモルトスコッチウイスキー 46% 700mlコンパスボックス」のデータを正常に取得しました。
#    3.46秒待機します...
#
# --- 334/1076件目を処理中: https://www.saketry.com/112132.html ---
# ○ 「ブティック・ウイスキー・カンパニー ワールド・ウイスキー・ブレンド 41.6% 700mlブティック・ウイスキー・カンパニー」のデータを正常に取得しました。
#    2.41秒待機します...
#
# --- 335/1076件目を処理中: https://www.saketry.com/112134.html ---
# ○ 「グレンアラヒー ナパヴァレーレッドワインカスク 2010 10年 53.7% 700mlグレンアラヒー」のデータを正常に取得しました。
#    2.55秒待機します...
#
# --- 336/1076件目を処理中: https://www.saketry.com/112135.html ---
# ○ 「モートラック 16年 52.6% 700mlハートブラザーズファイネスト・コレクション」のデータを正常に取得しました。
#    2.34秒待機します...
#
# --- 337/1076件目を処理中: https://www.saketry.com/112136.html ---
# ○ 「ダルユーイン 21年 52.8% 700mlハートブラザーズ・ファイネスト・コレクション」のデータを正常に取得しました。
#    3.47秒待機します...
#
# --- 338/1076件目を処理中: https://www.saketry.com/112137.html ---
# ○ 「グレントファース 22年 47.9% 700mlハートブラザーズ・ファイネスト・コレクション」のデータを正常に取得しました。
#    2.95秒待機します...
#
# --- 339/1076件目を処理中: https://www.saketry.com/112138.html ---
# ○ 「グレントファース 22年 50.2% 700mlハートブラザーズ・ファイネスト・コレクション」のデータを正常に取得しました。
#    2.20秒待機します...
#
# --- 340/1076件目を処理中: https://www.saketry.com/112139.html ---
# ○ 「ストラスミル シェリー・バット 26年 48.1% 700mlハートブラザーズ・ファイネスト・コレクション」のデータを正常に取得しました。
#    3.44秒待機します...
#
# --- 341/1076件目を処理中: https://www.saketry.com/112140.html ---
# ○ 「グレントファース 28年 50.5% 700mlハートブラザーズ・ファイネスト・コレクション」のデータを正常に取得しました。
#    2.56秒待機します...
#
# --- 342/1076件目を処理中: https://www.saketry.com/112141.html ---
# ○ 「ベンリアック ポートウッド  14年 51.9% 700mlハートブラザーズ・ファイネスト・コレクション」のデータを正常に取得しました。
#    3.00秒待機します...
#
# --- 343/1076件目を処理中: https://www.saketry.com/112142.html ---
# ○ 「ブナハーブン 2013 7年 ヘヴィリーピーテッド バーボンカスク 53.5% 700mlザ・クーパーズ・チョイス」のデータを正常に取得しました。
#    2.47秒待機します...
#
# --- 344/1076件目を処理中: https://www.saketry.com/112143.html ---
# ○ 「ウィリアムソン 2005 14年 アイラ ブレンデッド モルト バーボンカスク 51% 700mlザ・クーパーズ・チョイス」のデータを正常に取得しました。
#    2.41秒待機します...
#
# --- 345/1076件目を処理中: https://www.saketry.com/112144.html ---
# ○ 「インチガワー 2001 19年 ソーテルヌ フィニッシュ 49.5% 700mlザ・クーパーズ・チョイス」のデータを正常に取得しました。
#    3.90秒待機します...
#
# --- 346/1076件目を処理中: https://www.saketry.com/112145.html ---
# ○ 「マクダフ 2003 16年 ポート フィニッシュ 51% 700mlザ・クーパーズ・チョイス」のデータを正常に取得しました。
#    3.93秒待機します...
#
# --- 347/1076件目を処理中: https://www.saketry.com/112146.html ---
# ○ 「マノックモア 2009 12年 リフィル シェリー カスク 54.5% 700mlザ・クーパーズ・チョイス」のデータを正常に取得しました。
#    2.47秒待機します...
#
# --- 348/1076件目を処理中: https://www.saketry.com/112147.html ---
# ○ 「ブレアソール 2009 11年 シェリー ウッド マチュアド 52.5% 700mlザ・クーパーズ・チョイス」のデータを正常に取得しました。
#    3.87秒待機します...
#
# --- 349/1076件目を処理中: https://www.saketry.com/112148.html ---
# ○ 「オールドロスデュー 1994 27YO Bourbon Cask 47% 700mlザ・クーパーズ・チョイス」のデータを正常に取得しました。
#    3.62秒待機します...
#
# --- 350/1076件目を処理中: https://www.saketry.com/112149.html ---
# ○ 「インバゴードン 1990 30年 バーボンカスク 42.5% 700mlザ・クーパーズ・チョイス」のデータを正常に取得しました。
#    3.79秒待機します...
#
# ...
# ○ 「シングルモルト 津貫 2024 エディション 50% 700シングルモルト 津貫」のデータを正常に取得しました。
#    3.70秒待機します...
#
# --- 973/1076件目を処理中: https://www.saketry.com/113161.html ---
# ○ 「Scary Tale 5th Bottling  ティーニニック  2008 15年 ファーストフィル オロロソ ホグスヘッド 51.8% 700mlScary Tale」のデータを正常に取得しました。
#    2.27秒待機します...
#
# --- 974/1076件目を処理中: https://www.saketry.com/113162.html ---
# ○ 「Happy Loner  ファスト ボトリング ブレアアソール 2009 14年 オロロソ シェリー ホグスヘッド 51.0% 700mlHappy Loner」のデータを正常に取得しました。
#    3.37秒待機します...
#
# --- 975/1076件目を処理中: https://www.saketry.com/113175.html ---
# ○ 「『鉄人28号』ラベル ストラスアイラ 2013 9年 52.7% 700ML漫画ラベル」のデータを正常に取得しました。
#    2.48秒待機します...
#
# --- 976/1076件目を処理中: https://www.saketry.com/113189.html ---
# ○ 「イクイノックス＆ソルスティス オータム エディション 2023 アバフェルディ 10年 48.5% 700mlイクイノックス＆ソルスティス」のデータを正常に取得しました。
#    2.65秒待機します...
#
# --- 977/1076件目を処理中: https://www.saketry.com/113192.html ---
# ○ 「オールド・オークニー OO2 19年 53% 700mlオールド・オークニー」のデータを正常に取得しました。
#    2.73秒待機します...
#
# --- 978/1076件目を処理中: https://www.saketry.com/113193.html ---
# ○ 「イクイノックス＆ソルスティス ウィンターエディション 2023 ミルトンダフ 11年 1st フィル・シェリーホグスヘッド 48.5% 700mlイクイノックス＆ソルスティス」のデータを正常に取得しました。
#    3.29秒待機します...
#
# --- 979/1076件目を処理中: https://www.saketry.com/113194.html ---
# ○ 「エディション No.84 オーヘントッシャン 31年 2nd フィル・バレル 53.6% 700mlウイスキースポンジ」のデータを正常に取得しました。
#    3.15秒待機します...
#
# --- 980/1076件目を処理中: https://www.saketry.com/113207.html ---
# ○ 「ブレアソール 1992 31年 43.3% 700mlザ・モルトマン」のデータを正常に取得しました。
#    3.27秒待機します...
#
# --- 981/1076件目を処理中: https://www.saketry.com/113218.html ---
# ○ 「YUZA シングルモルト ジャパニーズウイスキー サードエディション 2023 55% 700mledition シリーズ」のデータを正常に取得しました。
#    2.74秒待機します...
#
# --- 982/1076件目を処理中: https://www.saketry.com/113219.html ---
# ○ 「YUZA スプリング イン ジャパン 2024 55% 700ML限定シリーズ」のデータを正常に取得しました。
#    2.19秒待機します...
#
# --- 983/1076件目を処理中: https://www.saketry.com/113231.html ---
# ○ 「「ミワさんなりすます」ラベル アードモア 2010 12年 48.1% 700ML漫画ラベル」のデータを正常に取得しました。
#    2.75秒待機します...
#
# --- 984/1076件目を処理中: https://www.saketry.com/113232.html ---
# ○ 「「村松誠イラスト」ラベル "猫” TOMARTIN 2008 13年 49.4% 700MLウイスキー・ミュウ」のデータを正常に取得しました。
#    3.23秒待機します...
#
# --- 985/1076件目を処理中: https://www.saketry.com/113233.html ---
# ○ 「「村松誠イラスト」ラベル "犬” TOMARTIN 2008 13年 49.4% 700ML漫画ラベル」のデータを正常に取得しました。
#    3.12秒待機します...
#
# --- 986/1076件目を処理中: https://www.saketry.com/113234.html ---
# ○ 「「三丁目の夕日」ラベル あかし 3年 (トロンセ樽) 63% 500ML漫画ラベル」のデータを正常に取得しました。
#    3.27秒待機します...
#
# --- 987/1076件目を処理中: https://www.saketry.com/113235.html ---
# ○ 「嘉之助「ダブル ディスティラリー」53% 700MLダブル ディスティラリー」のデータを正常に取得しました。
#    3.04秒待機します...
#
# --- 988/1076件目を処理中: https://www.saketry.com/113236.html ---
# ○ 「MARS The.Y.A. #03 51% 700mlMARS The.Y.A.」のデータを正常に取得しました。
#    3.37秒待機します...
#
# --- 989/1076件目を処理中: https://www.saketry.com/113237.html ---
# ○ 「ザ クライドサイド 2018 5年 FOR  スリーリバーズ 20th アニバーサリー 58.6% 700mlクライドサイド」のデータを正常に取得しました。
#    3.05秒待機します...
#
# --- 990/1076件目を処理中: https://www.saketry.com/113239.html ---
# ○ 「『釣りバカ日誌』ラベル シークレットアイラ 2013 ８年 53.4% 700ml漫画ラベル」のデータを正常に取得しました。
#    2.85秒待機します...
#
# --- 991/1076件目を処理中: https://www.saketry.com/113241.html ---
# ○ 「『黄昏流星群』ラベル シークレットアイラ 2018 4年 53.7% 700ML漫画ラベル」のデータを正常に取得しました。
#    2.17秒待機します...
#
# --- 992/1076件目を処理中: https://www.saketry.com/113242.html ---
# ○ 「シークレットハイランド 2010 13年 シェリーカスク 52.1% 700mlディスティラリーズ・コレクション」のデータを正常に取得しました。
#    3.69秒待機します...
#
# --- 993/1076件目を処理中: https://www.saketry.com/113243.html ---
# ○ 「シークレットオークニー  2006 17年 ホグスヘッド 51.7% 700mlディスティラリーズ・コレクション」のデータを正常に取得しました。
#    3.34秒待機します...
#
# --- 994/1076件目を処理中: https://www.saketry.com/113244.html ---
# ○ 「バルメナック 2013 10年 シェリーホグスヘッド 53.8% 700mlディスティラリーズ・コレクション」のデータを正常に取得しました。
#    3.16秒待機します...
#
# --- 995/1076件目を処理中: https://www.saketry.com/113245.html ---
# ○ 「グレンロセス 1992 30年 ホグスヘッド 48.3% 700mlザ・テイスター」のデータを正常に取得しました。
#    2.56秒待機します...
#
# --- 996/1076件目を処理中: https://www.saketry.com/113246.html ---
# ○ 「【限定377本】シークレットアイラ 2017 6年 ウイスキペディア×Pen コラボレーションボトル 53.9% 700mlウイスキペディア×Pen」のデータを正常に取得しました。
#    2.02秒待機します...
#
# --- 997/1076件目を処理中: https://www.saketry.com/113247.html ---
# ○ 「【限定58本】シークレットアイラ 2009 14年 ウイスキペディア×Pen コラボレーションボトル 51.7% 700mlウイスキペディア×Pen」のデータを正常に取得しました。
#    3.48秒待機します...
#
# --- 998/1076件目を処理中: https://www.saketry.com/113248.html ---
# ○ 「ベンネヴィス 1998 25年 ホグスヘッド 能登チャリティーボトル 49.4% 700mlザ・モルトマン」のデータを正常に取得しました。
#    3.13秒待機します...
#
# --- 999/1076件目を処理中: https://www.saketry.com/113249.html ---
# ○ 「ノックデュー 2013 10年 シェリーカスク 能登チャリティーボトル 54.8% 700mlザ・モルトマン」のデータを正常に取得しました。
#    3.90秒待機します...
#
# --- 1000/1076件目を処理中: https://www.saketry.com/113251.html ---
# ○ 「『銀河英雄伝説』ラインハルト ラベル プルトニー 2013 9年 52.3% 700ML漫画ラベルシリーズ」のデータを正常に取得しました。
#    3.68秒待機します...
#
# --- 1001/1076件目を処理中: https://www.saketry.com/113252.html ---
# ○ 「『銀河英雄伝説』ヤン・ウェンリー・ラベル カリラ 2010 12年 53.4% 700ML漫画ラベル」のデータを正常に取得しました。
#    2.57秒待機します...
#
# --- 1002/1076件目を処理中: https://www.saketry.com/113253.html ---
# ○ 「『西伊豆木負』ラベル 川瀬巴水 ベンネヴィス 2012  10年 56.1% 700MLアートエクスプレッション」のデータを正常に取得しました。
#    2.08秒待機します...
#
# --- 1003/1076件目を処理中: https://www.saketry.com/113254.html ---
# ○ 「『東京十二景 馬込の月』ラベル  川瀬巴水 クラインリーシュ 2011 12年 61.0% 700MLアートエクスプレッション」のデータを正常に取得しました。
#    2.05秒待機します...
#
# --- 1004/1076件目を処理中: https://www.saketry.com/113265.html ---
# ○ 「アードモア 2013 10年 52.5% 700mlザ・クーパーズチョイス」のデータを正常に取得しました。
#    2.77秒待機します...
#
# --- 1005/1076件目を処理中: https://www.saketry.com/113266.html ---
# ○ 「ブレアソール 2011 12年 マスカットカスクフィニッシュ 52.5% 700mlザ・クーパーズチョイス」のデータを正常に取得しました。
#    3.78秒待機します...
#
# --- 1006/1076件目を処理中: https://www.saketry.com/113267.html ---
# ○ 「ベンリネス 2011 12年 マルティニークラムカスクフィニッシュ 51.5% 700mlザ・クーパーズチョイス」のデータを正常に取得しました。
#    3.61秒待機します...
#
# --- 1007/1076件目を処理中: https://www.saketry.com/113268.html ---
# ○ 「カンバス 1991 32年 47.5% 700mlザ・クーパーズチョイス」のデータを正常に取得しました。
#    2.24秒待機します...
#
# --- 1008/1076件目を処理中: https://www.saketry.com/113270.html ---
# ○ 「グレンロッシー2011 12年 カルヴァドスカスクフィニッシュ 54.5% 700mlザ・クーパーズチョイス」のデータを正常に取得しました。
#    3.79秒待機します...
#
# --- 1009/1076件目を処理中: https://www.saketry.com/113271.html ---
# ○ 「グレンマレイ 2015 8年 マルサラ フィニッシュ 58.5% 700mlザ・クーパーズチョイス」のデータを正常に取得しました。
#    3.80秒待機します...
#
# --- 1010/1076件目を処理中: https://www.saketry.com/113272.html ---
# ○ 「リンクウッド 2011 12年 オロロソシェリーカスクフィニッシュ 54% 700mlザ・クーパーズチョイス」のデータを正常に取得しました。
#    3.86秒待機します...
#
# --- 1011/1076件目を処理中: https://www.saketry.com/113273.html ---
# ○ 「タムデュー 2015 8年 マデイラカスクフィニッシュ 57.4% 700mlザ・クーパーズチョイス」のデータを正常に取得しました。
#    2.70秒待機します...
#
# --- 1012/1076件目を処理中: https://www.saketry.com/113274.html ---
# ○ 「ディーンストン 2014 8年 マルサラ フィニッシュ 54% 700mlザ・クーパーズチョイス」のデータを正常に取得しました。
#    3.16秒待機します...
#
# --- 1013/1076件目を処理中: https://www.saketry.com/113275.html ---
# ○ 「インバーゴードン2005 18年 マルサラ フィニッシュ 47.8% 700mlザ・クーパーズチョイス」のデータを正常に取得しました。
#    2.43秒待機します...
#
# --- 1014/1076件目を処理中: https://www.saketry.com/113276.html ---
# ○ 「トーモア 2015 7年 オロロソ シェリー カスク フィニッシュ 57% 700mlザ・クーパーズチョイス」のデータを正常に取得しました。
#    2.70秒待機します...
#
# --- 1015/1076件目を処理中: https://www.saketry.com/113297.html ---
# ○ 「エディション No.85 ベンネヴィス 10年 リフィルバット / リフィル・クォーターカスク・フィニッシュ 52.0% 700mlウイスキースポンジ」のデータを正常に取得しました。
#    2.19秒待機します...
#
# --- 1016/1076件目を処理中: https://www.saketry.com/113301.html ---
# ○ 「エディション No.89 ‘ゴーン グラント’ 31年 2nd フィル・バレル 43.9% 700mlウイスキースポンジ」のデータを正常に取得しました。
#    2.00秒待機します...
#
# --- 1017/1076件目を処理中: https://www.saketry.com/113302.html ---
# ○ 「イクイノックス＆ソルスティス スプリングエディション 2024 ティーニニック 12年 シングルリフィル・ホグスヘッド 48.5% 700mlイクイノックス＆ソルスティス」のデータを正常に取得しました。
#    3.42秒待機します...
#
# --- 1018/1076件目を処理中: https://www.saketry.com/113303.html ---
# ○ 「エディション No.90 ブラドノック 34年 リフィルバレル 55.1% 700mlウイスキースポンジ」のデータを正常に取得しました。
#    3.10秒待機します...
#
# --- 1019/1076件目を処理中: https://www.saketry.com/113310.html ---
# ○ 「コッツウォルズ リザーブ シングルモルトウイスキー 1st フィル・バーボンカスク / レッドワインカスク 50% 700mlコッツウォルズ」のデータを正常に取得しました。
#    2.41秒待機します...
#
# --- 1020/1076件目を処理中: https://www.saketry.com/113311.html ---
# ○ 「グレンバーギー 2010 13年 オロロソ シェリー フィニッシュ 53.3% 700mlザ・ウイスキー・セラー プライベート・セラーズ・コレクション」のデータを正常に取得しました。
#    3.09秒待機します...
#
# --- 1021/1076件目を処理中: https://www.saketry.com/113312.html ---
# ○ 「カリラ 2012 11年 コート・ロティ ワインカスク フィニッシュ 55.2% 700mlザ・ウイスキー・セラー プライベート・セラーズ・コレクション」のデータを正常に取得しました。
#    3.18秒待機します...
#
# --- 1022/1076件目を処理中: https://www.saketry.com/113313.html ---
# ○ 「ノースブリティッシュ 1989 33年 リフィル バーボンバレル 50.1% 700mlザ・ウイスキー・セラー プライベート・セラーズ・コレクション」のデータを正常に取得しました。
#    2.39秒待機します...
#
# --- 1023/1076件目を処理中: https://www.saketry.com/113314.html ---
# ○ 「ロブスト シガーモルト 2015 8年 オロロソシェリーカスク 52.5% 700mlザ・ウイスキー・セラー プライベート・セラーズ・コレクション」のデータを正常に取得しました。
#    3.90秒待機します...
#
# --- 1024/1076件目を処理中: https://www.saketry.com/113315.html ---
# ○ 「グレンスペイ 2009 14年 ルピアック ワインカスク フィニッシュ 54.7% 700mlピンテイル」のデータを正常に取得しました。
#    2.29秒待機します...
#
# --- 1025/1076件目を処理中: https://www.saketry.com/113316.html ---
# ○ 「オスロスク 2008 15年 フォンディジョン ワインカスク フィニッシュ 54.3% 700mlピンテイル」のデータを正常に取得しました。
#    2.28秒待機します...
#
# --- 1026/1076件目を処理中: https://www.saketry.com/113317.html ---
# ○ 「ベンネヴィス 1997 25年 ホグスヘッド 47.6% 700mlスピリッツ ショップ セレクション」のデータを正常に取得しました。
#    2.86秒待機します...
#
# --- 1027/1076件目を処理中: https://www.saketry.com/113318.html ---
# ○ 「レダイグ 2005 14年 ホグスヘッド 57.8% 700mlスピリッツ ショップ セレクション」のデータを正常に取得しました。
#    3.18秒待機します...
#
# --- 1028/1076件目を処理中: https://www.saketry.com/113319.html ---
# ○ 「グレンエルギン 2008 12年 シェリーバット 58.7% 700mlスピリッツ ショップ セレクション」のデータを正常に取得しました。
#    3.02秒待機します...
#
# --- 1029/1076件目を処理中: https://www.saketry.com/113320.html ---
# ○ 「オスロスク 2010 12年 ホグスヘッド 60.8% 700mlスピリッツ ショップ セレクション」のデータを正常に取得しました。
#    3.31秒待機します...
#
# --- 1030/1076件目を処理中: https://www.saketry.com/113322.html ---
# ○ 「インチガワー 2010 12年 ホグスヘッド 57.6% 700mlスピリッツ ショップ セレクション」のデータを正常に取得しました。
#    3.50秒待機します...
#
# --- 1031/1076件目を処理中: https://www.saketry.com/113323.html ---
# ○ 「ガーヴァン 2006 17年 ファインブルターニュカスクフィニッシュ 53.7% 700mlピンテイル」のデータを正常に取得しました。
#    3.25秒待機します...
#
# --- 1032/1076件目を処理中: https://www.saketry.com/113325.html ---
# ○ 「シングルモルト 駒ヶ岳 2024 エディション 50% 700MLシングルモルト駒ヶ岳」のデータを正常に取得しました。
#    2.58秒待機します...
#
# --- 1033/1076件目を処理中: https://www.saketry.com/113332.html ---
# ○ 「イチローズ モルト アンド グレーン 20th アニバーサリーエディション 48% 700MLICHRO`S MALT」のデータを正常に取得しました。
#    2.92秒待機します...
#
# --- 1034/1076件目を処理中: https://www.saketry.com/113356.html ---
# ○ 「インバーゴードン 1974 50年 バーボンバレル 43.2% 700mlザ・グレーンマン」のデータを正常に取得しました。
#    2.83秒待機します...
#
# --- 1035/1076件目を処理中: https://www.saketry.com/113357.html ---
# ○ 「ダルユーイン 2009 14年 リフィル シェリーバット 53.1% 700mlザ・モルトマン」のデータを正常に取得しました。
#    2.67秒待機します...
#
# --- 1036/1076件目を処理中: https://www.saketry.com/113358.html ---
# ○ 「グレンロッシー 1997 26年 リフィル シェリーバット 47.6% 700mlザ・モルトマン」のデータを正常に取得しました。
#    2.83秒待機します...
#
# --- 1037/1076件目を処理中: https://www.saketry.com/113360.html ---
# ○ 「アイランズ ブレンデッドモルト 1999 22年 バーボン ホグスヘッド 46.5% 700mlザ・モルトマン」のデータを正常に取得しました。
#    2.19秒待機します...
#
# --- 1038/1076件目を処理中: https://www.saketry.com/113362.html ---
# ○ 「ブレンデットスコッチ 信濃屋  25年 48.2% 700mlザ・モルトマン」のデータを正常に取得しました。
#    2.80秒待機します...
#
# --- 1039/1076件目を処理中: https://www.saketry.com/113363.html ---
# ○ 「ブレンデットスコッチ 信濃屋 37年 43.8% 700mlザ・モルトマン」のデータを正常に取得しました。
#    2.54秒待機します...
#
# --- 1040/1076件目を処理中: https://www.saketry.com/113364.html ---
# ○ 「リンクウッド 2006 17年 マデイラカスク フィニッシュ ジャパン・エクスクルーシブ 52.2% 700mlザ・モルトマン」のデータを正常に取得しました。
#    3.94秒待機します...
#
# --- 1041/1076件目を処理中: https://www.saketry.com/113365.html ---
# ○ 「ウルフバーン マンサニージャカスクフィニッシュ 46% 700mlウルフバーン」のデータを正常に取得しました。
#    2.57秒待機します...
#
# --- 1042/1076件目を処理中: https://www.saketry.com/113366.html ---
# ○ 「ウルフバーン ウィック・ハーバー・トラスト ブラックサタデー 46% 700mlウルフバーン」のデータを正常に取得しました。
#    2.67秒待機します...
#
# --- 1043/1076件目を処理中: https://www.saketry.com/113374.html ---
# ○ 「ウルフバーン ジャパン・エクスクルーシブ 7 2017 7年 カスク No.245 50% 700mlウルフバーン」のデータを正常に取得しました。
#    3.20秒待機します...
#
# --- 1044/1076件目を処理中: https://www.saketry.com/113385.html ---
# ○ 「ウルフバーン メリークリスマス 10年 46% 350mlウルフバーン」のデータを正常に取得しました。
#    3.10秒待機します...
#
# --- 1045/1076件目を処理中: https://www.saketry.com/113386.html ---
# ○ 「ブルックラディ 1991 32年 リフィル ホグスヘッド 49.3% 700mlザ・モルトマン」のデータを正常に取得しました。
#    2.73秒待機します...
#
# --- 1046/1076件目を処理中: https://www.saketry.com/113389.html ---
# ○ 「アードナッホー ファースト リリース 50％ 700MLアードナッホー」のデータを正常に取得しました。
#    2.28秒待機します...
#
# --- 1047/1076件目を処理中: https://www.saketry.com/113402.html ---
# ○ 「アイル・オブ・ハリス ザ・ヒーラック オロロソカスク シングルモルトウイスキー 46% 700mlアイル・オブ・ハリス」のデータを正常に取得しました。
#    3.37秒待機します...
#
# --- 1048/1076件目を処理中: https://www.saketry.com/113404.html ---
# ○ 「エディション No.67 オールド・ロスデュー 1993 29年 リフィル・ホグスヘッド 57.1％ 700mlウイスキースポンジ」のデータを正常に取得しました。
#    2.33秒待機します...
#
# --- 1049/1076件目を処理中: https://www.saketry.com/113405.html ---
# ○ 「『めぞん一刻』音無響子ラベル／グレングラント 1998 25年 リフィル・シェリーバット 48.9% 700ml漫画ラベルシリーズ」のデータを正常に取得しました。
#    2.96秒待機します...
#
# --- 1050/1076件目を処理中: https://www.saketry.com/113406.html ---
# ○ 「『めぞん一刻』音無響子＆五代裕作ラベル／キルダルトン 2009 ホグスヘッド 54.2% 700ml漫画ラベルシリーズ」のデータを正常に取得しました。
#    2.68秒待機します...
#
# --- 1051/1076件目を処理中: https://www.saketry.com/113407.html ---
# ○ 「『旅みやげ第三集 別府の朝』ラベル 川瀬巴水 アン・オークニー2006 17年  59.1% 700MLアートエクスプレッション」のデータを正常に取得しました。
#    2.38秒待機します...
#
# --- 1052/1076件目を処理中: https://www.saketry.com/113408.html ---
# ○ 「成田一徹「THE DUFFTOWN」ラベル／レダイグ 2009 14年 ホグスヘッド 50.5% 700ml成田一徹 ラベル・ウイスキー」のデータを正常に取得しました。
#    3.06秒待機します...
#
# --- 1053/1076件目を処理中: https://www.saketry.com/113409.html ---
# ○ 「成田一徹「AUGUSTA」ラベル／ウエストポート 2006 17年 ホグスヘッド 51.2% 700ml成田一徹 ラベル・ウイスキー」のデータを正常に取得しました。
#    2.39秒待機します...
#
# --- 1054/1076件目を処理中: https://www.saketry.com/113410.html ---
# ○ 「『笑ゥせぇるすまん』ラベル／ベンネヴィス 1997 25年 シェリーバット 48.7% 700ml漫画ラベルシリーズ」のデータを正常に取得しました。
#    3.64秒待機します...
#
# --- 1055/1076件目を処理中: https://www.saketry.com/113411.html ---
# ○ 「パート6 カリラ 13年 リフィル・シェリーホグスヘッド / ファーストフィル・シェリーホグスヘッド 53% 700mlアイラスポンジ」のデータを正常に取得しました。
#    3.93秒待機します...
#
# --- 1056/1076件目を処理中: https://www.saketry.com/113412.html ---
# ○ 「エディション No.95 ‘サイドバーン’ 31年 2nd フィル・バレル / 1st フィル・バレル 51.4% 700mlウイスキースポンジ」のデータを正常に取得しました。
#    3.37秒待機します...
#
# --- 1057/1076件目を処理中: https://www.saketry.com/113413.html ---
# ○ 「エディション No.4 レダイグ 29年 2nd フィル・シェリーバット 52.0% 700mlウエスティースポンジ」のデータを正常に取得しました。
#    3.48秒待機します...
#
# --- 1058/1076件目を処理中: https://www.saketry.com/113414.html ---
# ○ 「イクイノックス＆ソルスティス サマーエディション 2024 モートラック 16年 48.5% 700mlウイスキースポンジ」のデータを正常に取得しました。
#    2.48秒待機します...
#
# --- 1059/1076件目を処理中: https://www.saketry.com/113415.html ---
# ○ 「エディション No.94 インチマリン 15年 2nd フィル・ホグスヘッド 53% 700mlウイスキースポンジ」のデータを正常に取得しました。
#    2.37秒待機します...
#
# --- 1060/1076件目を処理中: https://www.saketry.com/113416.html ---
# ○ 「エディション No.92 アベラワー 33年 49.7% 700mlウイスキースポンジ」のデータを正常に取得しました。
#    2.61秒待機します...
#
# --- 1061/1076件目を処理中: https://www.saketry.com/113419.html ---
# ○ 「シングルモルト津貫 2025 エディション 49% 700ML津貫」のデータを正常に取得しました。
#    2.10秒待機します...
#
# --- 1062/1076件目を処理中: https://www.saketry.com/113443.html ---
# ○ 「コッツウォルズ  ハーベスト・シリーズ No.3 アンバーメドウ シングルモルトウイスキー 51.6% 700mlコッツウォルズ」のデータを正常に取得しました。
#    2.89秒待機します...
#
# --- 1063/1076件目を処理中: https://www.saketry.com/113444.html ---
# ○ 「アードベッグ 2007 16年 スコッチモルト販売45周年記念ボトル 54.1% 700mlザ・モルトマン」のデータを正常に取得しました。
#    3.53秒待機します...
#
# --- 1064/1076件目を処理中: https://www.saketry.com/113445.html ---
# ○ 「ベンリネス 2010 14年 リフィル シェリーカスク 58.2% 700mlザ・モルトマン」のデータを正常に取得しました。
#    3.44秒待機します...
#
# --- 1065/1076件目を処理中: https://www.saketry.com/113452.html ---
# ○ 「コッツウォルズ シングルモルトウイスキー 母の日限定ラッピング 46% 200mlコッツウォルズ」のデータを正常に取得しました。
#    3.58秒待機します...
#
# --- 1066/1076件目を処理中: https://www.saketry.com/113467.html ---
# ○ 「MARS The Y.A. #04 50％ 700mlMARS The.Y.A.」のデータを正常に取得しました。
#    3.30秒待機します...
#
# --- 1067/1076件目を処理中: https://www.saketry.com/113468.html ---
# ○ 「ザ・ヒーラック シャトー・ビアック シングルモルトウイスキー 50% 700mlアイル・オブ・ハリス」のデータを正常に取得しました。
#    3.71秒待機します...
#
# --- 1068/1076件目を処理中: https://www.saketry.com/113472.html ---
# ○ 「リンクウッド 2009 13年 バーボンカスク 51.3％ 700mlザ・テイスター」のデータを正常に取得しました。
#    3.61秒待機します...
#
# --- 1069/1076件目を処理中: https://www.saketry.com/208525.html ---
# ○ 「マルス 津貫ニューポット ノンピーテッド 2016 60% 250ml」のデータを正常に取得しました。
#    3.31秒待機します...
#
# --- 1070/1076件目を処理中: https://www.saketry.com/208734.html ---
# ○ 「ホワイト ドッグ マッシュ #1 62.5% 375mlバッファロートレース」のデータを正常に取得しました。
#    3.83秒待機します...
#
# --- 1071/1076件目を処理中: https://www.saketry.com/41-03.html ---
# ○ 「コーキゲン シングルモルト」のデータを正常に取得しました。
#    3.81秒待機します...
#
# --- 1072/1076件目を処理中: https://www.saketry.com/600205.html ---
# ○ 「レベルイェル チェリー バーボンリキュール  35% 750mlREBEL YELL」のデータを正常に取得しました。
#    2.44秒待機します...
#
# --- 1073/1076件目を処理中: https://www.saketry.com/ob03-2019.html ---
# ○ 「Secret Speyside Distillery(シークレット スペイサイド ディスティラリー) 1994 24年 49.3%」のデータを正常に取得しました。
#    2.20秒待機します...
#
# --- 1074/1076件目を処理中: https://www.saketry.com/single-barrel.html ---
# ○ 「ギャリソン･ブラザーズ　シングルバレル」のデータを正常に取得しました。
#    3.03秒待機します...
#
# --- 1075/1076件目を処理中: https://www.saketry.com/straight.html ---
# ○ 「ギャリソン･ブラザーズ　ストレート」のデータを正常に取得しました。
#    3.74秒待機します...
#
# --- 1076/1076件目を処理中: https://www.saketry.com/thompson-bros-2010-10-529-700mlbr-thompson-bros-clone-.html ---
# ○ 「THOMPSON BROS. カリラ 2010 10年 52.9% 700MLTHOMPSON BROS.」のデータを正常に取得しました。
#    2.40秒待機します...
#
# --- 全ての処理が完了しました！ ---
# 1074件のデータを抽出し、'output\whisky_dataset_final.csv'に保存しました。

# %%
df = pd.read_csv('output\whisky_dataset_final.csv')
df.head(100)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\fugat\AppData\Local\Temp\ipykernel_47244\639702345.py:1: SyntaxWarning: invalid escape sequence '\w'
#   df = pd.read_csv('output\whisky_dataset_final.csv')
#                                                   商品名  \
# 0                                 クラシック オブ アイラ (10L樽)
# 1                                  ハイランド・クラシック (10L樽)
# 2                   クラシック オブ アイラ 58% 700mlスコッチモルトセールス
# 3                         タリバーディン 1991 19年 46％ザ・モルトマン
# 4                          燻酒 アイラ シングルモルト 50% 700ml燻酒
# ..                                                ...
# 95  プルトニー 2006 13年 シェリーバット 53.6% 700mlハートブラザーズ ファイ...
# 96        キングスバーンズ ドリーム・トゥ・ドラム シングルモルト 46％ 700mlウィームス
# 97        グレンアラヒー 1990 29年 オロロソシェリーパンチョン 58.2％グレンアラヒー
# 98              アードベッグ 2005 13年 バッチ17 48.4%ブティックウイスキー
# 99                       アラン 22年 バッチ8 48.4%ブティックウイスキー
#
#                                            テイスティングノート  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99  香り：バニラ、バナナ、トーストしたオーク、スパイス、杉 味：ミルクチョコレート、桃、パイナッ...
#
#                                     URL      原産国      地域  \
# 0   https://www.saketry.com/103120.html  スコットランド     アイラ
# 1   https://www.saketry.com/103237.html  スコットランド   ハイランド
# 2   https://www.saketry.com/105095.html  スコットランド     アイラ
# 3   https://www.saketry.com/110066.html  スコットランド   ハイランド
# 4   https://www.saketry.com/110371.html  スコットランド     アイラ
# ..                                  ...      ...     ...
# 95  https://www.saketry.com/111500.html  スコットランド   ハイランド
# 96  https://www.saketry.com/111502.html  スコットランド   ローランド
# 97  https://www.saketry.com/111504.html  スコットランド  スペイサイド
# 98  https://www.saketry.com/111505.html  スコットランド     アイラ
# 99  https://www.saketry.com/111506.html  スコットランド     アイラ
#
#                      ブランド            メーカー アルコール度数（%）  容量 (ml／g)          銘柄  \
# 0               エイジング・バレル    スコッチモルト・セールス         58    10000.0         NaN
# 1               エイジング・バレル    スコッチモルト・セールス        NaN    10000.0         NaN
# 2                     NaN    スコッチモルト・セールス         58      700.0         NaN
# 3                 ザ・モルトマン  メドウサイド・ブレンディング         46      700.0  タリバーディン蒸留所
# 4                      燻酒    スコッチモルト・セールス         50      700.0         NaN
# ..                    ...             ...        ...        ...         ...
# 95  ハートブラザーズ ファイネストコレクション       ハート・ブラザーズ       53.6      700.0    プルトニー蒸溜所
# 96               キングスバーンズ    Wemyss Malts         46      700.0         NaN
# 97                グレンアラヒー         グレンアラヒー       58.2      700.0         NaN
# 98             ブティックウイスキー             NaN       48.5      500.0         NaN
# 99             ブティックウイスキー             NaN       48.4      500.0         NaN
#
#    ビンテージ   年数
# 0    NaN  NaN
# 1    NaN  NaN
# 2    NaN  NaN
# 3   1991   19
# 4    NaN  NaN
# ..   ...  ...
# 95  2006  NaN
# 96   NaN  NaN
# 97  1990  NaN
# 98  2005  NaN
# 99   NaN  NaN
#
# [100 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   商品名         1074 non-null   object
#  1   テイスティングノート  541 non-null    object
#  2   URL         1074 non-null   object
#  3   原産国         1061 non-null   object
#  4   地域          967 non-null    object
#  5   ブランド        972 non-null    object
#  6   メーカー        883 non-null    object
#  7   アルコール度数（%）  1052 non-null   object
#  8   容量 (ml／g)   1057 non-null   float64
#  9   銘柄          787 non-null    object
#  10  ビンテージ       694 non-null    object
#  11  年数          797 non-null    object
# dtypes: float64(1), object(11)
# memory usage: 100.8+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                                     商品名 テイスティングノート  \
# 0                                   クラシック オブ アイラ (10L樽)        NaN
# 1                                    ハイランド・クラシック (10L樽)        NaN
# 2                     クラシック オブ アイラ 58% 700mlスコッチモルトセールス        NaN
# 3                           タリバーディン 1991 19年 46％ザ・モルトマン        NaN
# 4                            燻酒 アイラ シングルモルト 50% 700ml燻酒        NaN
# ...                                                 ...        ...
# 1069         レベルイェル チェリー バーボンリキュール  35% 750mlREBEL YELL        NaN
# 1070  Secret Speyside Distillery(シークレット スペイサイド ディスティ...        NaN
# 1071                                ギャリソン･ブラザーズ　シングルバレル        NaN
# 1072                                  ギャリソン･ブラザーズ　ストレート        NaN
# 1073  THOMPSON BROS. カリラ 2010 10年 52.9% 700MLTHOMPSO...        NaN
#
#                                                     URL      原産国      地域  \
# 0                   https://www.saketry.com/103120.html  スコットランド     アイラ
# 1                   https://www.saketry.com/103237.html  スコットランド   ハイランド
# 2                   https://www.saketry.com/105095.html  スコットランド     アイラ
# 3                   https://www.saketry.com/110066.html  スコットランド   ハイランド
# 4                   https://www.saketry.com/110371.html  スコットランド     アイラ
# ...                                                 ...      ...     ...
# 1069                https://www.saketry.com/600205.html     アメリカ  ケンタッキー
# 1070             https://www.saketry.com/ob03-2019.html  スコットランド  スペイサイド
# 1071         https://www.saketry.com/single-barrel.html     アメリカ  テキサス南西
# 1072              https://www.saketry.com/straight.html     アメリカ  テキサス南西
# 1073  https://www.saketry.com/thompson-bros-2010-10-...  スコットランド     アイラ
#
#                 ブランド            メーカー アルコール度数（%）  容量 (ml／g)          銘柄 ビンテージ  \
# 0          エイジング・バレル    スコッチモルト・セールス         58    10000.0         NaN   NaN
# 1          エイジング・バレル    スコッチモルト・セールス        NaN    10000.0         NaN   NaN
# 2                NaN    スコッチモルト・セールス         58      700.0         NaN   NaN
# 3            ザ・モルトマン  メドウサイド・ブレンディング         46      700.0  タリバーディン蒸留所  1991
# 4                 燻酒    スコッチモルト・セールス         50      700.0         NaN   NaN
# ...              ...             ...        ...        ...         ...   ...
# 1069             NaN             NaN         35      750.0         NaN   NaN
# 1070             NaN             NaN       49.3        NaN         NaN  1994
# 1071     ギャリソン･ブラザーズ             NaN         47        NaN         NaN   NaN
# 1072     ギャリソン･ブラザーズ             NaN         47        NaN         NaN   NaN
# 1073  THOMPSON BROS.        ドーノッホ蒸留所       52.9      700.0         カリラ  2010
#
#        年数
# 0     NaN
# 1     NaN
# 2     NaN
# 3      19
# 4     NaN
# ...   ...
# 1069  NaN
# 1070   24
# 1071  NaN
# 1072  NaN
# 1073   10
#
# [1074 rows x 12 columns]>

# %%
df[df['テイスティングノート'].notna()]
# Out:
#                                                     商品名  \
# 7                                 アラン ポートカスク・フィニッシュ 50%
# 8                        ティーリング シングルモルト 46% 700mlティーリング
# 24                             アラン ソーテルヌ・カスク・フィニッシュ 50%
# 31    ブレンデッド モルト スコッチ ウイスキー キメラ Cask ref:CH1-2016 46...
# 32                         ピートリーク エンバース EMB3 59%ブラックアダー
# ...                                                 ...
# 1059  コッツウォルズ  ハーベスト・シリーズ No.3 アンバーメドウ シングルモルトウイスキー ...
# 1061     ベンリネス 2010 14年 リフィル シェリーカスク 58.2% 700mlザ・モルトマン
# 1062   コッツウォルズ シングルモルトウイスキー 母の日限定ラッピング 46% 200mlコッツウォルズ
# 1064  ザ・ヒーラック シャトー・ビアック シングルモルトウイスキー 50% 700mlアイル・オブ...
# 1065         リンクウッド 2009 13年 バーボンカスク 51.3％ 700mlザ・テイスター
#
#                                              テイスティングノート  \
# 7     香り：ベイクドアップル、スパイス、ビターオレンジ。\n味わい：バニラ、シトラス、ドライフルー...
# 8     香り：　メロン、イチジク、トフィーとレモン。\n味わい：　ドライドフルーツ、シトラス、バニラ...
# 24                                香り： 蜂蜜、柑橘、アプリコット、メロン。
# 31    香り：甘いシェリーの味わい、バニラ、アプリコットと完熟のバナナ、ほんのりとタバコの香りとピー...
# 32    香り：スモーキーでピーティ。カリカリのベーコンのハチミツがけ。ハム、革。\n味わい：濃いハチ...
# ...                                                 ...
# 1059  香り：ストーンフルーツ、ラフランス、ハニードーナツ、メープルシロップ、ピンクペッパー\n味わ...
# 1061  香り：シトラスと焦がしたオーク。\n味わい：クリーミーで纏わりつくようなチョコレートにプラム...
# 1062  香り：　マジパンの香りと軽やかなフルーツ（桃とアプリコット）が重なる、蜂蜜とバタースコッチ\...
# 1064  香り：ピートスモークと甘草と甘いワインが穏やかに混ざり合う。\n味わい：果実味はより軽くなり...
# 1065  アロマ：馥郁とした果実の香りに満ちている。熟したプラムやレモンのマーマレード、青リンゴ、クラ...
#
#                                       URL      原産国       地域        ブランド  \
# 7     https://www.saketry.com/110484.html  スコットランド    アイランズ         NaN
# 8     https://www.saketry.com/110503.html   アイルランド      NaN      ティーリング
# 24    https://www.saketry.com/110890.html  スコットランド    アイランズ  ワインカスクシリーズ
# 31    https://www.saketry.com/110995.html  スコットランド      NaN         NaN
# 32    https://www.saketry.com/111007.html  スコットランド      アイラ      ピートリーク
# ...                                   ...      ...      ...         ...
# 1059  https://www.saketry.com/113443.html   イングランド  コッツウォルズ     コッツウォルズ
# 1061  https://www.saketry.com/113445.html  スコットランド   スぺイサイド     ザ・モルトマン
# 1062  https://www.saketry.com/113452.html   イングランド  コッツウォルズ         NaN
# 1064  https://www.saketry.com/113468.html  スコットランド    アイランズ  アイル・オブ・ハリス
# 1065  https://www.saketry.com/113472.html  スコットランド   スぺイサイド     ザ・テイスター
#
#                  メーカー アルコール度数（%）  容量 (ml／g)             銘柄 ビンテージ   年数
# 7     Whisk-e Limited         50      700.0            NaN   NaN  NaN
# 8        ティーリングウイスキー社         46      700.0      ティーリング蒸留所   NaN  NaN
# 24                NaN         50      700.0  アイル オブ アラン蒸溜所   NaN  NaN
# 31            ブラックアダー         46      700.0            NaN   NaN  NaN
# 32            ブラックアダー         59      700.0            NaN   NaN  NaN
# ...               ...        ...        ...            ...   ...  ...
# 1059          コッツウォルズ       51.6      700.0     コッツウォルズ蒸溜所   NaN  NaN
# 1061   メドウサイド・ブレンディング       58.2      700.0       ベンリネス蒸溜所  2010   14
# 1062          コッツウォルズ         46        NaN     コッツウォルズ蒸溜所   NaN  NaN
# 1064    アイル・オブ・ハリス蒸溜所         50      700.0  アイル・オブ・ハリス蒸溜所   NaN  NaN
# 1065  ザ・ウィスキー・エージェンシー       51.3      700.0      リンクウッド蒸溜所  2009   13
#
# [541 rows x 12 columns]

# %%
import pandas as pd
import MeCab
from pathlib import Path

# --- 1. 準備：データの読み込み ---
# 前回作成したCSVファイルを読み込みます
csv_file_path = Path('output') / 'whisky_dataset_final.csv' # 必要に応じてファイル名を変更してください

try:
    df = pd.read_csv(csv_file_path)
    # 念のため、この段階でもノートが空の行は除外しておきます
    df.dropna(subset=['テイスティングノート'], inplace=True)
    df = df[df['テイスティングノート'].str.strip() != '']
    print(f"'{csv_file_path}' を読み込み、{len(df)}件のデータを処理対象とします。")
except FileNotFoundError:
    print(f"エラー: '{csv_file_path}' が見つかりません。")
    exit()

# --- 2. MeCabの設定 ---
# MeCabのTagger（タグ付け器）オブジェクトを作成します
# "-Owakati" は「分かち書き」モードを指定するおまじないで、
# 文章をスペース区切りの単語の羅列に変換してくれます。
try:
    mecab = MeCab.Tagger("-Owakati")
    print("MeCabの準備ができました。")
except RuntimeError:
    print("エラー: MeCabの初期化に失敗しました。MeCabが正しくインストールされているか確認してください。")
    exit()

# --- 3. 形態素解析を行う関数を定義 ---
# テキストを一つ受け取り、分かち書きした結果を返す関数
def tokenize_text(text):
    # mecab.parse()でテキストを解析し、末尾の不要な改行などを.strip()で削除
    return mecab.parse(text).strip()

# --- 4. DataFrameの各行に形態素解析を適用 ---
# .apply()は、「テイスティングノート」列の各行に対して、
# 作成した`tokenize_text`関数を順番に実行し、
# その結果を新しい'tokens'という列に格納する、という非常に便利な命令です。
print("形態素解析を開始します...（データ量によって少し時間がかかります）")
df['tokens'] = df['テイスティングノート'].apply(tokenize_text)
print("形態素解析が完了しました。")


# --- 5. 結果の確認 ---
# 元の文章と、単語に分割された結果を並べて表示してみましょう
print("\n▼ 形態素解析の結果（先頭5行）")
print(df[['テイスティングノート', 'tokens']].head())


# --- 6. (任意) 結果を新しいCSVファイルとして保存 ---
# save_path = Path('output') / 'whisky_dataset_tokenized.csv'
# df.to_csv(save_path, index=False, encoding='utf-8-sig')
# print(f"\n形態素解析後のデータを '{save_path}' に保存しました。")
# Out:
# 'output\whisky_dataset_final.csv' を読み込み、541件のデータを処理対象とします。
# MeCabの準備ができました。
# 形態素解析を開始します...（データ量によって少し時間がかかります）
# 形態素解析が完了しました。
#
# ▼ 形態素解析の結果（先頭5行）
#                                            テイスティングノート  \
# 7   香り：ベイクドアップル、スパイス、ビターオレンジ。\n味わい：バニラ、シトラス、ドライフルー...
# 8   香り：　メロン、イチジク、トフィーとレモン。\n味わい：　ドライドフルーツ、シトラス、バニラ...
# 24                              香り： 蜂蜜、柑橘、アプリコット、メロン。
# 31  香り：甘いシェリーの味わい、バニラ、アプリコットと完熟のバナナ、ほんのりとタバコの香りとピー...
# 32  香り：スモーキーでピーティ。カリカリのベーコンのハチミツがけ。ハム、革。\n味わい：濃いハチ...
#
#                                                tokens
# 7   香り ： ベイクドアップル 、 スパイス 、 ビターオレンジ 。 味わい ： バニラ 、 シ...
# 8   香り ： 　 メロン 、 イチジク 、 トフィー と レモン 。 味わい ： 　 ドライドフ...
# 24                      香り ： 蜂蜜 、 柑橘 、 アプリコット 、 メロン 。
# 31  香り ： 甘い シェリー の 味わい 、 バニラ 、 アプリコット と 完熟 の バナナ 、...
# 32  香り ： スモーキー で ピーティ 。 カリカリ の ベーコン の ハチミツ がけ 。 ハム...

# %%
# --- 7. 分割した単語リストから、不要な単語（ノイズ）を除去する ---

# ストップワードのリストを定義（これは自由にカスタマイズできます）
stop_words = ['する', 'いる', 'ある', 'これ', 'それ', 'あれ', '思う', '感じ', '的', '的',
              '香り', '味わい', 'フィニッシュ', 'アロマ', 'フレーバー', 'ノート', 'テイスティング','かすか','微か','ほのか','わずか','少し','少々','やや','かなり','非常に',
              'とても', 'すごく', 'めちゃくちゃ', 'すごい', '大変', 'すごく', 'とても', 'かなり', '非常に', '極めて', '特に', '特別', '一番', '最高',
]

# 単語をお掃除する関数を定義
def clean_tokens(text):
    # テキストをスペースで単語リストに分割
    words = text.split(' ')
    
    # フィルタリング後の単語を入れるための空リスト
    cleaned_words = []
    
    for word in words:
        # 品詞情報などを取得（今回は使わないが、より高度な処理も可能）
        # parts = mecab.parse(word).split('\t')
        
        # ▼ フィルタリングの条件 ▼
        # 1. ストップワードリストに含まれていない
        # 2. 1文字だけの単語ではない（「、」や「。」などの記号や助詞を除外しやすい）
        # 3. 数字ではない
        if word not in stop_words and len(word) > 1 and not word.isnumeric():
            cleaned_words.append(word)
            
    # 掃除後の単語リストを、再度スペース区切りの一つのテキストに戻す
    return ' '.join(cleaned_words)


# --- 8. 作成したお掃除関数を、'tokens'列に適用 ---
print("\n形態素解析後のトークンをクリーニングします...")
df['tokens_cleaned'] = df['tokens'].apply(clean_tokens)
print("クリーニングが完了しました。")


# --- 9. クリーニング前と後を比較して確認 ---
print("\n▼ クリーニング前後の比較（先頭5行）")
print(df[['tokens', 'tokens_cleaned']].head())


# --- 10. (任意) 最終的なデータをCSVに保存 ---
save_path = Path('output') / 'whisky_dataset_cleaned.csv'
df.to_csv(save_path, index=False, encoding='utf-8-sig')
print(f"\nクリーニング後のデータを '{save_path}' に保存しました。")
# Out:
# 形態素解析後のトークンをクリーニングします...
# クリーニングが完了しました。
#
# ▼ クリーニング前後の比較（先頭5行）
#                                                tokens  \
# 7   香り ： ベイクドアップル 、 スパイス 、 ビターオレンジ 。 味わい ： バニラ 、 シ...
# 8   香り ： 　 メロン 、 イチジク 、 トフィー と レモン 。 味わい ： 　 ドライドフ...
# 24                      香り ： 蜂蜜 、 柑橘 、 アプリコット 、 メロン 。
# 31  香り ： 甘い シェリー の 味わい 、 バニラ 、 アプリコット と 完熟 の バナナ 、...
# 32  香り ： スモーキー で ピーティ 。 カリカリ の ベーコン の ハチミツ がけ 。 ハム...
#
#                                        tokens_cleaned
# 7   ベイクドアップル スパイス ビターオレンジ バニラ シトラス ドライ フルーツ ナッツ チョ...
# 8   メロン イチジク トフィー レモン ドライドフルーツ シトラス バニラ スパイス クローブ ...
# 24                                   蜂蜜 柑橘 アプリコット メロン
# 31  甘い シェリー バニラ アプリコット 完熟 バナナ ほんのり タバコ ピート これら カラメ...
# 32  スモーキー ピーティ カリカリ ベーコン ハチミツ がけ ハム 濃い ハチミツ よう なめら...
#
# クリーニング後のデータを 'output\whisky_dataset_cleaned.csv' に保存しました。

# %%
# ランダムサンプリング
display(df[['テイスティングノート', 'tokens_cleaned']].sample(20))
# Out:
#                                              テイスティングノート  \
# 987   香り：透明感のあるピーティーさを、甘さとフルーティーさが包んでいる。徐々にピート焚きした麦芽...
# 586   香り：リンゴのコンポート、トフィー、ココナッツ、ミルクティ。\n味わい：トフィー、キャラメル...
# 1004  香り：ジンジャーと緑茶をまぶしたバニラスポンジケーキ\n味わい：オールドバーボンが香るバニラ...
# 927   香り：サクラやハナミズキの花。リンゴの皮。ビスケットとクリーム。\n味わい：桜餅。パティスリ...
# 839   香り：明るく、シトラスのようで、甘いヘザーのようなピートスモークとチョークのようなミネラルの...
# 779   香り：焼き菓子のフロランタン、バニラ、黒ブドウ、ブラックチェリー。\n味わい：モルティな甘み...
# 909   香り：甘いショートブレッド、バニラ、青リンゴ、レモンの皮。\n味わい：甘いビスケット、さくら...
# 357   香り：バランスが非常によいシェリー樽ウイスキーの香り。ナツメヤシ、プルーンなどドライフルーツ...
# 153   香り：ナツメヤシなどのドライフルーツ。ナッツ入りのチョコレート。最後にリンゴの皮。フレーバー...
# 432   香り：レーズンの香り、バタースコッチのこってりとしたアマロ、シナモンやクローブといった甘やか...
# 665   香り：レモンとオレンジのピール。麦芽の殻。クリアーなモルティーさ。徐々に穏やかなスモーク。\...
# 285   香り：磨いた家具、古いシガー、杉の木、いちじくとデーツ、プラリネ、ピスタチオのマジパン、わず...
# 440   香り：灰、ヨード、燻製したプラム、潮風、ハムの燻製、ダークフルーツ、洋ナシの煮込み、ダークチ...
# 716   香り：焼いたレモン、リッチなねっとりしたトフィープディング、麦芽のビスケット、プラム、ヘーゼ...
# 314   香り：焼きリンゴにシナモンとクローブをまぶし、レーズンの香りと、海岸の微妙な塩分を感じさせま...
# 473   香り：キャラメル、ハチミツ、フルーツ、トーストしたオーク、スパイス。\n味わい：デーツ、プル...
# 1038  香り：トップノートはすっきりとしたシトラスピールとレンゲの蜂蜜。マスカットや青リンゴ、パイナ...
# 709   香り：優しい樽香、キャラメル、フレッシュなレモンで覆われた豊かな赤系の果実。\n味わい：ミデ...
# 1061  香り：シトラスと焦がしたオーク。\n味わい：クリーミーで纏わりつくようなチョコレートにプラム...
# 437   香り：ママレード、ハニー、ソルト＆ミント、オレンジピール、海のロープに張り付いたムール貝、焼...
#
#                                          tokens_cleaned
# 987   透明 ピーティー フルーティー 包ん 徐々に ピート 焚き 麦芽 美味しい 桜餅 柏餅 感じ...
# 586   リンゴ コンポート トフィー ココナッツ ミルクティ トフィー キャラメル バニラ クリーム...
# 1004  ジンジャー 緑茶 まぶし バニラスポンジケーキ オールドバーボン 香る バニラ トフィーポッ...
# 927   サクラ ハナミズキ リンゴ ビスケット クリーム 桜餅 パティスリー モル ティー スパイス...
# 839   明るく シトラス よう 甘い ヘザー よう ピートスモーク チョーク よう ミネラル 側面 ...
# 779   焼き 菓子 フロランタン バニラ ブドウ ブラック チェリー モルティ 甘み ブラックカラン...
# 909   甘い ショートブレッド バニラ リンゴ レモン 甘い ビスケット さくらんぼ グラッセ ホワ...
# 357   バランス 非常 よい シェリー ウイスキー ナツメヤシ プルーン など ドライ フルーツ 高...
# 153   ナツメヤシ など ドライ フルーツ ナッツ 入り チョコレート 最後 リンゴ ビターチョコ ...
# 432   レーズン バター スコッチ こってり アマ シナモン クローブ といった スパイス レーズン...
# 665   レモン オレンジ ピール 麦芽 クリアー モル ティー 徐々に 穏やか スモーク グレープフ...
# 285   磨い 家具 古い シガー いちじく デーツ プラリネ ピスタチオ マジパン なき この 柔ら...
# 440   ヨード 燻製 プラム 潮風 ハム 燻製 ダーク フルーツ ナシ 煮込み ダーク チョコレート...
# 716   焼い レモン リッチ ねっとり トフィープディング 麦芽 ビスケット プラム ヘーゼルナッツ...
# 314   焼きリンゴ シナモン クローブ まぶし レーズン 海岸 微妙 塩分 させ ます バター よう...
# 473   キャラメル ハチミツ フルーツ トースト オーク スパイス デーツ プルーン いちじく シナ...
# 1038  トップ すっきり シトラスピール レンゲ 蜂蜜 マスカット リンゴ パイナップル キウイ ク...
# 709   優しい キャラメル フレッシュ レモン 覆わ 豊か 果実 ミディアムボディ フルーティー シ...
# 1061  シトラス 焦がし オーク クリーミー 纏わり つく よう チョコレート プラム ジャム シェ...
# 437   ママレード ハニー ソルト ミント オレンジピール ロープ 張り付い ムール貝 焼い オレン...

# %%
import pandas as pd
import MeCab
from pathlib import Path
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

print("--- プログラムを開始します ---")

csv_file_path = Path('output') / 'whisky_dataset_final.csv'

try:
    df = pd.read_csv(csv_file_path)
    df.dropna(subset=['テイスティングノート'], inplace=True)
    df = df[df['テイスティングノート'].str.strip() != '']
    df.reset_index(drop=True, inplace=True)
    print(f"'{csv_file_path}' を読み込み、{len(df)}件のデータを処理対象とします。")
except FileNotFoundError:
    print(f"エラー: '{csv_file_path}' が見つかりません。")
    exit()

#形態素分析
print("\n--- ステップ2: テキストの前処理を開始します ---")
try:
    mecab = MeCab.Tagger("-Owakati")
except RuntimeError as e:
    print(f"エラー: MeCabの初期化に失敗しました。インストールを確認してください。 {e}")
    exit()

stop_words = ['する', 'いる', 'ある', 'これ', 'それ', 'あれ', '思う', '感じ', '的',
              '香り', '味わい', 'フィニッシュ', 'アロマ', 'フレーバー', 'ノート', 'テイスティング']

def clean_and_tokenize(text):
    wakati_text = mecab.parse(text).strip()
    words = wakati_text.split(' ')
    cleaned_words = []
    for word in words:
        if word not in stop_words and len(word) > 1 and not word.isnumeric():
            cleaned_words.append(word)
    return ' '.join(cleaned_words)

df['tokens_cleaned'] = df['テイスティングノート'].apply(clean_and_tokenize)
print("テキストの前処理が完了しました。")


# 重みづけ
smoky_words = ['スモーキー', 'ピート', 'ピーティ', 'ヨード', '煙', '燻製', '潮', '薬品', '正露丸']
fruity_words = ['フルーティー', 'フルーツ', '果実', 'リンゴ', '柑橘', 'レモン', 'オレンジ', 
                'ベリー', 'レーズン', 'ピーチ', 'アプリコット', 'パイナップル']
sherry_words = ['シェリー', 'ドライフルーツ', 'レーズン', 'カカオ', 'チョコレート']

def add_weights(text):
    words = text.split(' ')
    boosted_text = text
    
    # スモーキー系
    if any(word in text for word in smoky_words):
        boosted_text += ' スモーキー' * 10
        
    # フルーティー系
    if any(word in text for word in fruity_words):
        boosted_text += ' フルーティー' * 10
        
    # シェリー系
    if any(word in text for word in sherry_words):
        boosted_text += ' シェリー' * 10
        
    return boosted_text

df['tokens_boosted'] = df['tokens_cleaned'].apply(add_weights)

print("キーワードの重みづけが完了しました。")
print("\n--- ステップ3: レコメンドエンジンを構築します ---")

# TF-IDFベクトル化
vectorizer = TfidfVectorizer(max_features=2000)
tfidf_matrix = vectorizer.fit_transform(df['tokens_boosted']) 
print(f"TF-IDF行列を作成しました。(形状: {tfidf_matrix.shape})")

# コサイン類似度計算
cosine_sim_matrix = cosine_similarity(tfidf_matrix)
print(f"類似度行列を作成しました。(形状: {cosine_sim_matrix.shape})")

# レコメンド関数を定義
indices = pd.Series(df.index, index=df['商品名']).drop_duplicates()

def get_recommendations(title, cosine_sim=cosine_sim_matrix):
    try:
        idx = indices[title]
    except KeyError:
        return f"エラー: '{title}' というウイスキーはデータセットに存在しません。"
    
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:6]
    whisky_indices = [i[0] for i in sim_scores]
    
    return df.iloc[whisky_indices]

print("レコメンドエンジンの準備が完了しました！")


print("\n--- ステップ4: レコメンド実行例 ---")
target_whisky = input("レコメンドを受けたいウイスキーの名前を入力してください: ")

recommendations = get_recommendations(target_whisky)

print(f"\n▼「{target_whisky}」が好きなあなたへのおすすめ:")
if isinstance(recommendations, pd.DataFrame):
    print(recommendations[['商品名', 'URL']])
else:
    print(recommendations)
# Out:
# --- プログラムを開始します ---
# 'output\whisky_dataset_final.csv' を読み込み、541件のデータを処理対象とします。
#
# --- ステップ2: テキストの前処理を開始します ---
# テキストの前処理が完了しました。
# キーワードの重みづけが完了しました。
#
# --- ステップ3: レコメンドエンジンを構築します ---
# TF-IDF行列を作成しました。(形状: (541, 1813))
# 類似度行列を作成しました。(形状: (541, 541))
# レコメンドエンジンの準備が完了しました！
#
# --- ステップ4: レコメンド実行例 ---
#
# ▼「ブルックラディ 13年 バッチ11 47.6%ブティックウイスキー」が好きなあなたへのおすすめ:
#                                                    商品名  \
# 232  グレンスペイ 2010 11年 カルヴァドスフィニッシュ 55% 700mlザ・クーパーズ・...
# 132  ウイスキーギャラリー オーヘントッシャン2000 20年 58.1% 700ml Whisk...
# 2                             アラン ソーテルヌ・カスク・フィニッシュ 50%
# 33                    グレンフィディック12年 スペシャルリザーブ 40％ 700ml
# 205                   バスカ― アイリッシュウイスキーバスカ― アイリッシュウイスキー
#
#                                      URL
# 232  https://www.saketry.com/112472.html
# 132  https://www.saketry.com/112252.html
# 2    https://www.saketry.com/110890.html
# 33   https://www.saketry.com/111956.html
# 205  https://www.saketry.com/112413.html
